[57158.3, 16.5, 0.0217, 0.0214],
[57158.3, 29.5, 0.0401, 0.0362],
[57158.3, 35, -0.00361, 0.045],

[57187.2, 1.26, 0.277, 0.116], #BnA _> A
[57187.2, 1.74, -0.0505, 0.0776],
[57187.2, 5, 0.0194, 0.0204],
[57187.2, 7, 0.044, 0.0223],
[57187.2, 13.5, 0.0587, 0.0157],
[57187.2, 16.5, 0.0569, 0.021],
[57187.2, 29.5, 0.13, 0.0446],
[57187.2, 35, -0.0206, 0.0588],

#57360.7	1.26	XX	XX #D
#57360.7	1.74	XX	XX
[57360.7, 5, 0.0795, 0.031],
[57360.7, 7, 0.0561, 0.022],
[57360.7, 13.5, -0.0000599, 0.0196],
[57360.7, 16.5, -0.000577, 0.0199],
[57360.7, 29.6, -0.0157, 0.051],
[57360.7, 35, 0.0632, 0.0608],)



df =  pd.DataFrame(data, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

# %%
df
# Out:
#         MJD  Freq (GHz)  Flux Density (mJy)  Uncertainty (mJy)
# 0   57067.5        4.55            4.132000             0.0203
# 1   57067.5        7.38            2.786000             0.0128
# 2   57067.5       28.20            0.819000             0.0575
# 3   57067.5       36.50            0.675000             0.0834
# 4   57071.5       13.50            0.416000             0.0175
# ..      ...         ...                 ...                ...
# 79  57360.7        7.00            0.056100             0.0220
# 80  57360.7       13.50           -0.000060             0.0196
# 81  57360.7       16.50           -0.000577             0.0199
# 82  57360.7       29.60           -0.015700             0.0510
# 83  57360.7       35.00            0.063200             0.0608
#
# [84 rows x 4 columns]

# %%
#creating the days from the first reading
#defining a list of days
days = df['MJD'] - 57064.837

# %%
#defining the flux and flux errors to it can be plotted

flux = df["Flux Density (mJy)"]
flux_err = df["Uncertainty (mJy)"]

# %%
fig,ax = plt.subplots()

ax.plot(days,flux, '.')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel("Days")
ax.set_ylabel("Flux Density (mJy)")
ax.set_title("")
plt.show();

# %%
#now to split it up by frequency

# %%
#57360.7	1.26	XX	XX #D
#57360.7	1.74	XX	XX #D

f1_26 = ([57187.2, 1.26, 0.277, 0.116], #BnA _> A
         [57158.3, 1.26, -0.152, 0.177], #B_> BnA
         [57143.3, 1.26, -0.0723, 0.106], #B
         [57130.35, 1.26, 0.444, 0.0813],
         [57120.57, 1.26, 0.873, 0.1], #B
         [57106.47, 1.26, 0.273, 0.112], #B
         [57091.4, 1.26, 0.153, 0.0738], #B
         [57082.5, 1.26, 0.0142, 0.101], #B
         [57072.5, 1.26, 1.57, 0.0765], #B
        )

f1_74 = ([57187.2, 1.74, -0.0505, 0.0776],#BnA _> A
         [57158.3, 1.74, 0.101, 0.0784],#B_> BnA
         [57143.3, 1.74, 0.165, 0.0711],
         [57130.35, 1.74, 0.258, 0.056],
         [57120.57, 1.74, 0.661, 0.0562],
         [57106.47, 1.74, 0.163, 0.0597],
         [57091.4, 1.74, 0.11, 0.0538],
         [57082.5, 1.74, 0.12, 0.0655],
         [57072.5, 1.74, 1.21, 0.0728],
        )

f4_55 = ([57360.7, 5, 0.0795, 0.031],#D
         [57187.2, 5, 0.0194, 0.0204],#BnA _> A
         [57158.3, 4.55, 0.0727, 0.023],#B_> BnA
         [57143.3, 4.55, 0.17, 0.0183],
         [57130.35, 4.55, 0.256, 0.0172],
         [57120.57, 4.55, 0.483, 0.0191],
         [57106.47, 4.55, 0.222, 0.0161],
         [57091.4, 4.55, 0.455, 0.0187],
         [57082.5, 4.55, 0.221, 0.0181],
         [57077.7, 4.87, 0.155, 0.0409], #VLBA
         [57072.5, 4.87, 0.484, 0.0505], #VLBA
         [57072.5, 4.55, 0.65, 0.0168],
         [57067.5, 4.55, 4.132, 0.0203],#B
        )

f7_38 = ([57360.7, 7, 0.0561, 0.022],#D
         [57187.2, 7, 0.044, 0.0223],#BnA _> A
         [57158.3, 7.38, 0.0708, 0.0171],#B_> BnA
         [57143.3, 7.38, 0.139, 0.0144],
         [57130.35, 7.38, 0.228, 0.0117],
         [57120.57, 7.38, 0.374, 0.0138],
         [57106.47, 7.38, 0.253, 0.012],
         [57091.4, 7.38, 0.536, 0.0136],
         [57082.5, 7.38, 0.192, 0.0157],
         [57072.5, 7.38, 0.439, 0.0126],
         [57067.5, 7.38, 2.786, 0.0128],
        )

f13_5 = ([57360.7, 13.5, -0.0000599, 0.0196],#D
         [57187.2, 13.5, 0.0587, 0.0157],#BnA _> A
         [57158.3, 13.5, 0.0518, 0.0175],#B_> BnA
         [57143.34, 13.5, 0.129, 0.0168], #B
         [57131.33, 13.5, 0.209, 0.0156], #B
         [57119.41, 13.5, 0.457, 0.0248], #B
         [57106.42, 13.5, 0.267, 0.0126], #B
         [57088.5, 13.5, 0.585, 0.0166], #B
         [57077.6, 13.5, 0.385, 0.0163], #B
         [57071.5, 13.5, 0.416, 0.0175], #B
        )

f17_4 = ([57360.7, 16.5, -0.000577, 0.0199],#D
         [57187.2, 16.5, 0.0569, 0.021],#BnA _> A
         [57158.3, 16.5, 0.0217, 0.0214],#B_> BnA
         [57143.34, 17.4, 0.164, 0.0216],
         [57131.33, 17.4, 0.167, 0.0221],
         [57119.41, 17.4, 0.399, 0.0182],
         [57106.42, 17.4, 0.299, 0.0143],
         [57088.5, 17.4, 0.755, 0.0207],
         [57077.6, 17.4, 0.456, 0.02],
         [57071.5, 17.4, 0.344, 0.0213],
        )

f28_2 = ([57360.7, 29.6, -0.0157, 0.051],#D
         [57187.2, 29.5, 0.13, 0.0446],#BnA _> A
         [57158.3, 29.5, 0.0401, 0.0362],#B_> BnA
         [57143.34, 28.2, 0.174, 0.0523],
         [57131.33, 28.2, 0.173, 0.0482],
         [57119.41, 28.2, 0.323, 0.0446],
         [57106.42, 28.2, 0.348, 0.0405],
         [57088.5, 28.2, 1.15, 0.0462],
         [57077.6, 28.2, 0.785, 0.0485],
         [57071.5, 28.2, 0.295, 0.0505],
         [57067.5, 28.2, 0.819, 0.0575],
        )

f36_5 = ([57360.7, 35, 0.0632, 0.0608],#D
         [57187.2, 35, -0.0206, 0.0588],#BnA _> A
         [57158.3, 35, -0.00361, 0.045],#B_> BnA
         [57143.34, 36.5, 0.0153, 0.0753],
         [57131.33, 36.5, 0.0395, 0.0833],
         [57119.41, 36.5, 0.276, 0.0602],
         [57106.42, 36.5, 0.186, 0.0551],
         [57088.5, 36.5, 1.68, 0.071],
         [57077.6, 36.5, 0.845, 0.0758],
         [57071.5, 36.5, 0.376, 0.0714],
         [57067.5, 36.5, 0.675, 0.0834],
        )

# %%
df1_26 =  pd.DataFrame(f1_26, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df1_74 =  pd.DataFrame(f1_74, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df4_55 =  pd.DataFrame(f4_55, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df7_38 =  pd.DataFrame(f7_38, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df13_5 =  pd.DataFrame(f13_5, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df17_4 =  pd.DataFrame(f17_4, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df28_2 =  pd.DataFrame(f28_2, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df36_5 =  pd.DataFrame(f36_5, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

# %%
days1_26 = df1_26['MJD'] - 57064.837
flux1_26 = df1_26["Flux Density (mJy)"]
flux_err1_26 = np.sqrt(df1_26["Uncertainty (mJy)"]**2 + (df1_26["Flux Density (mJy)"]*0.05)**2)

days1_74 = df1_74['MJD'] - 57064.837
flux1_74 = df1_74["Flux Density (mJy)"]
flux_err1_74 = np.sqrt(df1_74["Uncertainty (mJy)"]**2 + (df1_74["Flux Density (mJy)"]*0.05)**2)

days4_55 = df4_55['MJD'] - 57064.837
flux4_55 = df4_55["Flux Density (mJy)"]
flux_err4_55 = np.sqrt(df4_55["Uncertainty (mJy)"]**2 + (df4_55["Flux Density (mJy)"]*0.05)**2)

days7_38 = df7_38['MJD'] - 57064.837
flux7_38 = df7_38["Flux Density (mJy)"]
flux_err7_38 = np.sqrt(df7_38["Uncertainty (mJy)"]**2 + (df7_38["Flux Density (mJy)"]*0.05)**2)

days13_5 = df13_5['MJD'] - 57064.837
flux13_5 = df13_5["Flux Density (mJy)"]
flux_err13_5 = np.sqrt(df13_5["Uncertainty (mJy)"]**2 + (df13_5["Flux Density (mJy)"]*0.1)**2)

days17_4 = df17_4['MJD'] - 57064.837
flux17_4 = df17_4["Flux Density (mJy)"]
flux_err17_4 = np.sqrt(df17_4["Uncertainty (mJy)"]**2 + (df17_4["Flux Density (mJy)"]*0.1)**2)

days28_2 = df28_2['MJD'] - 57064.837
flux28_2 = df28_2["Flux Density (mJy)"]
flux_err28_2 = np.sqrt(df28_2["Uncertainty (mJy)"]**2 + (df28_2["Flux Density (mJy)"]*0.1)**2)

days36_5 = df36_5['MJD'] - 57064.837
flux36_5 = df36_5["Flux Density (mJy)"]
flux_err36_5 = np.sqrt(df36_5["Uncertainty (mJy)"]**2 + (df36_5["Flux Density (mJy)"]*0.1)**2)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,10)

# Store which labels have already been used
used_labels = set()

def plot(days, fluxes, errors, color, label_name):
    for day, flux, err in zip(days, fluxes, errors):
        if flux < 3 * err:
            fmt = 'x'  # square for non-detection
            label = None  # no label for non-detections

            ax.errorbar(day, (flux+3*err), fmt=fmt, color=color, label=label)
            
        if flux > 3*err :
            fmt = '^'  # triangle for detection
            label = label_name if label_name not in used_labels else None
        
            ax.errorbar(day, flux, yerr=err, fmt=fmt, color=color, label=label)
        
        if label:
            used_labels.add(label)

# Plot each band
plot(days1_26, flux1_26, flux_err1_26, 'orange', '1.26 GHz')
#ax.plot(days1_26, flux1_26, color='orange', linestyle = '--', alpha=.50)
plot(days1_74, flux1_74, flux_err1_74, 'red', '1.74 GHz')
#ax.plot(days1_74, flux1_74, color='red', linestyle = '--', alpha=.50)

plot(days4_55, flux4_55, flux_err4_55, 'green', '4.55 GHz')
#ax.plot(days4_55, flux4_55, color='green', linestyle = '--', alpha=.50)
plot(days7_38, flux7_38, flux_err7_38, 'blue', '7.38 GHz')
#ax.plot(days7_38, flux7_38, color='blue', linestyle = '--', alpha=.50)

plot(days13_5, flux13_5, flux_err13_5, 'purple', '13.5 GHz')
#ax.plot(days13_5, flux13_5, color='purple', linestyle = '--', alpha=.50)
plot(days17_4, flux17_4, flux_err17_4, 'hotpink', '17.4 GHz')
#ax.plot(days17_4, flux17_4, color='hotpink', linestyle = '--', alpha=.50)

plot(days28_2, flux28_2, flux_err28_2, 'black', '28.2 GHz')
#ax.plot(days28_2, flux28_2, color='black', linestyle = '--', alpha=.50)
plot(days36_5, flux36_5, flux_err36_5, 'grey', '36.5 GHz')
#ax.plot(days36_5, flux36_5, color='grey', linestyle = '--', alpha=.50)


# Final plot formatting
ax.set_xscale('log')
ax.set_xticks([10,20,50,100,200], labels = ['10','20','50','100','200'], fontsize = 20)
ax.set_yscale('log')
ax.set_yticks([.1,1.0, 10.0], labels = [r'$10^{-1}$',r'$10^{0}$', r'$10^{1}$'], fontsize = 20)
ax.set_xlabel("Time since eruption (days)", fontsize = 25)
ax.set_ylabel("Flux Density (mJy)", fontsize = 25)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

ax.set_title("")
plt.legend(fontsize = 15)
plt.savefig("V1535Sco_lc.png")
plt.show()

# %%
np.max(flux4_55)
# Out:
# 4.132

# %%
df4_55
# Out:
#          MJD  Freq (GHz)  Flux Density (mJy)  Uncertainty (mJy)
# 0   57360.70        5.00              0.0795             0.0310
# 1   57187.20        5.00              0.0194             0.0204
# 2   57158.30        4.55              0.0727             0.0230
# 3   57143.30        4.55              0.1700             0.0183
# 4   57130.35        4.55              0.2560             0.0172
# 5   57120.57        4.55              0.4830             0.0191
# 6   57106.47        4.55              0.2220             0.0161
# 7   57091.40        4.55              0.4550             0.0187
# 8   57082.50        4.55              0.2210             0.0181
# 9   57077.70        4.87              0.1550             0.0409
# 10  57072.50        4.87              0.4840             0.0505
# 11  57072.50        4.55              0.6500             0.0168
# 12  57067.50        4.55              4.1320             0.0203

# %%
print(flux_err4_55)
# Out:
# 0     0.031254
# 1     0.020423
# 2     0.023285
# 3     0.020178
# 4     0.021440
# 5     0.030790
# 6     0.019556
# 7     0.029449
# 8     0.021206
# 9     0.041628
# 10    0.055999
# 11    0.036585
# 12    0.207595
# dtype: float64
