# %% [markdown]
# V5589 Sag lightcurve

# %%
#imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#defining all the data points

data = ([56040.4,	1,	33,	0.032,	0.025,	1.00E-10,	0.05],
    [56069.0,	'A',	225.3,	13.80,	2.000,	1.00E-10,	0.05],
    [56084.4,	2,	5,	1.089,	0.028,	1.00E-10,	0.05],
    [56084.4,	2,	6.8,	1.381,	0.025,	1.00E-10,	0.05],
    [56092.2,	3,	13.3,	3.523,	0.042,	1.00E-10,	0.05],
    [56092.2,	3,	16,	3.98,	0.049,	1.00E-10,	0.05],
    [56092.2,	3,	28.2,	5.727,	0.098,	1.00E-10,	0.05],
    [56092.2,	3,	36.5,	5.961,	0.139,	1.00E-10,	0.05],
    [56100.3,	4,	2.5,	3.094,	0.037,	1.00E-10,	0.05],
    [56100.3,	4,	3.5,	3.201,	0.030,	1.00E-10,	0.05],
    [56100.3,	4,	5,	3.423,	0.023,	1.00E-10,	0.05],
    [56100.3,	4,	6.8,	3.629,	0.025,	1.00E-10,	0.05],
    [56100.3,	4,	8.5,	3.683,	0.052,	1.00E-10,	0.05],
    [56100.3,	4,	11.4,	3.779,	0.071,	1.00E-10,	0.05],
    [56117.9,	'B',	225.5,	0.000,	0.068,	1.00E-10,	0.05],
    [56119.1,	5,	1.35,	1.68,	0.120,	1.00E-10,	0.05],
    [56119.1,	5,	1.84,	1.391,	0.066,	1.00E-10,	0.05],
    [56119.1,	5,	4.74,	1.907,	0.027,	1.00E-10,	0.05],
    [56119.1,	5,	7.59,	1.921,	0.023,	1.00E-10,	0.05],
    [56128.3,	6,	17.5,	1.374,	0.091,	1.00E-10,	0.05],
    [56128.3,	6,	27.5,	1.438,	0.143,	1.00E-10,	0.05],
    [56128.3,	6,	36.5,	1.136,	0.194,	1.00E-10,	0.05],
    [56148.0,	7,	1.2555,	0.340,	0.071,	1.00E-10,	0.05],
    [56148.0,	7,	1.7715,	0.560,	0.072,	1.00E-10,	0.05],
    [56148.0,	7,	4.74,	0.521,	0.033,	1.00E-10,	0.05],
    [56148.0,	7,	7.59,	0.528,	0.025,	1.00E-10,	0.05],
    [56148.0,	7,	8.53,	0.556,	0.031,	1.00E-10,	0.05],
    [56148.0,	7,	11.38,	0.571,	0.060,	1.00E-10,	0.05],
    [56150.2,	8,	13.3,	0.495,	0.042,	1.00E-10,	0.05],
    [56150.2,	8,	17.45,	0.38,	0.049,	1.00E-10,	0.05],
    [56150.2,	8,	27.5,	0.469,	0.078,	1.00E-10,	0.05],
    [56150.2,	8,	36.5,	0.39,	0.086,	1.00E-10,	0.05],
    [56151.3,	8,	1.25,	0,	0.091,	1.00E-10,	0.05],
    [56151.3,	8,	1.80,	0.497,	0.088,	1.00E-10,	0.05],
    [56151.3,	8,	4.549,	0.502,	0.034,	1.00E-10,	0.05],
    [56151.3,	8,	7.399,	0.469,	0.025,	1.00E-10,	0.05],
    [56151.3,	8,	8.51,	0.443,	0.021,	1.00E-10,	0.05],
    [56151.3,	8,	11.34,	0.418,	0.035,	1.00E-10,	0.05],
    
#S4322
    [56167.0,	9,	1.36,	0.244,	0.049,	1.00E-10,	0.05],
    [56167.0,	9,	1.78,	0.431,	0.048,	1.00E-10,	0.05],

#12A-479
#56167.0	9	1.3835	0	0.075	1.00E-10	0.05
#56167.0	9	1.8035	0	0.029	1.00E-10	0.05
    [56167.0,	9,	4.608,	0.347,	0.028,	1.00E-10,	0.05],
    [56167.0,	9,	7.458,	0.292,	0.016,	1.00E-10,	0.05],
    [56167.0,	9,	8.5,	0.289,	0.018,	1.00E-10,	0.05],
    [56167.0,	9,	11.4,	0.368,	0.031,	1.00E-10,	0.05],

#12A-483
#56167.0	9	1.2555	0	0.086	1.00E-10	0.05
#56167.0	9	1.7395	0.346	0.093	1.00E-10	0.05
#56167.0	9	4.5490	0.282	0.036	1.00E-10	0.05
#56167.0	9	7.399	0.286	0.024	1.00E-10	0.05

    [56174.2,	10,	13.3,	0.188,	0.019,	1.00E-10,	0.05],
    [56174.2,	10,	17.45,	0.110,	0.029,	1.00E-10,	0.05],
    [56174.2,	10,	27.5,	0.106,	0.027,	1.00E-10,	0.05],
    [56174.2,	10,	36.5,	0.365,	0.131,	1.00E-10,	0.05],
    [56177.9,	11,	1.33,	0.225,	0.044,	1.00E-10,	0.05],
    [56177.9,	11,	1.77,	0.201,	0.042,	1.00E-10,	0.05],
    [56231.0,	12,	13.3,	0.035,	0.021,	1.00E-10,	0.05],
    [56231.0,	12,	17.4,	0.043,	0.027,	1.00E-10,	0.05],
    [56231.0,	12,	27.5,	0.060,	0.044,	1.00E-10,	0.05],
    [56231.0,	12,	36.5,	0.044,	0.052,	1.00E-10,	0.05],
    [56270.8,	13,	1.2555,	0,	0.083,	1.00E-10,	0.05],
    [56270.8,	13,	1.7395,	0,	0.084,	1.00E-10,	0.05],
    [56270.8,	13,	4.549,	0,	0.021,	1.00E-10,	0.05],
    [56270.8,	13,	7.399,	0,	0.016,	1.00E-10,	0.05],
    [56270.8,	13,	8.519,	0,	0.025,	1.00E-10,	0.05],
    [56270.8,	13,	11.399,	0,	0.030,	1.00E-10,	0.05],
    [56284.6,	14,	13.299,	0,	0.029,	1.00E-10,	0.05],
    [56284.6,	14,	17.449,	0,	0.035,	1.00E-10,	0.05],
    [56284.6,	14,	13.30,	0.047,	0.022,	1.00E-10,	0.05],
    [56284.6,	14,	17.45,	0.049,	0.026,	1.00E-10,	0.05],
    [56284.6,	14,	27.50,	0.036,	0.050,	1.00E-10,	0.05],
    [56284.6,	14,	36.50,	0.020,	0.068,	1.00E-10,	0.05],
    [56297.7,	15,	1.26,	0.0504,	0.102,	1.00E-10,	0.05],
    [56297.7,	15,	1.74,	-0.00249,	0.068,	1.00E-10,	0.05],
    [56297.7,	15,	4.55,	0.0328,	0.033,	1.00E-10,	0.05],
    [56297.7,	15,	7.399,	0.0288,	0.023,	1.00E-10,	0.05],
    [56297.7,	15,	8.52,	0.0286,	0.018,	1.00E-10,	0.05],
    [56297.7,	15,	11.4,	0.0413,	0.023,	1.00E-10,	0.05],
    [56347.7,	16,	1.26,	0.346,	0.503,	1.00E-10,	0.05],
    [56347.7,	16,	1.74,	-0.0272,	0.368,	1.00E-10,	0.05],
    [56347.7,	16,	4.55,	-0.232,	0.114,	1.00E-10,	0.05],
    [56347.7,	16,	7.399,	-0.00948,	0.160,	1.00E-10,	0.05],
    [56347.7,	16,	8.52,	0.465,	0.201,	1.00E-10,	0.05],
    [56347.7,	16,	11.4,	-0.0358,	0.301,	1.00E-10,	0.05],
    [56358.6,	17,	13.22,	0.025,	0.027,	1.00E-10,	0.05],
    [56358.6,	17,	17.45,	0.009,	0.025,	1.00E-10,	0.05],
    [56358.6,	17,	27.50,	0.046,	0.049,	1.00E-10,	0.05],
    [56358.6,	17,	36.50,	0.120,	0.062,	1.00E-10,	0.05],
    [56369.6,	17,	13.3,	-0.0319,	0.023,	1.00E-10,	0.05],
    [56369.6,	17,	17.4,	0.0240,	0.029,	1.00E-10,	0.05],
    [56369.6,	17,	27.5,	0.113,	0.065,	1.00E-10,	0.05],
    [56369.6,	17,	36.5,	0.0109,	0.083,	1.00E-10,	0.05],
    [56441.4,	18,	1.26,	0.0811,	0.396,	1.00E-10,	0.05],
    [56441.4,	18,	1.74,	-0.202,	0.326,	1.00E-10,	0.05],
    [56441.4,	18,	4.55,	0.0437,	0.033,	1.00E-10,	0.05],
    [56441.4,	18,	7.399,	-0.0098,	0.021,	1.00E-10,	0.05],
    [56441.4,	18,	8.52,	-0.00263,	0.018,	1.00E-10,	0.05],
    [56441.4,	18,	11.4,	-0.0266,	0.019,	1.00E-10,	0.05],
    [56446.2,	18,	13.3,	-0.0169,	0.024,	1.00E-10,	0.05],
    [56446.2,	18,	17.4,	0.0260,	0.029,	1.00E-10,	0.05],
    [56446.2,	18,	27.5,	0.112,	0.077,	1.00E-10,	0.05],
    [56446.2,	18,	36.5,	-0.0663,	0.095,	1.00E-10,	0.05],
    [56526.7,	19,	1.26,	-0.571,	0.276,	1.00E-10,	0.05],
    [56526.7,	19,	1.74,	-0.348,	0.169,	1.00E-10,	0.05],
    [56526.7,	19,	4.55,	-0.00306,	0.028,	1.00E-10,	0.05],
    [56526.7,	19,	7.40,	-0.0045,	0.019,	1.00E-10,	0.05],
    [56526.7,	19,	8.52,	0.00449,	0.022,	1.00E-10,	0.05],
    [56526.7,	19,	11.4,	-0.0051,	0.024,	1.00E-10,	0.05],
    [56530.7,	19,	13.3,	-0.00734,	0.031,	1.00E-10,	0.05],
    [56530.7,	19,	17.4,	-0.00912,	0.053,	1.00E-10,	0.05],
    [56530.7,	19,	27.5,	0.0271,	0.011,	1.00E-10,	0.05],
    [56530.7,	19,	36.5,	0.110,	0.110,	1.00E-10,	0.05],
       )
df =  pd.DataFrame(data, columns = ["MJD",	"Epoch",	"Freq",	"Flux",	"error","RM", "systematics"])

# %%
#printing out the dataframe to check if everything looks okay
df
# Out:
#          MJD Epoch   Freq      Flux  error            RM  systematics
# 0    56040.4     1   33.0   0.03200  0.025  1.000000e-10         0.05
# 1    56069.0     A  225.3  13.80000  2.000  1.000000e-10         0.05
# 2    56084.4     2    5.0   1.08900  0.028  1.000000e-10         0.05
# 3    56084.4     2    6.8   1.38100  0.025  1.000000e-10         0.05
# 4    56092.2     3   13.3   3.52300  0.042  1.000000e-10         0.05
# ..       ...   ...    ...       ...    ...           ...          ...
# 101  56526.7    19   11.4  -0.00510  0.024  1.000000e-10         0.05
# 102  56530.7    19   13.3  -0.00734  0.031  1.000000e-10         0.05
# 103  56530.7    19   17.4  -0.00912  0.053  1.000000e-10         0.05
# 104  56530.7    19   27.5   0.02710  0.011  1.000000e-10         0.05
# 105  56530.7    19   36.5   0.11000  0.110  1.000000e-10         0.05
#
# [106 rows x 7 columns]

# %%
#creating the days from the first reading
#defining a list of MJD
MJD = df["MJD"]
#making days since with the MJD- the first MJD that was taken.
days = MJD-MJD[0]

# %%
#defining the flux and flux errors to it can be plotted

flux = df["Flux"]
flux_err = df["error"]

# %%
fig,ax = plt.subplots()

ax.plot(days,flux, '.')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel("Days")
ax.set_ylabel("Flux Density (mJy)")
ax.set_title("")
plt.show();

# %%
#printing out all the different frequencies from the data
df['Freq'].unique()
# Out:
# array([ 33.    , 225.3   ,   5.    ,   6.8   ,  13.3   ,  16.    ,
#         28.2   ,  36.5   ,   2.5   ,   3.5   ,   8.5   ,  11.4   ,
#        225.5   ,   1.35  ,   1.84  ,   4.74  ,   7.59  ,  17.5   ,
#         27.5   ,   1.2555,   1.7715,   8.53  ,  11.38  ,  17.45  ,
#          1.25  ,   1.8   ,   4.549 ,   7.399 ,   8.51  ,  11.34  ,
#          1.36  ,   1.78  ,   4.608 ,   7.458 ,   1.33  ,   1.77  ,
#         17.4   ,   1.7395,   8.519 ,  11.399 ,  13.299 ,  17.449 ,
#          1.26  ,   1.74  ,   4.55  ,   8.52  ,  13.22  ,   7.4   ])

# %%
#[56069.0,	'A',	225.3,	13.80,	2.000,	1.00E-10,	0.05],
#[56117.9,	'B',	225.5,	0.000,	0.068,	1.00E-10,	0.05],
    
#12A-479
#56167.0	9	1.3835	0	0.075	1.00E-10	0.05
#56167.0	9	1.8035	0	0.029	1.00E-10	0.05
    
#12A-483
#56167.0	9	1.2555	0	0.086	1.00E-10	0.05
#56167.0	9	1.7395	0.346	0.093	1.00E-10	0.05
#56167.0	9	4.5490	0.282	0.036	1.00E-10	0.05
#56167.0	9	7.399	0.286	0.024	1.00E-10	0.05

    
    
f1_35 = ([56526.7,	19,	1.26,	-0.571,	0.276,	1.00E-10,	0.05],
          [56441.4,	18,	1.26,	0.0811,	0.396,	1.00E-10,	0.05],
          [56347.7,	16,	1.26,	0.346,	0.503,	1.00E-10,	0.05],
         [56297.7,	15,	1.26,	0.0504,	0.102,	1.00E-10,	0.05],
         [56270.8,	13,	1.2555,	0,	0.083,	1.00E-10,	0.05],
         [56177.9,	11,	1.33,	0.225,	0.044,	1.00E-10,	0.05],
         [56167.0,	9,	1.36,	0.244,	0.049,	1.00E-10,	0.05],
          [56151.3,	8,	1.25,	0,	0.091,	1.00E-10,	0.05],
         [56148.0,	7,	1.2555,	0.340,	0.071,	1.00E-10,	0.05],
         [56119.1,	5,	1.35,	1.68,	0.120,	1.00E-10,	0.05],
        )

f1_78 = ([56526.7,	19,	1.74,	-0.348,	0.169,	1.00E-10,	0.05],
         [56441.4,	18,	1.74,	-0.202,	0.326,	1.00E-10,	0.05],
         [56347.7,	16,	1.74,	-0.0272,	0.368,	1.00E-10,	0.05],
         [56297.7,	15,	1.74,	-0.00249,	0.068,	1.00E-10,	0.05],
         [56270.8,	13,	1.7395,	0,	0.084,	1.00E-10,	0.05],
         [56177.9,	11,	1.77,	0.201,	0.042,	1.00E-10,	0.05],
         [56167.0,	9,	1.78,	0.431,	0.048,	1.00E-10,	0.05],
         [56151.3,	8,	1.80,	0.497,	0.088,	1.00E-10,	0.05],
         [56148.0,	7,	1.7715,	0.560,	0.072,	1.00E-10,	0.05],
         [56119.1,	5,	1.84,	1.391,	0.066,	1.00E-10,	0.05],
        )

f3 = ([56100.3,	4,	2.5,	3.094,	0.037,	1.00E-10,	0.05],
        [56100.3,	4,	3.5,	3.201,	0.030,	1.00E-10,	0.05],)

f4_74 = ( [56526.7,	19,	4.55,	-0.00306,	0.028,	1.00E-10,	0.05],
         [56347.7,	16,	4.55,	-0.232,	0.114,	1.00E-10,	0.05],
         [56297.7,	15,	4.55,	0.0328,	0.033,	1.00E-10,	0.05],
         [56270.8,	13,	4.549,	0,	0.021,	1.00E-10,	0.05],
         [56167.0,	9,	4.608,	0.347,	0.028,	1.00E-10,	0.05],
         [56151.3,	8,	4.549,	0.502,	0.034,	1.00E-10,	0.05],
         [56148.0,	7,	4.74,	0.521,	0.033,	1.00E-10,	0.05],
         [56119.1,	5,	4.74,	1.907,	0.027,	1.00E-10,	0.05],
         [56100.3,	4,	5,	3.423,	0.023,	1.00E-10,	0.05],
         [56084.4,	2,	5,	1.089,	0.028,	1.00E-10,	0.05],
        )

f7_46 = ([56526.7,	19,	7.40,	-0.0045,	0.019,	1.00E-10,	0.05],
          [56441.4,	18,	7.399,	-0.0098,	0.021,	1.00E-10,	0.05],
         [56441.4,	18,	4.55,	0.0437,	0.033,	1.00E-10,	0.05],
          [56347.7,	16,	7.399,	-0.00948,	0.160,	1.00E-10,	0.05],
         [56297.7,	15,	7.399,	0.0288,	0.023,	1.00E-10,	0.05],
         [56270.8,	13,	7.399,	0,	0.016,	1.00E-10,	0.05],
         [56167.0,	9,	7.458,	0.292,	0.016,	1.00E-10,	0.05],
         [56151.3,	8,	7.399,	0.469,	0.025,	1.00E-10,	0.05],
        [56148.0,	7,	7.59,	0.528,	0.025,	1.00E-10,	0.05],
         [56119.1,	5,	7.59,	1.921,	0.023,	1.00E-10,	0.05],
         [56100.3,	4,	6.8,	3.629,	0.025,	1.00E-10,	0.05],
         [56084.4,	2,	6.8,	1.381,	0.025,	1.00E-10,	0.05],
        )

f8_51 = ([56526.7,	19,	8.52,	0.00449,	0.022,	1.00E-10,	0.05],
         [56441.4,	18,	8.52,	-0.00263,	0.018,	1.00E-10,	0.05],
         [56347.7,	16,	8.52,	0.465,	0.201,	1.00E-10,	0.05],
         [56297.7,	15,	8.52,	0.0286,	0.018,	1.00E-10,	0.05],
         [56270.8,	13,	8.519,	0,	0.025,	1.00E-10,	0.05],
         [56167.0,	9,	8.5,	0.289,	0.018,	1.00E-10,	0.05],
         [56151.3,	8,	8.51,	0.443,	0.021,	1.00E-10,	0.05],
         [56148.0,	7,	8.53,	0.556,	0.031,	1.00E-10,	0.05],
         [56100.3,	4,	8.5,	3.683,	0.052,	1.00E-10,	0.05],
        )

f11_38 = ( [56526.7,	19,	11.4,	-0.0051,	0.024,	1.00E-10,	0.05],
          [56441.4,	18,	11.4,	-0.0266,	0.019,	1.00E-10,	0.05],
          [56347.7,	16,	11.4,	-0.0358,	0.301,	1.00E-10,	0.05],
           [56297.7,	15,	11.4,	0.0413,	0.023,	1.00E-10,	0.05],
          [56270.8,	13,	11.399,	0,	0.030,	1.00E-10,	0.05],
          [56167.0,	9,	11.4,	0.368,	0.031,	1.00E-10,	0.05],
          [56151.3,	8,	11.34,	0.418,	0.035,	1.00E-10,	0.05],
          [56148.0,	7,	11.38,	0.571,	0.060,	1.00E-10,	0.05],
          [56100.3,	4,	11.4,	3.779,	0.071,	1.00E-10,	0.05],
         )

f13_3 = ([56530.7,	19,	13.3,	-0.00734,	0.031,	1.00E-10,	0.05],
         [56446.2,	18,	13.3,	-0.0169,	0.024,	1.00E-10,	0.05],
         [56369.6,	17,	13.3,	-0.0319,	0.023,	1.00E-10,	0.05],
         [56358.6,	17,	13.22,	0.025,	0.027,	1.00E-10,	0.05],
         [56284.6,	14,	13.30,	0.047,	0.022,	1.00E-10,	0.05],
         [56284.6,	14,	13.299,	0,	0.029,	1.00E-10,	0.05],
         [56231.0,	12,	13.3,	0.035,	0.021,	1.00E-10,	0.05],
         [56174.2,	10,	13.3,	0.188,	0.019,	1.00E-10,	0.05],
         [56150.2,	8,	13.3,	0.495,	0.042,	1.00E-10,	0.05],
         [56092.2,	3,	13.3,	3.523,	0.042,	1.00E-10,	0.05],
        )

f17_45 = ([56530.7,	19,	17.4,	-0.00912,	0.053,	1.00E-10,	0.05],
          [56446.2,	18,	17.4,	0.0260,	0.029,	1.00E-10,	0.05],
          [56369.6,	17,	17.4,	0.0240,	0.029,	1.00E-10,	0.05],
          [56358.6,	17,	17.45,	0.009,	0.025,	1.00E-10,	0.05],
          [56284.6,	14,	17.45,	0.049,	0.026,	1.00E-10,	0.05],
          [56284.6,	14,	17.449,	0,	0.035,	1.00E-10,	0.05],
          [56231.0,	12,	17.4,	0.043,	0.027,	1.00E-10,	0.05],
          [56174.2,	10,	17.45,	0.110,	0.029,	1.00E-10,	0.05],
          [56150.2,	8,	17.45,	0.38,	0.049,	1.00E-10,	0.05],
          [56128.3,	6,	17.5,	1.374,	0.091,	1.00E-10,	0.05],
          [56092.2,	3,	16,	3.98,	0.049,	1.00E-10,	0.05],
         )

f28_2 = ([56530.7,	19,	27.5,	0.0271,	0.011,	1.00E-10,	0.05],
         [56446.2,	18,	27.5,	0.112,	0.077,	1.00E-10,	0.05],
         [56369.6,	17,	27.5,	0.113,	0.065,	1.00E-10,	0.05],
         [56358.6,	17,	27.50,	0.046,	0.049,	1.00E-10,	0.05],
         [56284.6,	14,	27.50,	0.036,	0.050,	1.00E-10,	0.05],
         [56231.0,	12,	27.5,	0.060,	0.044,	1.00E-10,	0.05],
         [56174.2,	10,	27.5,	0.106,	0.027,	1.00E-10,	0.05],
         [56150.2,	8,	27.5,	0.469,	0.078,	1.00E-10,	0.05],
         [56128.3,	6,	27.5,	1.438,	0.143,	1.00E-10,	0.05],
         [56092.2,	3,	28.2,	5.727,	0.098,	1.00E-10,	0.05],
        )

f36_5 = ([56530.7,	19,	36.5,	0.110,	0.110,	1.00E-10,	0.05],
         [56446.2,	18,	36.5,	-0.0663,	0.095,	1.00E-10,	0.05],
         [56369.6,	17,	36.5,	0.0109,	0.083,	1.00E-10,	0.05],
         [56358.6,	17,	36.50,	0.120,	0.062,	1.00E-10,	0.05],
         [56284.6,	14,	36.50,	0.020,	0.068,	1.00E-10,	0.05],
         [56231.0,	12,	36.5,	0.044,	0.052,	1.00E-10,	0.05],
         [56174.2,	10,	36.5,	0.365,	0.131,	1.00E-10,	0.05],
         [56150.2,	8,	36.5,	0.39,	0.086,	1.00E-10,	0.05],
         [56128.3,	6,	36.5,	1.136,	0.194,	1.00E-10,	0.05],
         [56092.2,	3,	36.5,	5.961,	0.139,	1.00E-10,	0.05],
         [56040.4,	1,	33,	0.032,	0.025,	1.00E-10,	0.05],
        )

# %%
df1_35 =  pd.DataFrame(f1_35, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df1_78 =  pd.DataFrame(f1_78, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df3 =  pd.DataFrame(f3, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df4_74 =  pd.DataFrame(f4_74, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df7_46 =  pd.DataFrame(f7_46, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df8_51 =  pd.DataFrame(f8_51, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df11_38 =  pd.DataFrame(f11_38, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df13_3 =  pd.DataFrame(f13_3, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df17_45 =  pd.DataFrame(f17_45, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df28_2 =  pd.DataFrame(f28_2, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

df36_5 =  pd.DataFrame(f36_5, columns = ["MJD",	"Epoch", "Freq", "Flux", "error","RM", "systematics"])

# %%
MJD1_35 = df1_35["MJD"]
days1_35 = MJD1_35-56038.0
flux1_35 = df1_35["Flux"]
flux_err1_35 = np.sqrt((df1_35["error"])**2 + (df1_35['Flux']*0.05)**2)

MJD1_78 = df1_78["MJD"]
days1_78 = MJD1_78-56038.0
flux1_78 = df1_78["Flux"]
flux_err1_78 = np.sqrt((df1_78["error"])**2 + (df1_78['Flux']*0.05)**2)

MJD3 = df3["MJD"]
days3 = MJD3-56038.0
flux3 = df3["Flux"]
flux_err3 = np.sqrt((df3["error"])**2 + (df3['Flux']*0.05)**2)

MJD4_74 = df4_74["MJD"]
days4_74 = MJD4_74 -56038.0
flux4_74  = df4_74["Flux"]
flux_err4_74  = np.sqrt((df4_74["error"])**2 + (df4_74['Flux']*0.05)**2)

MJD7_46 = df7_46["MJD"]
days7_46 = MJD7_46-56038.0
flux7_46 = df7_46["Flux"]
flux_err7_46 = np.sqrt((df7_46["error"])**2 + (df7_46['Flux']*0.05)**2)

MJD8_51 = df8_51["MJD"]
days8_51 = MJD8_51 -56038.0
flux8_51  = df8_51["Flux"]
flux_err8_51  = np.sqrt((df8_51["error"])**2 + (df8_51['Flux']*0.05)**2)

MJD11_38 = df11_38["MJD"]
days11_38 = MJD11_38-56038.0
flux11_38 = df11_38["Flux"]
flux_err11_38 = np.sqrt((df11_38["error"])**2 + (df11_38['Flux']*0.1)**2)

MJD13_3 = df13_3["MJD"]
days13_3 = MJD13_3-56038.0
flux13_3 = df13_3["Flux"]
flux_err13_3 = np.sqrt((df13_3["error"])**2 + (df13_3['Flux']*0.1)**2)

MJD17_45 = df17_45["MJD"]
days17_45 = MJD17_45-56038.0
flux17_45 = df17_45["Flux"]
flux_err17_45 = np.sqrt((df17_45["error"])**2 + (df17_45['Flux']*0.1)**2)

MJD28_2 = df28_2["MJD"]
days28_2 = MJD28_2-56038.0
flux28_2 = df28_2["Flux"]
flux_err28_2 = np.sqrt((df28_2["error"])**2 + (df28_2['Flux']*0.1)**2)

MJD36_5 = df36_5["MJD"]
days36_5 = MJD36_5-56038.0
flux36_5 = df36_5["Flux"]
flux_err36_5 = np.sqrt((df36_5["error"])**2 + (df36_5['Flux']*0.1)**2)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,10)

# Store which labels have already been used
used_labels = set()

def plot(days, fluxes, errors, color, label_name):
    for day, flux, err in zip(days, fluxes, errors):
        if flux < 3 * err:
            fmt = 'x'  # square for non-detection
            label = None  # no label for non-detections

            ax.errorbar(day, (flux+3*err), fmt=fmt, color=color, label=label)
            
        else:
            fmt = '^'  # triangle for detection
            label = label_name if label_name not in used_labels else None
        
            ax.errorbar(day, flux, yerr=err, fmt=fmt, color=color, label=label)
        
        if label:
            used_labels.add(label)

# Plot each band
plot(days1_35, flux1_35, flux_err1_35, 'orange', '1.35 GHz')
#ax.plot(days1_35, flux1_35, color='orange', linestyle = '--', alpha=.50)

plot(days1_78, flux1_78, flux_err1_78, 'red', '1.78 GHz')
#ax.plot(days1_78, flux1_78, color='red', linestyle = '--', alpha=.50)

plot(days3, flux3, flux_err3, 'yellow', '3 GHz')
#ax.plot(days3, flux3, color='yellow', linestyle = '--', alpha=.50)

plot(days4_74, flux4_74, flux_err4_74, 'green', '4.74 GHz')
#ax.plot(days4_74, flux4_74, color='green', linestyle = '--', alpha=.50)

plot(days7_46, flux7_46, flux_err7_46, 'blue', '7.46 GHz')
#ax.plot(days7_46, flux7_46, color='blue', linestyle = '--', alpha=.50)

plot(days8_51, flux8_51, flux_err8_51, 'purple', '8.51 GHz')
#ax.plot(days8_51, flux8_51, color='purple', linestyle = '--', alpha=.50)

plot(days11_38, flux11_38, flux_err11_38, 'hotpink', '11.38 GHz')
#ax.plot(days11_38, flux11_38, color='hotpink', linestyle = '--', alpha=.50)

plot(days13_3, flux13_3, flux_err13_3, 'skyblue', '13.3 GHz')
#ax.plot(days13_3, flux13_3, color='skyblue', linestyle = '--', alpha=.50)

plot(days17_45, flux17_45, flux_err17_45, 'black', '17.45 GHz')
#ax.plot(days17_45, flux17_45, color='black', linestyle = '--', alpha=.50)

plot(days28_2, flux28_2, flux_err28_2, 'grey', '28.2 GHz')
#ax.plot(days28_2, flux28_2, color='grey', linestyle = '--', alpha=.50)

plot(days36_5, flux36_5, flux_err36_5, 'lime', '36.5 GHz')
#ax.plot(days36_5, flux36_5, color='lime', linestyle = '--', alpha=.50)

# Final plot formatting
ax.set_xscale('log')
ax.set_xticks([1,10,20,50,100,500,1000], labels = ['1','10','20','50','100','500','1000'], fontsize = 20)
ax.set_yscale('log')
ax.set_yticks([.01,.10, 1.00, 10], labels = [r'$10^{-2}$',r'$10^{-1}$',r'$10^{0}$',r'$10^{1}$'], fontsize = 20)

ax.set_xlabel("Time since eruption (days)", fontsize = 25)
ax.set_ylabel("Flux Density (mJy)", fontsize = 25)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

ax.set_title("")
plt.legend(fontsize = 15)
plt.savefig("V5589_lc.png")
plt.show()

# %%
np.max(flux4_74)
# Out:
# 3.423

# %%
df4_74
# Out:
#        MJD  Epoch   Freq     Flux  error            RM  systematics
# 0  56526.7     19  4.550 -0.00306  0.028  1.000000e-10         0.05
# 1  56347.7     16  4.550 -0.23200  0.114  1.000000e-10         0.05
# 2  56297.7     15  4.550  0.03280  0.033  1.000000e-10         0.05
# 3  56270.8     13  4.549  0.00000  0.021  1.000000e-10         0.05
# 4  56167.0      9  4.608  0.34700  0.028  1.000000e-10         0.05
# 5  56151.3      8  4.549  0.50200  0.034  1.000000e-10         0.05
# 6  56148.0      7  4.740  0.52100  0.033  1.000000e-10         0.05
# 7  56119.1      5  4.740  1.90700  0.027  1.000000e-10         0.05
# 8  56100.3      4  5.000  3.42300  0.023  1.000000e-10         0.05
# 9  56084.4      2  5.000  1.08900  0.028  1.000000e-10         0.05

# %%
print(flux_err4_74)
# Out:
# 0    0.028000
# 1    0.114589
# 2    0.033041
# 3    0.021000
# 4    0.032940
# 5    0.042261
# 6    0.042043
# 7    0.099099
# 8    0.172689
# 9    0.061227
# dtype: float64
