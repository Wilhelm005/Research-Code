# %% [markdown]
# ### RS Oph Lightcurve

# %% [markdown]
# This recuurent nova exploded on August 8th 2021, giving it a start MJD of 59434

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = (

[59439.04,	2.6,	4.71,	0.14],
[59439.04,	3.4,	5.328,	0.093],
[59439.04,	5.1,	10.012,	0.058],
[59439.04,	7,	15.607,	0.057],
[59439.04,	13.7,	24.088,	0.055],
[59439.04,	16.5,	25.573,	0.059],
[59439.04,	31.1,	35.973,	0.14],
[59439.04,	34.9,	38.318,	0.16],
    
[59440.08,	2.6,	18.206,	0.11],
[59440.08,	3.4,	23.366,	0.1],
[59440.08,	5.1,	33.454,	0.059],
[59440.08,	7,	39.663,	0.055],
[59440.08,	13.7,	40.939,	0.062],
[59440.08,	16.5,	41.636,	0.063],
[59440.08,	31.1,	44.762,	0.14],
[59440.08,	34.9,	46.68,	0.15],
			
[59443.99,	2.6,	68.929,	0.37],
[59443.99,	3.4,	73.933,	0.11],
[59443.99,	5.1,	67.597,	0.087],
[59443.99,	7,	58.65,	0.068],
[59443.99,	13.7,	47.847,	0.066],
[59443.99,	16.5,	46.81,	0.063],
[59443.99,	31.1,	48.13,	0.14],
[59443.99,	34.9,	49.924,	0.16],
			
[59446.01,	2.6,	88.695,	0.21],
[59446.01,	3.4,	78.259,	0.11],
[59446.01,	5.1,	60.457,	0.065],
[59446.01,	7,	50.875,	0.057],
[59446.01,	13.7,	43.692,	0.054],
[59446.01,	16.5,	42.418,	0.055],
[59446.01,	31.1,	46.076,	0.12],
[59446.01,	34.9,	48.49,	0.14],
			
[59446.99,	2.6,	84.443,	0.34],
[59446.99,	3.4,	82.034,	0.13],
[59446.99,	5.1,	63.977,	0.083],
[59446.99,	7,	51.883,	0.062],
[59446.99,	13.7,	41.854,	0.056],
[59446.99,	16.5,	40.83,	0.056],
[59446.99,	31.1,	43.653,	0.12],
[59446.99,	34.9,	45.965,	0.13],
			
[59451.01,	2.6,	92.534,	0.24],
[59451.01,	3.4,	83.135,	0.19],
[59451.01,	5.1,	61.832,	0.074],
[59451.01,	7,	52.291,	0.059],
[59451.01,	13.7,	44.133,	0.054],
[59451.01,	16.5,	42.894,	0.061],
[59451.01,	31.1,	47.067,	0.12],
[59451.01,	34.9,	48.103,	0.13],
			
[59461.01,	2.6,	94.467,	0.22],
[59461.01,	3.4,	85.812,	0.17],
[59461.01,	5.1,	65.115,	0.074],
[59461.01,	7,	57.617,	0.064],
[59461.01,	13.7,	54.102,	0.06],
[59461.01,	16.5,	54.536,	0.065],
[59461.01,	31.1,	70.776,	0.15],
[59461.01,	34.9,	77.042,	0.16],
			
[59463.02,	2.6,	88.638,	0.2],
[59463.02,	3.4,	80.579,	0.17],
[59463.02,	5.1,	60.766,	0.069],
[59463.02,	7,	56.003,	0.062],
[59463.02,	13.7,	51.457,	0.068],
[59463.02,	16.5,	54.259,	0.074],
[59463.02,	31.1,	75.224,	0.17],
[59463.02,	34.9,	82.831,	0.18],
			
[59466.04,	2.6,	58.862,	0.17],
[59466.04,	3.4,	58.434,	0.13],
[59466.04,	5.1,	54.499,	0.067],
[59466.04,	7,	54.364,	0.068],
			
[59467.99,	2.6,	81.96,	0.23],
[59467.99,	3.4,	75.044,	0.15],
[59467.99,	5.1,	60.253,	0.061],
[59467.99,	7,	55.839,	0.055],
[59467.99,	13.7,	55.46,	0.057],
[59467.99,	16.5,	57.657,	0.059],
[59467.99,	31.1,	85.302,	0.13],
[59467.99,	34.9,	94.908,	0.14],
			
[59470.01,	2.6,	74.216,	0.24],
[59470.01,	3.4,	67.992,	0.14],
[59470.01,	5.1,	56.608,	0.058],
[59470.01,	7,	54.465,	0.056],
[59470.01,	13.7,	56.891,	0.061],
[59470.01,	16.5,	60.279,	0.063],
[59470.01,	31.1,	92.384,	0.14],
[59470.01,	34.9,	103.52,	0.15],
			
[59487.96,	2.6,	65.358,	0.18],
[59487.96,	3.4,	60.804,	0.13],
[59487.96,	5.1,	49.879,	0.061],
[59487.96,	7,	46.096,	0.058],
[59487.96,	13.7,	51.336,	0.074],
[59487.96,	16.5,	55.64,	0.083],
[59487.96,	31.1,	92.061,	0.14],
[59487.96,	34.9,	103.31,	0.16],
			
[59510.94,	2.6,	27.414,	0.13],
[59510.94,	3.4,	30.985,	0.086],
[59510.94,	5.1,	36.454,	0.052],
[59510.94,	7,	38.595,	0.05],		
			
[59511.92,	2.6,	36.139,	0.13],
[59511.92,	3.4,	36.456,	0.11],
[59511.92,	5.1,	36.228,	0.053],
[59511.92,	7,	38.215,	0.053],
[59511.92,	13.7,	45.791,	0.053],
[59511.92,	16.5,	50.332,	0.052],
[59511.92,	31.1,	79.492,	0.12],
[59511.92,	34.9,	88.439,	0.13],
			
[59523.82,	2.6,	32.964,	0.13],
[59523.82,	3.4,	32.519,	0.092],
[59523.82,	5.1,	31.849,	0.053],
[59523.82,	7,	32.08,	0.049],
[59523.82,	13.7,	38.122,	0.049],
[59523.82,	16.5,	41.511,	0.05],
[59523.82,	31.1,	66.05,	0.11],
[59523.82,	34.9,	72.993,	0.12],
			
[59574.76,	2.6,	17.902,	0.2],
[59574.76,	3.4,	17.739,	0.18],
[59574.76,	5.1,	17.481,	0.064],
[59574.76,	7,	19.527,	0.06],
[59574.76,	13.7,	25.248,	0.067],
[59574.76,	16.5,	26.955,	0.061],
[59574.76,	31.1,	42.236,	0.34],
[59574.76,	34.9,	47.137,	0.35],
			
[59588.66,	2.6,	24.59,	0.16],
[59588.66,	3.4,	22.702,	0.14],
[59588.66,	5.1,	18.554,	0.06],
[59588.66,	7,	18.619,	0.051],
[59588.66,	13.7,	21.6,	0.051],
[59588.66,	16.5,	22.164,	0.053],
[59588.66,	31.1,	26.488,	0.1],
[59588.66,	34.9,	27.475,	0.11],
			
[59590.61,	2.6,	24.388,	0.21],
[59590.61,	3.4,	22.617,	0.11],
[59590.61,	5.1,	19.794,	0.062],
[59590.61,	7,	19.169,	0.052],
[59590.61,	13.7,	21.908,	0.051],
[59590.61,	16.5,	22.994,	0.047],
[59590.61,	31.1,	28.341,	0.11],
[59590.61,	34.9,	29.746,	0.12],
			
[59595.61,	2.6,	23.163,	0.16],
[59595.61,	3.4,	20.742,	0.13],
[59595.61,	5.1,	17.488,	0.056],
[59595.61,	7,	17.871,	0.057],
[59595.61,	13.7,	20.702,	0.05],
[59595.61,	16.5,	21.855,	0.048],
[59595.61,	31.1,	27.116,	0.11],
[59595.61,	34.9,	28.356,	0.11],
			
[60034.47,	2.6,	3.295,	0.17],
[60034.47,	3.4,	3.342,	0.12],
[60034.47,	5.1,	2.765,	0.052],
[60034.47,	7,	2.347,	0.049],
[60034.47,	13.7,	1.672,	0.05],
[60034.47,	16.5,	1.526,	0.051],
[60034.47,	31.1,	0.87,	0.1],
[60034.47,	34.9,	0.862,	0.11],
			
[60049.34,	2.6,	2.777,	0.17],
[60049.34,	3.4,	2.82,	0.078],
[60049.34,	5.1,	2.684,	0.053],
[60049.34,	7,	2.373,	0.046],
[60049.34,	13.7,	1.67,	0.048],
[60049.34,	16.5,	1.541,	0.048],
[60049.34,	31.1,	1.077,	0.11],
[60049.34,	34.9,	1.113,	0.12],
			
[60131.12,	2.6,	1.808,	0.017],
[60131.12,	3.4,	1.999,	0.014],
[60131.12,	5.1,	2.163,	0.016],
[60131.12,	7,	2.336,	0.018],
[60131.12,	13.7,	1.933,	0.02],
[60131.12,	16.5,	1.923,	0.022],
[60131.12,	31.1,	1.336,	0.066],
[60131.12,	34.9,	1.306,	0.079],
)

df =  pd.DataFrame(data, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

# %%
f2_6 = (
    [59439.04,	2.6,	4.71,	0.14],
    [59440.08,	2.6,	18.206,	0.11],
    [59443.99,	2.6,	68.929,	0.37],
    [59446.01,	2.6,	88.695,	0.21],
    [59446.99,	2.6,	84.443,	0.34],
    [59451.01,	2.6,	92.534,	0.24],	
    [59461.01,	2.6,	94.467,	0.22],
    [59463.02,	2.6,	88.638,	0.2],		
    [59466.04,	2.6,	58.862,	0.17],			
    [59467.99,	2.6,	81.96,	0.23],
    [59470.01,	2.6,	74.216,	0.24],
    [59487.96,	2.6,	65.358,	0.18],
    [59510.94,	2.6,	27.414,	0.13],
    [59511.92,	2.6,	36.139,	0.13],
    [59523.82,	2.6,	32.964,	0.13],		
    [59574.76,	2.6,	17.902,	0.2],
    [59588.66,	2.6,	24.59,	0.16],
    [59590.61,	2.6,	24.388,	0.21],
    [59595.61,	2.6,	23.163,	0.16],
    [60034.47,	2.6,	3.295,	0.17],
    [60049.34,	2.6,	2.777,	0.17],
    [60131.12,	2.6,	1.808,	0.017],
)

f3_4 = (
    [59439.04,	3.4,	5.328,	0.093],
    [59440.08,	3.4,	23.366,	0.1],
    [59443.99,	3.4,	73.933,	0.11],
    [59446.01,	3.4,	78.259,	0.11],
    [59446.99,	3.4,	82.034,	0.13],
    [59451.01,	3.4,	83.135,	0.19],
    [59461.01,	3.4,	85.812,	0.17],
    [59463.02,	3.4,	80.579,	0.17],
    [59466.04,	3.4,	58.434,	0.13],
    [59467.99,	3.4,	75.044,	0.15],
    [59470.01,	3.4,	67.992,	0.14],
    [59487.96,	3.4,	60.804,	0.13],
    [59510.94,	3.4,	30.985,	0.086],
    [59511.92,	3.4,	36.456,	0.11],
    [59523.82,	3.4,	32.519,	0.092],
    [59574.76,	3.4,	17.739,	0.18],
    [59588.66,	3.4,	22.702,	0.14],
    [59590.61,	3.4,	22.617,	0.11],
    [59595.61,	3.4,	20.742,	0.13],
    [60034.47,	3.4,	3.342,	0.12],
    [60049.34,	3.4,	2.82,	0.078],
    [60131.12,	3.4,	1.999,	0.014],
)

f5_1 = (
    [59439.04,	5.1,	10.012,	0.058],
    [59440.08,	5.1,	33.454,	0.059],
    [59443.99,	5.1,	67.597,	0.087],
    [59446.01,	5.1,	60.457,	0.065],
    [59446.99,	5.1,	63.977,	0.083],
    [59451.01,	5.1,	61.832,	0.074],
    [59461.01,	5.1,	65.115,	0.074],
    [59463.02,	5.1,	60.766,	0.069],
    [59466.04,	5.1,	54.499,	0.067],
    [59467.99,	5.1,	60.253,	0.061],
    [59470.01,	5.1,	56.608,	0.058],
    [59487.96,	5.1,	49.879,	0.061],
    [59510.94,	5.1,	36.454,	0.052],
    [59511.92,	5.1,	36.228,	0.053],
    [59523.82,	5.1,	31.849,	0.053],
    [59574.76,	5.1,	17.481,	0.064],
    [59588.66,	5.1,	18.554,	0.06],
    [59590.61,	5.1,	19.794,	0.062],
    [59595.61,	5.1,	17.488,	0.056],
    [60034.47,	5.1,	2.765,	0.052],
    [60049.34,	5.1,	2.684,	0.053],
    [60131.12,	5.1,	2.163,	0.016],
)

f7 = (
    [59439.04,	7,	15.607,	0.057],
    [59440.08,	7,	39.663,	0.055],
    [59443.99,	7,	58.65,	0.068],
    [59446.01,	7,	50.875,	0.057],
    [59446.99,	7,	51.883,	0.062],
    [59451.01,	7,	52.291,	0.059],
    [59461.01,	7,	57.617,	0.064],
    [59463.02,	7,	56.003,	0.062],
    [59466.04,	7,	54.364,	0.068],
    [59467.99,	7,	55.839,	0.055],
    [59470.01,	7,	54.465,	0.056],
    [59487.96,	7,	46.096,	0.058],
    [59510.94,	7,	38.595,	0.05],	
    [59511.92,	7,	38.215,	0.053],
    [59523.82,	7,	32.08,	0.049],
    [59574.76,	7,	19.527,	0.06],
    [59588.66,	7,	18.619,	0.051],
    [59590.61,	7,	19.169,	0.052],
    [59595.61,	7,	17.871,	0.057],
    [60034.47,	7,	2.347,	0.049],
    [60049.34,	7,	2.373,	0.046],
    [60131.12,	7,	2.336,	0.018],
)

f13_7 = (
    [59439.04,	13.7,	24.088,	0.055],
    [59440.08,	13.7,	40.939,	0.062],
    [59443.99,	13.7,	47.847,	0.066],
    [59446.01,	13.7,	43.692,	0.054],
    [59446.99,	13.7,	41.854,	0.056],
    [59451.01,	13.7,	44.133,	0.054],
    [59461.01,	13.7,	54.102,	0.06],
    [59463.02,	13.7,	51.457,	0.068],
    [59467.99,	13.7,	55.46,	0.057],
    [59470.01,	13.7,	56.891,	0.061],
    [59487.96,	13.7,	51.336,	0.074],
    [59511.92,	13.7,	45.791,	0.053],
    [59523.82,	13.7,	38.122,	0.049],
    [59574.76,	13.7,	25.248,	0.067],
    [59588.66,	13.7,	21.6,	0.051],
    [59590.61,	13.7,	21.908,	0.051],
    [59595.61,	13.7,	20.702,	0.05],
    [60034.47,	13.7,	1.672,	0.05],
    [60049.34,	13.7,	1.67,	0.048],
    [60131.12,	13.7,	1.933,	0.02],
)

f16_5 = (
    [59439.04,	16.5,	25.573,	0.059],
    [59440.08,	16.5,	41.636,	0.063],
    [59443.99,	16.5,	46.81,	0.063],
    [59446.01,	16.5,	42.418,	0.055],
    [59446.99,	16.5,	40.83,	0.056],
    [59451.01,	16.5,	42.894,	0.061],
    [59461.01,	16.5,	54.536,	0.065],
    [59463.02,	16.5,	54.259,	0.074],
    [59467.99,	16.5,	57.657,	0.059],
    [59470.01,	16.5,	60.279,	0.063],
    [59487.96,	16.5,	55.64,	0.083],
    [59511.92,	16.5,	50.332,	0.052],
    [59523.82,	16.5,	41.511,	0.05],
    [59574.76,	16.5,	26.955,	0.061],
    [59588.66,	16.5,	22.164,	0.053],
    [59590.61,	16.5,	22.994,	0.047],
    [59595.61,	16.5,	21.855,	0.048],
    [60034.47,	16.5,	1.526,	0.051],
    [60049.34,	16.5,	1.541,	0.048],
    [60131.12,	16.5,	1.923,	0.022],
)

f31_1 = (
    [59439.04,	31.1,	35.973,	0.14],
    [59440.08,	31.1,	44.762,	0.14],
    [59443.99,	31.1,	48.13,	0.14],
    [59446.01,	31.1,	46.076,	0.12],
    [59446.99,	31.1,	43.653,	0.12],
    [59451.01,	31.1,	47.067,	0.12],
    [59461.01,	31.1,	70.776,	0.15],
    [59463.02,	31.1,	75.224,	0.17],
    [59467.99,	31.1,	85.302,	0.13],
    [59470.01,	31.1,	92.384,	0.14],
    [59487.96,	31.1,	92.061,	0.14],
    [59511.92,	31.1,	79.492,	0.12],
    [59523.82,	31.1,	66.05,	0.11],
    [59574.76,	31.1,	42.236,	0.34],
    [59588.66,	31.1,	26.488,	0.1],
    [59590.61,	31.1,	28.341,	0.11],
    [59595.61,	31.1,	27.116,	0.11],
    [60034.47,	31.1,	0.87,	0.1],
    [60049.34,	31.1,	1.077,	0.11],
    [60131.12,	31.1,	1.336,	0.066],
)

f34_9 = (
    [59439.04,	34.9,	38.318,	0.16],
    [59440.08,	34.9,	46.68,	0.15],
    [59443.99,	34.9,	49.924,	0.16],
    [59446.01,	34.9,	48.49,	0.14],
    [59446.99,	34.9,	45.965,	0.13],
    [59451.01,	34.9,	48.103,	0.13],
    [59461.01,	34.9,	77.042,	0.16],
    [59463.02,	34.9,	82.831,	0.18],
    [59467.99,	34.9,	94.908,	0.14],
    [59470.01,	34.9,	103.52,	0.15],
    [59487.96,	34.9,	103.31,	0.16],
    [59511.92,	34.9,	88.439,	0.13],
    [59523.82,	34.9,	72.993,	0.12],
    [59574.76,	34.9,	47.137,	0.35],
    [59588.66,	34.9,	27.475,	0.11],
    [59590.61,	34.9,	29.746,	0.12],
    [59595.61,	34.9,	28.356,	0.11],
    [60034.47,	34.9,	0.862,	0.11],
    [60049.34,	34.9,	1.113,	0.12],
    [60131.12,	34.9,	1.306,	0.079],
)

# %%
df2_6 =  pd.DataFrame(f2_6, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df3_4 =  pd.DataFrame(f3_4, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df5_1 =  pd.DataFrame(f5_1, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df7 =  pd.DataFrame(f7, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df13_7 =  pd.DataFrame(f13_7, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df16_5 =  pd.DataFrame(f16_5, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df31_1 =  pd.DataFrame(f31_1, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

df34_9 =  pd.DataFrame(f34_9, columns = ["MJD", "Freq (GHz)", "Flux Density (mJy)", "Uncertainty (mJy)"])

# %%
days2_6 = df2_6['MJD'] - 59434
flux2_6 = df2_6["Flux Density (mJy)"]
flux_err2_6 = np.sqrt(df2_6["Uncertainty (mJy)"]**2 + (df2_6["Flux Density (mJy)"]*0.05)**2)

days3_4 = df3_4['MJD'] - 59434
flux3_4 = df3_4["Flux Density (mJy)"]
flux_err3_4 = np.sqrt(df3_4["Uncertainty (mJy)"]**2 + (df3_4["Flux Density (mJy)"]*0.05)**2)

days5_1 = df5_1['MJD'] - 59434
flux5_1 = df5_1["Flux Density (mJy)"]
flux_err5_1 = np.sqrt(df5_1["Uncertainty (mJy)"]**2 + (df5_1["Flux Density (mJy)"]*0.05)**2)

days7 = df7['MJD'] - 59434
flux7 = df7["Flux Density (mJy)"]
flux_err7 = np.sqrt(df7["Uncertainty (mJy)"]**2 + (df7["Flux Density (mJy)"]*0.05)**2)

days13_7 = df13_7['MJD'] - 59434
flux13_7 = df13_7["Flux Density (mJy)"]
flux_err13_7 = np.sqrt(df13_7["Uncertainty (mJy)"]**2 + (df13_7["Flux Density (mJy)"]*0.1)**2)

days16_5 = df16_5['MJD'] - 59434
flux16_5 = df16_5["Flux Density (mJy)"]
flux_err16_5 = np.sqrt(df16_5["Uncertainty (mJy)"]**2 + (df16_5["Flux Density (mJy)"]*0.1)**2)

days31_1 = df31_1['MJD'] - 59434
flux31_1 = df31_1["Flux Density (mJy)"]
flux_err31_1 = np.sqrt(df31_1["Uncertainty (mJy)"]**2 + (df31_1["Flux Density (mJy)"]*0.1)**2)

days34_9 = df34_9['MJD'] - 59434
flux34_9 = df34_9["Flux Density (mJy)"]
flux_err34_9 = np.sqrt(df34_9["Uncertainty (mJy)"]**2 + (df34_9["Flux Density (mJy)"]*0.1)**2)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,10)

# Store which labels have already been used
used_labels = set()

def plot(days, fluxes, errors, color, label_name):
    for day, flux, err in zip(days, fluxes, errors):
        if flux < 3 * err:
            fmt = 'x'  # square for non-detection
            label = None  # no label for non-detections

            ax.errorbar(day, (flux+3*err), fmt=fmt, color=color, label=label)
            
        if flux > 3*err :
            fmt = '^'  # triangle for detection
            label = label_name if label_name not in used_labels else None
        
            ax.errorbar(day, flux, yerr=err, fmt=fmt, color=color, label=label)
        
        if label:
            used_labels.add(label)

# Plot each band
plot(days2_6, flux2_6, flux_err2_6, 'orange', '2.6 GHz')

plot(days3_4, flux3_4, flux_err3_4, 'red', '3.4 GHz')

plot(days5_1, flux5_1, flux_err5_1, 'green', '5.1 GHz')

plot(days7, flux7, flux_err7, 'blue', '7.0 GHz')

plot(days13_7, flux13_7, flux_err13_7, 'purple', '13.7 GHz')

plot(days16_5, flux16_5, flux_err16_5, 'hotpink', '16.5 GHz')

plot(days31_1, flux31_1, flux_err31_1, 'black', '31.1 GHz')

plot(days34_9, flux34_9, flux_err34_9, 'grey', '34.9 GHz')

# Final plot formatting
ax.set_xscale('log')
ax.set_xticks([10,20,50,100,200, 500, 1000], labels = ['10','20','50','100','200', '500', '1000'])
ax.set_yscale('log')
ax.set_yticks([1,10, 100], labels = ['1.0','10.0', '100.0'])
ax.set_xlabel("Time since eruption (days)")
ax.set_ylabel("Flux Density (mJy)")

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

ax.set_title("")
plt.legend()
plt.show();

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,10)

# Store which labels have already been used
used_labels = set()

def plot(days, fluxes, errors, color, label_name):
    for day, flux, err in zip(days, fluxes, errors):
        if flux < 3 * err:
            fmt = 'x'  # square for non-detection
            label = None  # no label for non-detections

            ax.errorbar(day, (flux+3*err), fmt=fmt, color=color, label=label)
            
        if flux > 3*err :
            fmt = '^'  # triangle for detection
            label = label_name if label_name not in used_labels else None
        
            ax.errorbar(day, flux, yerr=err, fmt=fmt, color=color, label=label)
        
        if label:
            used_labels.add(label)

# Plot each band
plot(days2_6, flux2_6, flux_err2_6, 'orange', '2.6 GHz')

plot(days3_4, flux3_4, flux_err3_4, 'red', '3.4 GHz')

plot(days5_1, flux5_1, flux_err5_1, 'green', '5.1 GHz')

plot(days7, flux7, flux_err7, 'blue', '7.0 GHz')

plot(days13_7, flux13_7, flux_err13_7, 'purple', '13.7 GHz')

plot(days16_5, flux16_5, flux_err16_5, 'hotpink', '16.5 GHz')

plot(days31_1, flux31_1, flux_err31_1, 'black', '31.1 GHz')

plot(days34_9, flux34_9, flux_err34_9, 'grey', '34.9 GHz')

# Final plot formatting
ax.set_xscale('log')
ax.set_xticks([10,20,50,100,200, 500, 1000], labels = ['10','20','50','100','200', '500', '1000'])
ax.set_yscale('log')
ax.set_yticks([1,10, 100], labels = ['1.0','10.0', '100.0'])
ax.set_xlabel("Time since eruption (days)")
ax.set_ylabel("Flux Density (mJy)")

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

ax.set_title("")
plt.legend()
plt.show();

# %% [markdown]
# ## Adding lines to make it clear

# %%
fig, ax = plt.subplots()
fig.set_size_inches(13,10)

# Store which labels have already been used
used_labels = set()

def plot(days, fluxes, errors, color, label_name):
    for day, flux, err in zip(days, fluxes, errors):
        if flux < 3 * err:
            fmt = 'x'  # square for non-detection
            label = None  # no label for non-detections

            ax.errorbar(day, (flux+3*err), fmt=fmt, color=color, label=label)
            
        if flux > 3*err :
            fmt = '^'  # triangle for detection
            label = label_name if label_name not in used_labels else None
        
            ax.errorbar(day, flux, yerr=err, fmt=fmt, color=color, label=label)
        
        if label:
            used_labels.add(label)

# Plot each band
plot(days2_6, flux2_6, flux_err2_6, 'orange', '2.6 GHz')
ax.plot(days2_6[0:27], flux2_6[0:27], color='orange', linestyle = '--', alpha=.30)


plot(days3_4, flux3_4, flux_err3_4, 'red', '3.4 GHz')
ax.plot(days3_4[0:27], flux3_4[0:27], color='red', linestyle = '--', alpha=.30)

plot(days5_1, flux5_1, flux_err5_1, 'green', '5.1 GHz')
ax.plot(days5_1[0:27], flux5_1[0:27], color='green', linestyle = '--', alpha=.30)

plot(days7, flux7, flux_err7, 'blue', '7.0 GHz')
ax.plot(days7[0:27], flux7[0:27], color='blue', linestyle = '--', alpha=.30)

plot(days13_7, flux13_7, flux_err13_7, 'purple', '13.7 GHz')
ax.plot(days13_7[0:27], flux13_7[0:27], color='purple', linestyle = '--', alpha=.30)

plot(days16_5, flux16_5, flux_err16_5, 'hotpink', '16.5 GHz')
ax.plot(days16_5[0:27], flux16_5[0:27], color='hotpink', linestyle = '--', alpha=.30)

plot(days31_1, flux31_1, flux_err31_1, 'black', '31.1 GHz')
ax.plot(days31_1[0:27], flux31_1[0:27], color='black', linestyle = '--', alpha=.30)

plot(days34_9, flux34_9, flux_err34_9, 'grey', '34.9 GHz')
ax.plot(days34_9[0:27], flux34_9[0:27], color='grey', linestyle = '--', alpha=.30)

# Final plot formatting
ax.set_xscale('log')
ax.set_xticks([10,20,50,100,200, 500, 1000], labels = ['10','20','50','100','200', '500', '1000'], fontsize = 20)
ax.set_yscale('log')
ax.set_yticks([1,10, 100], labels = [r'$10^{0}$',r'$10^{1}$', r'$10^{2}$'], fontsize = 20)
ax.set_xlabel("Time since eruption (days)", fontsize=25)
ax.set_ylabel("Flux Density (mJy)", fontsize=25)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title("RS Oph Lightcurve", fontsize=20)
plt.legend(fontsize = 15)
plt.show()
fig.savefig("RSOph_lc.png", dpi=300);

# %%
fig, ax = plt.subplots()
fig.set_size_inches(13,10)

# Store which labels have already been used
used_labels = set()

def plot(days, fluxes, errors, color, label_name):
    for day, flux, err in zip(days, fluxes, errors):
        if flux < 3 * err:
            fmt = 'x'  # square for non-detection
            label = None  # no label for non-detections

            ax.errorbar(day, (flux+3*err), fmt=fmt, color=color, label=label)
            
        if flux > 3*err :
            fmt = '^'  # triangle for detection
            label = label_name if label_name not in used_labels else None
        
            ax.errorbar(day, flux, yerr=err, fmt=fmt, color=color, label=label)
        
        if label:
            used_labels.add(label)

# Plot each band
plot(days2_6, flux2_6, flux_err2_6, 'orange', '2.6 GHz')
ax.plot(days2_6[0:27], flux2_6[0:27], color='orange', linestyle = '--', alpha=.30)



plot(days5_1, flux5_1, flux_err5_1, 'green', '5.1 GHz')
ax.plot(days5_1[0:27], flux5_1[0:27], color='green', linestyle = '--', alpha=.30)


plot(days13_7, flux13_7, flux_err13_7, 'hotpink', '13.7 GHz')
ax.plot(days13_7[0:27], flux13_7[0:27], color='hotpink', linestyle = '--', alpha=.30)



plot(days31_1, flux31_1, flux_err31_1, 'black', '31.1 GHz')
ax.plot(days31_1[0:27], flux31_1[0:27], color='black', linestyle = '--', alpha=.30)



# Final plot formatting
ax.set_xscale('log')
ax.set_xticks([10,20,50,100,200, 500, 1000], labels = ['10','20','50','100','200', '500', '1000'], fontsize = 20)
ax.set_yscale('log')
ax.set_yticks([1,10, 100], labels = [r'$10^{0}$',r'$10^{1}$', r'$10^{2}$'], fontsize = 20)
ax.set_xlabel("Time since eruption (days)", fontsize=25)
ax.set_ylabel("Flux Density (mJy)", fontsize=25)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title("RS Oph Lightcurve", fontsize=20)
plt.legend(fontsize = 15)
plt.show()
fig.savefig("RSOph_lc_simple.png", dpi=300);

# %%
np.max(flux5_1)
# Out:
# 67.597

# %%
print(days13_7)
# Out:
# 0       5.04
# 1       6.08
# 2       9.99
# 3      12.01
# 4      12.99
# 5      17.01
# 6      27.01
# 7      29.02
# 8      33.99
# 9      36.01
# 10     53.96
# 11     77.92
# 12     89.82
# 13    140.76
# 14    154.66
# 15    156.61
# 16    161.61
# 17    600.47
# 18    615.34
# 19    697.12
# Name: MJD, dtype: float64

# %%
df5_1
# Out:
#          MJD  Freq (GHz)  Flux Density (mJy)  Uncertainty (mJy)
# 0   59439.04         5.1              10.012              0.058
# 1   59440.08         5.1              33.454              0.059
# 2   59443.99         5.1              67.597              0.087
# 3   59446.01         5.1              60.457              0.065
# 4   59446.99         5.1              63.977              0.083
# 5   59451.01         5.1              61.832              0.074
# 6   59461.01         5.1              65.115              0.074
# 7   59463.02         5.1              60.766              0.069
# 8   59466.04         5.1              54.499              0.067
# 9   59467.99         5.1              60.253              0.061
# 10  59470.01         5.1              56.608              0.058
# 11  59487.96         5.1              49.879              0.061
# 12  59510.94         5.1              36.454              0.052
# 13  59511.92         5.1              36.228              0.053
# ...

# %%
print(flux_err5_1)
# Out:
# 0     0.503949
# 1     1.673740
# 2     3.380970
# 3     3.023549
# 4     3.199927
# 5     3.092485
# 6     3.256591
# 7     3.039083
# 8     2.725774
# 9     3.013267
# 10    2.830994
# 11    2.494696
# 12    1.823442
# 13    1.812175
# 14    1.593332
# 15    0.876390
# 16    0.929638
# 17    0.991640
# 18    0.876191
# 19    0.147706
# 20    0.144287
# 21    0.109327
# dtype: float64

# %% [markdown]
# ## Now for the optical data

# %%
#optical data input

rsoph_opt_unflitered = pd.read_csv('aavsodata_6908b40cd277e.txt', header = 0)

#now to get only the vband

column_name = 'Band'
key = 'V'

rsoph_opt_kinda = rsoph_opt_unflitered[rsoph_opt_unflitered[column_name].str.contains(key, na=False)]

rsoph_opt_close = rsoph_opt_kinda[~rsoph_opt_kinda[column_name].str.contains('Vis.|CV', na=False)]

rsoph_opt =  rsoph_opt_close[~rsoph_opt_kinda["Magnitude"].str.contains('<9.1', na=False)]

rsoph_opt
# Out:
# C:\Users\wilhe\AppData\Local\Temp\ipykernel_20412\77487244.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   rsoph_opt =  rsoph_opt_close[~rsoph_opt_kinda["Magnitude"].str.contains('<9.1', na=False)]
#                  JD Magnitude  Uncertainty  HQuncertainty Band Observer Code  \
# 6      2.459433e+06    11.121        0.011            NaN    V           FJQ
# 7      2.459433e+06    11.157        0.011            NaN    V           FJQ
# 8      2.459433e+06    11.109        0.012            NaN    V           FJQ
# 9      2.459433e+06    11.117        0.013            NaN    V           FJQ
# 10     2.459433e+06    11.083        0.013            NaN    V           FJQ
# ...             ...       ...          ...            ...  ...           ...
# 10883  2.460130e+06    11.041        0.018            NaN    V           FJQ
# 10891  2.460131e+06    10.991        0.003            NaN    V           FJQ
# ...

# %%
#MJD/t0 = 59434
#JD = 2459434

opticaldays = ((rsoph_opt['JD'].astype(float)) - 2459434)
vmag = rsoph_opt['Magnitude'].astype(float)
error_vmag = rsoph_opt['Uncertainty'].astype(float)

# %%
fig, ax = plt.subplots()

fig.set_size_inches(12,8)

ax.errorbar(opticaldays, vmag, yerr=error_vmag, fmt='.', color='black')

ax.set_xscale('log')
ax.set_xticks([1, 10,20,40,60,100, 200], labels = ['1','10','20', '40', '60','100', '200'], fontsize = 20)
#ax.set_yscale('log')
#ax.set_yticks([0.1,1], labels = [r], fontsize = 20)
ax.invert_yaxis()
ax.set_xlabel("Time since eruption (days)", fontsize = 25)
ax.set_ylabel("V mag ()", fontsize = 25)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

ax.set_title("")
plt.show();

# %%
#detection lists

mask0 =  df2_6['Flux Density (mJy)'] > 3 * np.sqrt(df2_6["Uncertainty (mJy)"]**2 + (df2_6["Flux Density (mJy)"]*0.05)**2) #don't show the non-detections
days2_6d = df2_6['MJD'][mask0] - 59434
flux2_6d = df2_6["Flux Density (mJy)"][mask0]
flux_err2_6d = np.sqrt(df2_6["Uncertainty (mJy)"][mask0]**2 + (df2_6["Flux Density (mJy)"][mask0]*0.05)**2)

mask1 =  df3_4["Flux Density (mJy)"] > 3 * np.sqrt(df3_4["Uncertainty (mJy)"]**2 + (df3_4["Flux Density (mJy)"]*0.05)**2) #don't show the non-detections
days3_4d = df3_4['MJD'][mask1] - 59434
flux3_4d = df3_4["Flux Density (mJy)"][mask1]
flux_err3_4d = np.sqrt(df3_4["Uncertainty (mJy)"][mask0]**2 + (df3_4["Flux Density (mJy)"][mask1]*0.05)**2)

mask2 =  df5_1["Flux Density (mJy)"] > 3 * np.sqrt(df5_1["Uncertainty (mJy)"]**2 + (df5_1["Flux Density (mJy)"]*0.05)**2) #don't show the non-detections
days5_1d = df5_1['MJD'][mask2] - 59434
flux5_1d = df5_1["Flux Density (mJy)"][mask2]
flux_err5_1d = np.sqrt(df5_1["Uncertainty (mJy)"][mask2]**2 + (df5_1["Flux Density (mJy)"][mask2]*0.05)**2)

mask3 =  df7["Flux Density (mJy)"] > 3 * np.sqrt(df7["Uncertainty (mJy)"]**2 + (df7["Flux Density (mJy)"]*0.05)**2) #don't show the non-detections
days7d = df7['MJD'][mask3] - 59434
flux7d = df7["Flux Density (mJy)"][mask3]
flux_err7d = np.sqrt(df7["Uncertainty (mJy)"][mask3]**2 + (df7["Flux Density (mJy)"][mask3]*0.05)**2)

mask4 =  df13_7["Flux Density (mJy)"] > 3 * np.sqrt(df13_7["Uncertainty (mJy)"]**2 + (df13_7["Flux Density (mJy)"]*0.1)**2) #don't show the non-detections
days13_7d = df13_7['MJD'][mask4] - 59434
flux13_7d = df13_7["Flux Density (mJy)"][mask4]
flux_err13_7d = np.sqrt(df13_7["Uncertainty (mJy)"][mask4]**2 + (df13_7["Flux Density (mJy)"][mask4]*0.1)**2)

mask5 =  df16_5["Flux Density (mJy)"] > 3 * np.sqrt(df16_5["Uncertainty (mJy)"]**2 + (df16_5["Flux Density (mJy)"]*0.1)**2) #don't show the non-detections
days16_5d = df16_5['MJD'][mask5] -59434
flux16_5d = df16_5["Flux Density (mJy)"][mask5]
flux_err16_5d = np.sqrt(df16_5["Uncertainty (mJy)"][mask5]**2 + (df16_5["Flux Density (mJy)"][mask5]*0.1)**2)


mask6 =  df31_1["Flux Density (mJy)"] > 3 * np.sqrt(df31_1["Uncertainty (mJy)"]**2 + (df31_1["Flux Density (mJy)"]*0.1)**2) #don't show the non-detections
days31_1d = df31_1['MJD'][mask6] - 59434
flux31_1d = df31_1["Flux Density (mJy)"][mask6]
flux_err31_1d = np.sqrt(df31_1["Uncertainty (mJy)"][mask6]**2 + (df31_1["Flux Density (mJy)"][mask6]*0.1)**2)

mask7 =  df34_9["Flux Density (mJy)"] > 3 * np.sqrt(df34_9["Uncertainty (mJy)"]**2 + (df34_9["Flux Density (mJy)"]*0.1)**2) #don't show the non-detections
days34_9d = df34_9['MJD'][mask7] - 59434
flux34_9d = df34_9["Flux Density (mJy)"][mask7]
flux_err34_9d = np.sqrt(df34_9["Uncertainty (mJy)"][mask7]**2 + (df34_9["Flux Density (mJy)"][mask7]*0.1)**2)

# %%
# non detection lists

mask0 =  df2_6['Flux Density (mJy)'] < 3 * np.sqrt(df2_6["Uncertainty (mJy)"]**2 + (df2_6["Flux Density (mJy)"]*0.05)**2) #don't show the non-detections
days2_6nd = df2_6['MJD'][mask0] - 59434
flux2_6nd = df2_6["Flux Density (mJy)"][mask0]
flux_err2_6nd = np.sqrt(df2_6["Uncertainty (mJy)"][mask0]**2 + (df2_6["Flux Density (mJy)"][mask0]*0.05)**2)

mask1 =  df3_4["Flux Density (mJy)"] < 3 * np.sqrt(df3_4["Uncertainty (mJy)"]**2 + (df3_4["Flux Density (mJy)"]*0.05)**2) #don't show the non-detections
days3_4nd = df3_4['MJD'][mask1] - 59434
flux3_4nd = df3_4["Flux Density (mJy)"][mask1]
flux_err3_4nd = np.sqrt(df3_4["Uncertainty (mJy)"][mask0]**2 + (df3_4["Flux Density (mJy)"][mask1]*0.05)**2)

mask2 =  df5_1["Flux Density (mJy)"] < 3 * np.sqrt(df5_1["Uncertainty (mJy)"]**2 + (df5_1["Flux Density (mJy)"]*0.05)**2) #don't show the non-detections
days5_1nd = df5_1['MJD'][mask2] - 59434
flux5_1nd = df5_1["Flux Density (mJy)"][mask2]
flux_err5_1nd = np.sqrt(df5_1["Uncertainty (mJy)"][mask2]**2 + (df5_1["Flux Density (mJy)"][mask2]*0.05)**2)

mask3 =  df7["Flux Density (mJy)"] < 3 * np.sqrt(df7["Uncertainty (mJy)"]**2 + (df7["Flux Density (mJy)"]*0.05)**2) #don't show the non-detections
days7nd = df7['MJD'][mask3] - 59434
flux7nd = df7["Flux Density (mJy)"][mask3]
flux_err7nd = np.sqrt(df7["Uncertainty (mJy)"][mask3]**2 + (df7["Flux Density (mJy)"][mask3]*0.05)**2)

mask4 =  df13_7["Flux Density (mJy)"] < 3 * np.sqrt(df13_7["Uncertainty (mJy)"]**2 + (df13_7["Flux Density (mJy)"]*0.1)**2) #don't show the non-detections
days13_7nd = df13_7['MJD'][mask4] - 59434
flux13_7nd = df13_7["Flux Density (mJy)"][mask4]
flux_err13_7nd = np.sqrt(df13_7["Uncertainty (mJy)"][mask4]**2 + (df13_7["Flux Density (mJy)"][mask4]*0.1)**2)

mask5 =  df16_5["Flux Density (mJy)"] < 3 * np.sqrt(df16_5["Uncertainty (mJy)"]**2 + (df16_5["Flux Density (mJy)"]*0.1)**2) #don't show the non-detections
days16_5nd = df16_5['MJD'][mask5] -59434
flux16_5nd = df16_5["Flux Density (mJy)"][mask5]
flux_err16_5nd = np.sqrt(df16_5["Uncertainty (mJy)"][mask5]**2 + (df16_5["Flux Density (mJy)"][mask5]*0.1)**2)


mask6 =  df31_1["Flux Density (mJy)"] < 3 * np.sqrt(df31_1["Uncertainty (mJy)"]**2 + (df31_1["Flux Density (mJy)"]*0.1)**2) #don't show the non-detections
days31_1nd = df31_1['MJD'][mask6] - 59434
flux31_1nd = df31_1["Flux Density (mJy)"][mask6]
flux_err31_1nd = np.sqrt(df31_1["Uncertainty (mJy)"][mask6]**2 + (df31_1["Flux Density (mJy)"][mask6]*0.1)**2)

mask7 =  df34_9["Flux Density (mJy)"] < 3 * np.sqrt(df34_9["Uncertainty (mJy)"]**2 + (df34_9["Flux Density (mJy)"]*0.1)**2) #don't show the non-detections
days34_9nd = df34_9['MJD'][mask7] - 59434
flux34_9nd = df34_9["Flux Density (mJy)"][mask7]
flux_err34_9nd = np.sqrt(df34_9["Uncertainty (mJy)"][mask7]**2 + (df34_9["Flux Density (mJy)"][mask7]*0.1)**2)

# %%
plt.style.use('tableau-colorblind10')

from matplotlib.ticker import AutoMinorLocator

fig, axs = plt.subplots(2, 1, figsize=(10, 10), sharey=False, sharex = True)#, constrained_layout=True)


#first the visual
axs[0].scatter(opticaldays, vmag, marker = '.', color = 'black')
axs[0].annotate('RS Oph (2021)',(90,6), fontsize=15)

axs[0].set_xscale('log')
#axs[0].set_yscale('log')

axs[0].set_ylabel('Visual Brightness (mag)',fontsize =20)

axs[0].set_yticks([4,6,8,10,12,14], labels = [r'$4$',r'$6$',r'$8$',r'$10$', r'$12$', r'$14$'], fontsize = 18)
axs[0].invert_yaxis()
axs[0].tick_params(which='minor', length=4, direction = 'in', top=True, labeltop=False, left=True, labelleft=False, bottom=True, labelbottom=False, right = True,labelright = False)
axs[0].yaxis.set_minor_locator(AutoMinorLocator(2))  # 2 minor intervals between major ticks
axs[0].tick_params(which='major', length=7, direction = 'in', width =1, top=True, labeltop=False, bottom=True, labelbottom=False, right = True, labelright = False)


#now the radio
axs[1].set_ylabel('Flux Density (mJy)',fontsize=20)
axs[1].set_xlabel('Time Since Eruption (Days)', fontsize=20)
axs[1].set_xscale('log')
axs[1].set_yscale('log')



axs[1].errorbar(days2_6d, flux2_6d, yerr=flux_err2_6d, linestyle ='--', fmt = '*' , markersize = 8.5, label='2.6 GHz')
#axs[1].errorbar(days3_4d, flux3_4d, yerr=flux_err3_4d, linestyle ='--', fmt = '*' , label='3.4 Ghz')
axs[1].errorbar(days5_1d, flux5_1d, yerr=flux_err5_1d, linestyle ='--', fmt = '*', markersize = 8.5, label='5.1 GHz')
#axs[1].errorbar(days7d, flux7d, yerr=flux_err7d, linestyle ='--', fmt = '*', markersize = 8.5 , label='7.0 Ghz')
axs[1].errorbar(days13_7d, flux13_7d, yerr=flux_err13_7d, linestyle ='--', fmt = '*' , label='13.7 GHz')
#axs[1].errorbar(days16_5d, flux16_5d, yerr=flux_err16_5d, linestyle ='--', fmt = '*', markersize = 8.5 , label='16.5 Ghz')
axs[1].errorbar(days31_1d, flux31_1d, yerr=flux_err31_1d, linestyle ='--', fmt = '*' , markersize = 8.5, label='31.1 GHz')
#axs[1].errorbar(days34_9d, flux34_9d, yerr=flux_err34_9d, linestyle ='--', fmt = '*' , label='34.9 Ghz')


axs[1].scatter(days2_6nd, flux2_6nd , marker = 'v')
#axs[1].scatter(days3_4nd, flux3_4nd , marker = 'v')
axs[1].scatter(days5_1nd, flux5_1nd , marker = 'v')
#axs[1].scatter(days7nd, flux7nd , marker = 'v')
axs[1].scatter(days13_7nd, flux13_7nd , marker = 'v')
#axs[1].scatter(days16_5nd, flux16_5nd , marker = 'v')
axs[1].scatter(days31_1nd, flux31_1nd , marker = 'v')
#axs[1].scatter(days34_9nd, flux34_9nd , marker = 'v')



axs[1].legend(fontsize=15)

axs[1].set_xticks([1, 10,100, 500], labels = ['1', '10','100', '500'], fontsize = 18)
axs[1].set_yticks([1, 10, 100], labels = [r'$1$', r'$10$', r'$100$'], fontsize = 18)
axs[1].set_ylim(bottom=0.5, top=150)

axs[1].tick_params(which='minor', length =4, direction = 'in', top=True, labeltop=False, bottom=True, labelbottom=False, right = True,labelright = False)
axs[1].tick_params(which='major', length=7, direction = 'in', width =1, top=True, labeltop=False, bottom=True, labelbottom=True, right = True, labelright = False)


fig.subplots_adjust(hspace=0.05)
plt.savefig("RSOph_Optical_and_Radio_lightcurves.png")
plt.show();
