# %% [markdown]
# ## Spectral Index Alpha values over time
# ### Going to make one for each nova, and then combine them all into one

# %%
## First get in the imports
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sympy import diff as dif

from astropy.io import ascii
import astropy.units as u
import astropy.constants as const
from astropy.modeling.powerlaws import BrokenPowerLaw1D, SmoothlyBrokenPowerLaw1D, PowerLaw1D
from astropy.modeling import fitting, models

# %% [markdown]
# ### U Sco First

# %%
usco_days = np.array([18.5, 32.53, 39.42])
usco_a = np.array([1.413, 0.38, 0.44])
usco_a_err = np.array([0.168, 0.753, 0.27])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

ax.errorbar(usco_days, usco_a, yerr=usco_a_err, fmt = '^', color='blue', label='U Sco', capsize = 3)

ax.set_xscale('log')
ax.set_xticks([10,20, 30, 40,50], labels = ['10', '20', '30', '40', '50'], fontsize = 13)
#ax.invert_xaxis()

#ax.set_yscale('log')
#ax.set_yticks([1], labels = ['1.0'], fontsize = 13)

ax.set_xlabel("Days Since Eruption", fontsize=17)
ax.set_ylabel("${\u03B1}$", fontsize=17)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title(r"$ V_{peak} $ and $ S_{max} $ Correlation", fontsize=20)

plt.legend(fontsize = 11)
plt.show();

# %% [markdown]
# ### V1535 Sco

# %%
v1535_days = np.array([2.7, 6.66, 7.66,12.67,17.66,23.66,26.56,41.58,54.57,55.73,65.51,66.49,78.463,93.46])
v1535_a = np.array([-0.888,-0.385,-0.777, 0.867, -0.291, 0.980, 0.339, 0.175,-0.486, -0.452, -0.221, -0.631,-0.145,0.054])
v1535_a_err = np.array([0.026, 0.324,0.025, 0.053,0.004, 0.069,0.177,0.044,0.016, 0.035, 0.043, 0.200, 0.092, 0.018])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

ax.errorbar(v1535_days, v1535_a, yerr=v1535_a_err, fmt = '^', color='blue', label='V1535 Sco', capsize = 3)

ax.set_xscale('log')
ax.set_xticks([10,20, 30, 40,50, 100], labels = ['10', '20', '30', '40', '50', '100'], fontsize = 13)
#ax.invert_xaxis()

#ax.set_yscale('log')
#ax.set_yticks([1], labels = ['1.0'], fontsize = 13)

ax.set_xlabel("Days Since Eruption", fontsize=17)
ax.set_ylabel("${\u03B1}$", fontsize=17)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title(r"$ V_{peak} $ and $ S_{max} $ Correlation", fontsize=20)

plt.legend(fontsize = 11)
plt.show();

# %% [markdown]
# ### V1534 Sco

# %%
v1534_days = np.array([4.65,14.65,16.65,25.55,31.55, 33.55, 45.45,47.55,78.45, 84.35, 98.35, 108.35, 138.15, 165.25, 193.75, 208.05,
                      210.05, 226.95, 254.95, 260.85, 296.75, 339.75, 393.55])
v1534_a = np.array([-1.324, -0.206, -1.588, -0.621, -0.538, -0.924, -0.850, -1.427, -0.943, -1.486, -.616, -0.628, 
                   -0.89, -.905, -0.351, -2.169, 0.458, -0.545, -1.298, 0.332, -0.099, -0.456, 0.216])
v1534_a_err = np.array([0.828, 0.142, 0.289,0.056, 0.071, 0.1,0.14, 0.303, 0.365, 0.181, 0.015, 0.123, 0.054, 0.109, 0.226, 0.21, 
                       1.007,0.083, 0.426,0.998, 0.339, 0.382, 0.552])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

ax.errorbar(v1534_days, v1534_a, yerr=v1534_a_err, fmt = '^', color='blue', label='V1534 Sco', capsize = 3)

ax.set_xscale('log')
ax.set_xticks([10,20, 30, 40,50, 100, 200, 400], labels = ['10', '20', '30', '40', '50', '100', '200', '400'], fontsize = 13)
#ax.invert_xaxis()

#ax.set_yscale('log')
#ax.set_yticks([1], labels = ['1.0'], fontsize = 13)

ax.set_xlabel("Days Since Eruption", fontsize=17)
ax.set_ylabel("${\u03B1}$", fontsize=17)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title(r"$ V_{peak} $ and $ S_{max} $ Correlation", fontsize=20)

plt.legend(fontsize = 11)
plt.show();

# %% [markdown]
# ### RS Oph

# %%
rs_days = np.array([5.04, 6.08, 9.99, 12.01, 12.99, 17.01, 27.01, 29.02, 32.04, 33.99, 36.01, 53.96, 76.94, 77.92, 89.82, 140.76, 
                    154.66, 156.61,161.61, 600.47, 615.34, 697.12])
rs_a = np.array([1.075, 0.534, -0.186, -0.358, -0.362, -0.37, -.35, -.336, -.093, -.287, -.228, -.284, .359, 0.088, 0.019, 0.111,
                 -0.18, -0.145, -0.159, -0.547, -.393, -0.057])
rs_a_err = np.array([0.154, 0.087, 0.034, 0.142, 0.075, 0.084, 0.116, 0.084, 0.036, 0.088, 0.169, 0.066, 0.033, 0.035, 0.037, 0.073, 0.08, 
                    0.063, 0.073, 0.038, 0.042, 0.089])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

ax.errorbar(rs_days, rs_a, yerr=rs_a_err, fmt = '^', color='blue', label='RS Oph', capsize = 3)

ax.set_xscale('log')
ax.set_xticks([10,20, 30, 40,50, 100, 200, 400, 600], labels = ['10', '20', '30', '40', '50', '100', '200', '400', '600'], fontsize = 13)
#ax.invert_xaxis()

#ax.set_yscale('log')
#ax.set_yticks([1], labels = ['1.0'], fontsize = 13)

ax.set_xlabel("Days Since Eruption", fontsize=17)
ax.set_ylabel("${\u03B1}$", fontsize=17)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title(r"$ V_{peak} $ and $ S_{max} $ Correlation", fontsize=20)

plt.legend(fontsize = 11)
plt.show();

# %% [markdown]
# ### V392 Per

# %%
v392_days = np.array([9,13,18,19,23,32,41,131,142,186,223, 224, 256, 259, 282, 390, 391, 415, 419, 475, 611, 687, 747])
v392_a = np.array([0.507, 1.187, 0.325, 1.131, 0.767, 0.312, 0.176, 0.465, 0.371, 0.078, 0.342, -0.282, 0.194, -0.273, -0.076,
                  0.244, -0.112, -.148, 0.771, -1.181, 0.318, 0.059, 0.068])
v392_a_err = np.array([0.149, 0.015, 0.070, 0.045, 0.002, 0.011, 0.020, 0.074, .153, 0.067, 0.151, 0.224, 0.032, 0.084, 0.086, 0.615, 
                      0.069, 0.007, 0.015, 0.017, 0.04, 0.229, 0.017])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

ax.errorbar(v392_days, v392_a, yerr=v392_a_err, fmt = '^', color='blue', label='V392 Per', capsize = 3)

ax.set_xscale('log')
ax.set_xticks([10,20, 30, 40,50, 100, 200, 400, 600, 800], labels = ['10', '20', '30', '40', '50', '100', '200', '400', '600', '800'], fontsize = 13)
#ax.invert_xaxis()

#ax.set_yscale('log')
#ax.set_yticks([1], labels = ['1.0'], fontsize = 13)

ax.set_xlabel("Days Since Eruption", fontsize=17)
ax.set_ylabel("${\u03B1}$", fontsize=17)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title(r"$ V_{peak} $ and $ S_{max} $ Correlation", fontsize=20)

plt.legend(fontsize = 11)
plt.show();

# %% [markdown]
# ### V407 Cyg

# %%
v407_days = np.array([19,23.9,28.9,32.9,35.8,38.9,42.8,45.8,49.8,52.8,57.8,61.8,64.7,66.7,75.7,79.7,96.7,101.8,102.7,138.5,153.6,168.5,183.5
                     , 203.4,359.6,469.6,603.3, 669, 769.6])
v407_a = np.array([1.34, .69, .719, .752, .848, .762, .67, .659, .649, .625, .607, .726, .767, .69, .694, .678, .774, .713, .584, .351, .227,
                  .352 ,.258, .299, .05, -.152, 0.035, 0.001, -0.035])
v407_a_err = np.array([.282, .011, .012, .028, .093, .028, .05, .03, .015, .028, .014, .142, .032, .051, .05, .049, .062, .079,
                      .085, .041, .038, .045, .046, .035, .016, .048, .022, .042, .021])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

ax.errorbar(v407_days, v407_a, yerr=v407_a_err, fmt = '^', color='blue', label='V407 Cyg', capsize = 3)

ax.set_xscale('log')
ax.set_xticks([10,20, 30, 40,50, 100, 200, 400, 600, 800], labels = ['10', '20', '30', '40', '50', '100', '200', '400', '600', '800'], fontsize = 13)
#ax.invert_xaxis()

#ax.set_yscale('log')
#ax.set_yticks([1], labels = ['1.0'], fontsize = 13)

ax.set_xlabel("Days Since Eruption", fontsize=17)
ax.set_ylabel("${\u03B1}$", fontsize=17)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title(r"$ V_{peak} $ and $ S_{max} $ Correlation", fontsize=20)

plt.legend(fontsize = 11)
plt.show();

# %% [markdown]
# ### V5589 Sgr

# %%
v5589_days = np.array([46.4, 54.2, 62.3, 81.1, 90.3, 110, 113.3, 129, 136.2, 139.9])
v5589_a = np.array([.773, .556, .152, .2,-.138, .119, -.136, -0.09, -.91, -.395])
v5589_a_err = np.array([.252, .093, .011, .128, .385, .082, .038, .128, .305, .305])

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

ax.errorbar(v5589_days, v5589_a, yerr=v5589_a_err, fmt = '^', color='blue', label='V5589 Sgr', capsize = 3)

ax.set_xscale('log')
ax.set_xticks([10,20, 30, 40,50, 100, 200, 400, 600, 800], labels = ['10', '20', '30', '40', '50', '100', '200', '400', '600', '800'], fontsize = 13)
#ax.invert_xaxis()

#ax.set_yscale('log')
#ax.set_yticks([1], labels = ['1.0'], fontsize = 13)

ax.set_xlabel("Days Since Eruption", fontsize=17)
ax.set_ylabel("${\u03B1}$", fontsize=17)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title(r"$ V_{peak} $ and $ S_{max} $ Correlation", fontsize=20)

plt.legend(fontsize = 11)
plt.show();

# %% [markdown]
# ## V745 Sco

# %%
v745_a_low = [0.73, 0.07, 0.17, 0.02, 0.03, 0.25, -0.17, -0.17]
v745_al_err = [0.17, 0.06, 0.04, 0.04, 0.03, 0.02, 0.01, 0.02]

v745_a_high = [1.21, -2.10, -0.24, -0.57, -0.13, -0.13, 0.15, 0.13]
v745_ah_err = [ 0.56, 0.91, 0.04, 0.34, 0.08, 0.02, 0.06, 0.17]
v745_days_lohi = [3.4, 17.5, 25.5, 38.5, 47.5, 54.4, 64.5, 73.4] #days for alpha 1 and 2 

v745_a = [1.27, -0.23, -0.24, 0.19,0.03,0.06]
v745_a_err = [0.23, 0.09,0.24,0.09,0.11,0.29]
v745_days = [2,92.3,115.3,148.5,182,244] #days for alpha

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

ax.errorbar(v745_days, v745_a, yerr=v745_a_err, fmt = '^', color='pink', label='V745 Sgr PowerFit', capsize = 3)
ax.errorbar(v745_days_lohi, v745_a_low, yerr=v745_al_err, fmt = 'o', color='pink', label='V745 Sgr Low', capsize = 3)
ax.errorbar(v745_days_lohi, v745_a_high, yerr=v745_ah_err, fmt = '*', markersize=10, color='pink', label='V745 Sgr High', capsize = 3)

ax.set_xscale('log')
ax.set_xticks([10,20, 30, 40,50, 100, 200, 400, 600, 800], labels = ['10', '20', '30', '40', '50', '100', '200', '400', '600', '800'], fontsize = 13)
#ax.invert_xaxis()

#ax.set_yscale('log')
#ax.set_yticks([1], labels = ['1.0'], fontsize = 13)

ax.set_xlabel("Days Since Eruption", fontsize=17)
ax.set_ylabel("${\u03B1}$", fontsize=17)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title(r"$ V_{peak} $ and $ S_{max} $ Correlation", fontsize=20)

plt.legend(fontsize = 11)
plt.show();

# %% [markdown]
# ## Now all together

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15,10)

ax.axhline(y=-.1, color='black', linestyle='--', linewidth=1.5)
ax.axhline(y=2, color='black', linestyle='--', linewidth=1.5)

x = np.linspace(0, 2000, 100)

# Add the horizontal lines
ax.axhline(y=-0.5, color='grey', linestyle='-', alpha=0.5, linewidth=1.5)
ax.axhline(y=-1, color='grey', linestyle='-', alpha=0.5, linewidth=1.5)

# Fill between y = -1 and y = -0.5 across the x-range
ax.fill_between(x, -1, -0.5, alpha=0.25, color='grey')


#You may also want a horizontal line plotted at y= -0.1 to
#show where we get optically thin thermal emission and a line at y=2 to show where we get optically thick thermal emission. 

ax.errorbar(v5589_days, v5589_a, yerr=v5589_a_err, fmt = '^', color='mediumblue', label='V5589 Sgr', capsize = 3,  alpha = .5)
ax.plot(v5589_days, v5589_a, color='mediumblue', alpha = .5)

ax.errorbar(v407_days, v407_a, yerr=v407_a_err, fmt = '^', color='purple', label='V407 Cyg', capsize = 3,  alpha = .5)
ax.plot(v407_days, v407_a, color='purple', alpha=.5)

ax.errorbar(v392_days, v392_a, yerr=v392_a_err, fmt = '^', color='green', label='V392 Per', capsize = 3,  alpha = .5)
ax.plot(v392_days, v392_a, color='green', alpha=.5)

ax.errorbar(rs_days, rs_a, yerr=rs_a_err, fmt = '^', color='orange', label='RS Oph', capsize = 3,  alpha = .5)
ax.plot(rs_days, rs_a, color='orange', alpha=.5)

ax.errorbar(v1534_days, v1534_a, yerr=v1534_a_err, fmt = '^', color='red', label='V1534 Sco', capsize = 3,  alpha = .5)
ax.plot(v1534_days, v1534_a, color='red', alpha=.5)

ax.errorbar(v1535_days, v1535_a, yerr=v1535_a_err, fmt = '^', color='aqua', label='V1535 Sco', capsize = 3,  alpha = .5)
ax.plot(v1535_days, v1535_a, color='aqua', alpha=.5)

ax.errorbar(usco_days, usco_a, yerr=usco_a_err, fmt = '^', color='yellow', label='U Sco', capsize = 3,  alpha = .5)
ax.plot(usco_days, usco_a, color='yellow', alpha=.5)

ax.errorbar(v745_days, v745_a, yerr=v745_a_err, fmt = '^', color='pink', label='V745 Sgr', capsize = 3)
#ax.errorbar(v745_days_lohi, v745_a_low, yerr=v745_al_err, fmt = 'o', color='pink', label='', capsize = 3)
#ax.errorbar(v745_days_lohi, v745_a_high, yerr=v745_ah_err, fmt = '*', markersize=10, color='pink', label='', capsize = 3)
ax.plot(v745_days, v745_a,color='pink', alpha=.5)
#ax.plot(v745_days_lohi, v745_a_low, linestyle=':', color='pink', alpha=.5)
#ax.plot(v745_days_lohi, v745_a_high, color='pink', alpha=.5)


ax.set_xscale('log')
ax.set_xlim(0, 900)
ax.set_xticks([10,20, 30,50, 100, 200, 400, 800], labels = ['10', '20', '30', '50', '100', '200', '400', '800'], fontsize = 20)
#ax.invert_xaxis()

#ax.set_yscale('log')
plt.yticks(fontsize=20)
#ax.set_yticks([1], labels = ['1.0'], fontsize = 13)

ax.set_xlabel("Days Since Eruption", fontsize=25)
ax.set_ylabel("${\u03B1}$", fontsize=25)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

#ax.set_title(r"$ V_{peak} $ and $ S_{max} $ Correlation", fontsize=20)

plt.legend(fontsize = 13)
plt.show()
fig.savefig("Combined_spec_index_a_over_time", dpi=300);
# Out:
# C:\Users\wilhe\AppData\Local\Temp\ipykernel_17796\1002670243.py:50: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   ax.set_xlim(0, 900)
