# %% [markdown]
# V392 Per lightcruve

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = ([58238.93,	1.26,	-0.0122,	0.0531,	1],
[58238.93,	1.74,	0.0298,	0.0385,	1],
[58238.93,	5,	0.0152,	0.012,	1],
[58238.93,	7,	-0.0184,	0.0143,	1],
[58246.67,	5,	0.232,	0.0125,	9],
[58246.67,	7,	0.3,	0.0125,	9],
[58246.68,	13.5,	0.435,	0.0181,	9],
[58246.68,	16.5,	0.342,	0.0186,	9],
[58246.68,	29.5,	0.968,	0.0239,	9],
[58246.68,	35,	0.913,	0.0231,	9],
[58250.64,	1.26,	0.114,	0.0474,	13],
[58250.64,	1.74,	0.15,	0.0419,	13],
[58250.64,	5,	0.5,	0.0132,	13],
[58250.64,	7,	0.751,	0.0147,	13],
[58255.65,	13.5,	7.378,	0.0135,	18],
[58255.65,	16.5,	8.321,	0.0171,	18],
[58255.65,	29.5,	11.851,	0.0286,	18],
[58255.65,	35,	12.991,	0.035,	18],
[58255.71,	8.416,	7.136,	0.0322,	18],
[58256.62,	1.26,	0.626,	0.0562,	19],
[58256.62,	1.74,	0.948,	0.0424,	19],
[58256.62,	5,	3.227,	0.0131,	19],
[58256.62,	7,	4.202,	0.0214,	19],
[58259.7,	4.868,	3.932,	0.0196,	22],
[58260.96,	1.26,	1.576,	0.0616,	23],
[58260.96,	1.74,	2.015,	0.041,	23],
[58260.96,	5,	4.523,	0.0134,	23],
[58260.96,	7,	5.889,	0.0152,	23],
[58269.56,	13.5,	7.582,	0.0116,	32],
[58269.56,	16.5,	8.545,	0.0131,	32],
[58269.56,	29.5,	14.418,	0.0485,	32],
[58269.56,	35,	17.162,	0.0565,	32],
[58269.61,	1.26,	3.471,	0.0551,	32],
[58269.61,	1.74,	3.887,	0.0374,	32],
[58269.61,	5,	5.226,	0.0122,	32],
[58269.61,	7,	5.994,	0.0134,	32],
[58278.53,	13.5,	6.545,	0.012,	41],
[58278.53,	16.5,	7.35,	0.0141,	41],
[58278.53,	29.5,	11.934,	0.0594,	41],
[58278.53,	35,	13.925,	0.07,	41],
[58278.58,	1.26,	3.704,	0.0571,	41],
[58278.58,	1.74,	3.746,	0.0413,	41],
[58278.58,	5,	4.419,	0.0123,	41],
[58278.58,	7,	4.984,	0.0137,	41],
[58280.64,	8.416,	1.98,	0.036,	43],
[58283.6,	4.868,	3.57,	0.025,	46],	
[58323.5,	4.868,	1.2,	0.02,	86],
#	1.4			90
[58347.5,	1.4,	0.22,	0.035,	110],
[58368.38,	13.5,	3.017,	0.0111,	131],
[58368.38,	16.5,	3.089,	0.0125,	131],
[58368.38,	29.5,	3.164,	0.0266,	131],
[58368.38,	35,	3.116,	0.0338,	131],
[58368.43,	1.26,	0.971,	0.272,	131],
[58368.43,	1.74,	0.85,	0.116,	131],
[58368.43,	5,	1.865,	0.017,	131],
[58368.43,	7,	2.333,	0.0126,	131],
[58379.39,	13.5,	2.444,	0.0118,	142],
[58379.39,	16.5,	2.475,	0.0127,	142],
[58379.39,	29.5,	2.364,	0.0237,	142],
[58379.39,	35,	2.193,	0.0256,	142],
[58379.44,	1.26,	1.033,	0.223,	142],
[58379.44,	1.74,	0.417,	0.125,	142],
[58379.44,	5,	1.637,	0.0158,	142],
[58379.44,	7,	2.018,	0.0125,	142],		
[58423.19,	13.5,	1.2,	0.0127,	186],
[58423.19,	16.5,	1.207,	0.0117,	186],
[58423.19,	29.5,	1.068,	0.0241,	186],
[58423.19,	35,	1.125,	0.0276,	186],
[58423.58,	1.26,	-0.108,	0.241,	186],
[58423.58,	1.74,	0.511,	0.107,	186],
[58423.58,	5,	1.121,	0.0201,	186],
[58423.58,	7,	1.165,	0.0165,	186],
[58460.18,	1.26,	0.105,	0.111,	223],
[58460.18,	1.74,	0.349,	0.0714,	223],
[58460.18,	5,	0.766,	0.0137,	223],
[58460.18,	7,	0.782,	0.0131,	223],	
[58461.08,	13.5,	0.738,	0.0119,	224],
[58461.08,	16.5,	0.717,	0.0121,	224],
[58461.08,	29.5,	0.57,	0.0229,	224],
[58461.08,	35,	0.593,	0.0273,	224],
[58493.11,	1.26,	0.178,	0.151,	256],
[58493.11,	1.74,	0.402,	0.0811,	256],
[58493.11,	5,	0.559,	0.0158,	256],
[58493.11,	7,	0.589,	0.0186,	256],
[58496.01,	13.5,	0.521,	0.0114,	259],
[58496.01,	16.5,	0.529,	0.0118,	259],
[58496.01,	29.5,	0.426,	0.0266,	259],
[58496.01,	35,	0.414,	0.0309,	259],
[58519.04,	1.26,	0.111,	0.109,	282],
[58519.04,	1.74,	0.41,	0.0637,	282],
[58519.04,	5,	0.492,	0.0127,	282],
[58519.04,	7,	0.457,	0.0126,	282],
[58627.98,	1.26,	0.0193,	0.086,	390],
[58627.98,	1.78,	0.177,	0.044,	390],
[58627.98,	5,	0.157,	0.0145,	390],
[58627.98,	7,	0.176,	0.0143,	390],
[58628.64,	13.5,	0.139,	0.034,	391],
[58628.64,	16.5,	0.125,	0.0399,	391],
[58628.64,	29.5,	0.126,	0.0373,	391],
[58628.64,	35,	-0.0704,	0.0471,	391],
[58652.58,	1.26,	0.104,	0.0989,	415],
[58652.58,	1.78,	0.0834,	0.0396,	415],
[58652.58,	5,	0.165,	0.0134,	415],
[58652.58,	7,	0.157,	0.0143,	415],
[58658.62,	13.5,	0.0657,	0.0114,	419],
[58658.62,	16.5,	0.0483,	0.0201,	419],
[58658.62,	29.5,	0.104,	0.0352,	419],
[58658.62,	35,	0.137,	0.0421,	419],
[58711.46,	13.5,	0.032,	0.014,	474],
[58711.46,	16.5,	0.007,	0.015,	474],
[58711.46,	29.5,	-0.033,	0.034,	474],
[58711.46,	35,	-0.031,	0.043,	474],
[58712.62,	1.26,	0.38,	0.09,	475],
[58712.62,	1.78,	0.255,	0.067,	475],
[58712.62,	5,	0.075,	0.017,	475],
[58712.62,	7,	0.056,	0.02,	475],
#[58765.29,	1.26			528],
[58765.29,	1.78,	0.0962,	0.066,	528],
[58765.29,	5,	0.0426,	0.016,	528],
[58765.29,	7,	0.0304,	0.016,	528],
#[58839.82,	5,			611],
#[58839.82,	7,			611
[58839.82,	13.5,	0.0592,	0.017,	611],
[58839.82,	16.5,	0.0631,	0.018,	611],
[58839.82,	29.5,	0.002,	0.04,	611],
[58839.82,	35,	0.02,	0.044,	611],
[58924.11,	5,	0.117,	0.022,	687],
[58924.11,	7,	0.088,	0.021,	687],
[58924.11,	13.5,	0.037,	0.017,	687],
[58924.11,	16.5,	0.024,	0.018,	687],
[58924.11,	29.5,	0.14,	0.036,	687],
[58924.11,	35,	0.05,	0.041,	687],
[58984.93,	5,	0.0606,	0.016,	747],
[58984.93,	7,	0.062,	0.015,	747],
[58984.93,	13.5,	0.0423,	0.017,	747],
[58984.93,	16.5,	0.0532,	0.018,	747],
[58984.93,	29.5,	0.0229,	0.037,	747],
[58984.93,	35,	0.008,	0.043,	747])

df =  pd.DataFrame(data, columns = ["MJD",	"Freq (GHz)",	"Flux (mJy)",	"eFlux (mJy)",	"Days"])

# %%
df
# Out:
#           MJD  Freq (GHz)  Flux (mJy)  eFlux (mJy)  Days
# 0    58238.93        1.26     -0.0122       0.0531     1
# 1    58238.93        1.74      0.0298       0.0385     1
# 2    58238.93        5.00      0.0152       0.0120     1
# 3    58238.93        7.00     -0.0184       0.0143     1
# 4    58246.67        5.00      0.2320       0.0125     9
# ..        ...         ...         ...          ...   ...
# 130  58984.93        7.00      0.0620       0.0150   747
# 131  58984.93       13.50      0.0423       0.0170   747
# 132  58984.93       16.50      0.0532       0.0180   747
# 133  58984.93       29.50      0.0229       0.0370   747
# 134  58984.93       35.00      0.0080       0.0430   747
#
# [135 rows x 5 columns]

# %%
df.describe()
# Out:
#                 MJD  Freq (GHz)  Flux (mJy)  eFlux (mJy)        Days
# count    135.000000  135.000000  135.000000   135.000000  135.000000
# mean   58480.232148   12.779526    1.945572     0.037399  242.925926
# std      225.369744   11.555215    3.258491     0.041297  225.774013
# min    58238.930000    1.260000   -0.108000     0.011100    1.000000
# 25%    58269.610000    4.868000    0.104000     0.014200   32.000000
# 50%    58423.190000    7.000000    0.511000     0.022000  186.000000
# 75%    58652.580000   16.500000    2.348500     0.042000  415.000000
# max    58984.930000   35.000000   17.162000     0.272000  747.000000

# %%
#now to seperate it based off of frequencies

# %%
df['Freq (GHz)'].unique()
# Out:
# array([ 1.26 ,  1.74 ,  5.   ,  7.   , 13.5  , 16.5  , 29.5  , 35.   ,
#         8.416,  4.868,  1.4  ,  1.78 ])

# %%
#data that wasn't complete
#	1.4			90
#[58765.29,	1.26			528],
#[58839.82,	5,			611],
#[58839.82,	7,			611

#frequency of 1.26 (also has some of 1.4)
f1_26 = ([58712.62,	1.26,	0.38,	0.09,	475],
         [58652.58,	1.26,	0.104,	0.0989,	415],
         [58627.98,	1.26,	0.0193,	0.086,	390],
         [58519.04,	1.26,	0.111,	0.109,	282],
         [58493.11,	1.26,	0.178,	0.151,	256],
         [58460.18,	1.26,	0.105,	0.111,	223],
         [58423.58,	1.26,	-0.108,	0.241,	186],
         [58379.44,	1.26,	1.033,	0.223,	142],
         [58368.43,	1.26,	0.971,	0.272,	131],
         [58347.5,	1.4,	0.22,	0.035,	110],
         [58278.58,	1.26,	3.704,	0.0571,	41],
         [58269.61,	1.26,	3.471,	0.0551,	32],
         [58260.96,	1.26,	1.576,	0.0616,	23],
         [58256.62,	1.26,	0.626,	0.0562,	19],
         [58250.64,	1.26,	0.114,	0.0474,	13],
         [58238.93,	1.26,	-0.0122,	0.0531,	1],
        )
#frequency of 1.74 (also has some of 1.78)
f1_74 = ([58765.29,	1.78,	0.0962,	0.066,	528],
         [58712.62,	1.78,	0.255,	0.067,	475],
         [58652.58,	1.78,	0.0834,	0.0396,	415],
         [58627.98,	1.78,	0.177,	0.044,	390],
         [58519.04,	1.74,	0.41,	0.0637,	282],
         [58493.11,	1.74,	0.402,	0.0811,	256],
         [58460.18,	1.74,	0.349,	0.0714,	223],
         [58423.58,	1.74,	0.511,	0.107,	186],
         [58379.44,	1.74,	0.417,	0.125,	142],
         [58368.43,	1.74,	0.85,	0.116,	131],
         [58278.58,	1.74,	3.746,	0.0413,	41],
         [58269.61,	1.74,	3.887,	0.0374,	32],
         [58260.96,	1.74,	2.015,	0.041,	23],
         [58256.62,	1.74,	0.948,	0.0424,	19],
         [58250.64,	1.74,	0.15,	0.0419,	13],
         [58238.93,	1.74,	0.0298,	0.0385,	1],
        )
#frequency of 5 (also has some of 4.868)
f5 = ([58984.93,	5,	0.0606,	0.016,	747],
      [58924.11,	5,	0.117,	0.022,	687],
      [58765.29,	5,	0.0426,	0.016,	528],
      [58712.62,	5,	0.075,	0.017,	475],
      [58652.58,	5,	0.165,	0.0134,	415],
      [58627.98,	5,	0.157,	0.0145,	390],
      [58519.04,	5,	0.492,	0.0127,	282],
      [58493.11,	5,	0.559,	0.0158,	256],
      [58460.18,	5,	0.766,	0.0137,	223],
      [58423.58,	5,	1.121,	0.0201,	186],
      [58379.44,	5,	1.637,	0.0158,	142],
      [58368.43,	5,	1.865,	0.017,	131],	
      [58323.5,	4.868,	1.2,	0.02,	86],
      [58283.6,	4.868,	3.57,	0.025,	46],
      [58278.58,	5,	4.419,	0.0123,	41],
      [58269.61,	5,	5.226,	0.0122,	32],
      [58260.96,	5,	4.523,	0.0134,	23],
      [58259.7,	4.868,	3.932,	0.0196,	22],
      [58256.62,	5,	3.227,	0.0131,	19],
      [58250.64,	5,	0.5,	0.0132,	13],
      [58246.67,	5,	0.232,	0.0125,	9],
      [58238.93,	5,	0.0152,	0.012,	1],
     )
#frequency of 7 (also has some of 8.416)
f7 = ([58984.93,	7,	0.062,	0.015,	747],
      [58924.11,	7,	0.088,	0.021,	687],
      [58765.29,	7,	0.0304,	0.016,	528],
      [58712.62,	7,	0.056,	0.02,	475],
      [58652.58,	7,	0.157,	0.0143,	415],
      [58627.98,	7,	0.176,	0.0143,	390],
      [58519.04,	7,	0.457,	0.0126,	282],
      [58493.11,	7,	0.589,	0.0186,	256],
      [58460.18,	7,	0.782,	0.0131,	223],
      [58423.58,	7,	1.165,	0.0165,	186],
      [58379.44,	7,	2.018,	0.0125,	142],
      [58368.43,	7,	2.333,	0.0126,	131],
      [58278.58,	7,	4.984,	0.0137,	41],
      [58280.64,	8.416,	1.98,	0.036,	43],
      [58269.61,	7,	5.994,	0.0134,	32],
      [58260.96,	7,	5.889,	0.0152,	23],
      [58256.62,	7,	4.202,	0.0214,	19],
      [58255.71,	8.416,	7.136,	0.0322,	18],
      [58250.64,	7,	0.751,	0.0147,	13],
      [58246.67,	7,	0.3,	0.0125,	9],
      [58238.93,	7,	-0.0184,	0.0143,	1],
     )
#frequency of 13.5
f13_5 = ([58984.93,	13.5,	0.0423,	0.017,	747],
         [58924.11,	13.5,	0.037,	0.017,	687],
         [58839.82,	13.5,	0.0592,	0.017,	611],
         [58711.46,	13.5,	0.032,	0.014,	474],
         [58658.62,	13.5,	0.0657,	0.0114,	419],
         [58628.64,	13.5,	0.139,	0.034,	391],
         [58496.01,	13.5,	0.521,	0.0114,	259],
         [58461.08,	13.5,	0.738,	0.0119,	224],
         [58423.19,	13.5,	1.2,	0.0127,	186],
         [58379.39,	13.5,	2.444,	0.0118,	142],
         [58368.38,	13.5,	3.017,	0.0111,	131],
         [58278.53,	13.5,	6.545,	0.012,	41],
         [58269.56,	13.5,	7.582,	0.0116,	32],
         [58255.65,	13.5,	7.378,	0.0135,	18],
         [58246.68,	13.5,	0.435,	0.0181,	9],
        )
#frequency of 16.5
f16_5 = ([58984.93,	16.5,	0.0532,	0.018,	747],
         [58924.11,	16.5,	0.024,	0.018,	687],
         [58839.82,	16.5,	0.0631,	0.018,	611],
         [58711.46,	16.5,	0.007,	0.015,	474],
         [58658.62,	16.5,	0.0483,	0.0201,	419],
         [58628.64,	16.5,	0.125,	0.0399,	391],
         [58496.01,	16.5,	0.529,	0.0118,	259],
         [58461.08,	16.5,	0.717,	0.0121,	224],
         [58423.19,	16.5,	1.207,	0.0117,	186],
         [58379.39,	16.5,	2.475,	0.0127,	142],
         [58368.38,	16.5,	3.089,	0.0125,	131],
         [58278.53,	16.5,	7.35,	0.0141,	41],
         [58269.56,	16.5,	8.545,	0.0131,	32],
         [58255.65,	16.5,	8.321,	0.0171,	18],
         [58246.68,	16.5,	0.342,	0.0186,	9],
        )
#frequency of 29.5
f29_5 = ([58984.93,	29.5,	0.0229,	0.037,	747],
         [58924.11,	29.5,	0.14,	0.036,	687],
         [58839.82,	29.5,	0.002,	0.04,	611],
         [58711.46,	29.5,	-0.033,	0.034,	474],
         [58658.62,	29.5,	0.104,	0.0352,	419],
         [58628.64,	29.5,	0.126,	0.0373,	391],
         [58496.01,	29.5,	0.426,	0.0266,	259],
         [58461.08,	29.5,	0.57,	0.0229,	224],
         [58423.19,	29.5,	1.068,	0.0241,	186],
         [58379.39,	29.5,	2.364,	0.0237,	142],
         [58368.38,	29.5,	3.164,	0.0266,	131],
         [58278.53,	29.5,	11.934,	0.0594,	41],
         [58269.56,	29.5,	14.418,	0.0485,	32],
         [58255.65,	29.5,	11.851,	0.0286,	18],
         [58246.68,	29.5,	0.968,	0.0239,	9],
        )
#frequency of 35
f35 = ([58984.93,	35,	0.008,	0.043,	747],
       [58924.11,	35,	0.05,	0.041,	687],
       [58839.82,	35,	0.02,	0.044,	611],
       [58711.46,	35,	-0.031,	0.043,	474],
       [58658.62,	35,	0.137,	0.0421,	419],
       [58628.64,	35,	-0.0704,	0.0471,	391],
       [58496.01,	35,	0.414,	0.0309,	259],
       [58461.08,	35,	0.593,	0.0273,	224],
       [58423.19,	35,	1.125,	0.0276,	186],
       [58379.39,	35,	2.193,	0.0256,	142],	
       [58368.38,	35,	3.116,	0.0338,	131],
       [58278.53,	35,	13.925,	0.07,	41],
       [58269.56,	35,	17.162,	0.0565,	32],
       [58255.65,	35,	12.991,	0.035,	18],
       [58246.68,	35,	0.913,	0.0231,	9],
      )

# %%
#Making the dataframe for each frequency

df1_26 =  pd.DataFrame(f1_26, columns = ["MJD",	"Freq (GHz)",	"Flux (mJy)",	"eFlux (mJy)",	"Days"])

df1_74 =  pd.DataFrame(f1_74, columns = ["MJD",	"Freq (GHz)",	"Flux (mJy)",	"eFlux (mJy)",	"Days"])

df5 =  pd.DataFrame(f5, columns = ["MJD",	"Freq (GHz)",	"Flux (mJy)",	"eFlux (mJy)",	"Days"])

df7 =  pd.DataFrame(f7, columns = ["MJD",	"Freq (GHz)",	"Flux (mJy)",	"eFlux (mJy)",	"Days"])

df13_5 =  pd.DataFrame(f13_5, columns = ["MJD",	"Freq (GHz)",	"Flux (mJy)",	"eFlux (mJy)",	"Days"])

df16_5 =  pd.DataFrame(f16_5, columns = ["MJD",	"Freq (GHz)",	"Flux (mJy)",	"eFlux (mJy)",	"Days"])

df29_5 =  pd.DataFrame(f29_5, columns = ["MJD",	"Freq (GHz)",	"Flux (mJy)",	"eFlux (mJy)",	"Days"])

df35 =  pd.DataFrame(f35, columns = ["MJD",	"Freq (GHz)",	"Flux (mJy)",	"eFlux (mJy)",	"Days"])

# %%
#Defining the lists of each frequencies days, flux, and error in flux to make it easier to graph

days1_26 = df1_26['Days']
flux1_26 = df1_26["Flux (mJy)"]
flux_err1_26 = np.sqrt((df1_26["eFlux (mJy)"])**2 + (df1_26["Flux (mJy)"]*0.05)**2)

days1_74 = df1_74['Days']
flux1_74 = df1_74["Flux (mJy)"]
flux_err1_74 = np.sqrt(df1_74["eFlux (mJy)"]**2 + (df1_74["Flux (mJy)"]*0.05)**2)

days5 = df5['Days']
flux5 = df5["Flux (mJy)"]
flux_err5 = np.sqrt(df5["eFlux (mJy)"]**2 + (df5["Flux (mJy)"]*0.05)**2)

days7 = df7['Days']
flux7 = df7["Flux (mJy)"]
flux_err7 = np.sqrt(df7["eFlux (mJy)"]**2 + (df7["Flux (mJy)"]*0.05)**2)

days13_5 = df13_5['Days']
flux13_5 = df13_5["Flux (mJy)"]
flux_err13_5 = np.sqrt(df13_5["eFlux (mJy)"]**2 + (df13_5["Flux (mJy)"]*0.1)**2)

days16_5 = df16_5['Days']
flux16_5 = df16_5["Flux (mJy)"]
flux_err16_5 = np.sqrt(df16_5["eFlux (mJy)"]**2 + (df16_5["Flux (mJy)"]*0.1)**2)

days29_5 = df29_5['Days']
flux29_5 = df29_5["Flux (mJy)"]
flux_err29_5 = np.sqrt(df29_5["eFlux (mJy)"]**2 + (df29_5["Flux (mJy)"]*0.1)**2)

days35 = df35['Days']
flux35 = df35["Flux (mJy)"]
flux_err35 = np.sqrt(df35["eFlux (mJy)"]**2 + (df35["Flux (mJy)"]*0.1)**2)

# %%
df5
# Out:
#          MJD  Freq (GHz)  Flux (mJy)  eFlux (mJy)  Days
# 0   58984.93       5.000      0.0606       0.0160   747
# 1   58924.11       5.000      0.1170       0.0220   687
# 2   58765.29       5.000      0.0426       0.0160   528
# 3   58712.62       5.000      0.0750       0.0170   475
# 4   58652.58       5.000      0.1650       0.0134   415
# 5   58627.98       5.000      0.1570       0.0145   390
# 6   58519.04       5.000      0.4920       0.0127   282
# 7   58493.11       5.000      0.5590       0.0158   256
# 8   58460.18       5.000      0.7660       0.0137   223
# 9   58423.58       5.000      1.1210       0.0201   186
# 10  58379.44       5.000      1.6370       0.0158   142
# 11  58368.43       5.000      1.8650       0.0170   131
# 12  58323.50       4.868      1.2000       0.0200    86
# 13  58283.60       4.868      3.5700       0.0250    46
# 14  58278.58       5.000      4.4190       0.0123    41
# 15  58269.61       5.000      5.2260       0.0122    32
# 16  58260.96       5.000      4.5230       0.0134    23
# 17  58259.70       4.868      3.9320       0.0196    22
# 18  58256.62       5.000      3.2270       0.0131    19
# 19  58250.64       5.000      0.5000       0.0132    13
# 20  58246.67       5.000      0.2320       0.0125     9
# 21  58238.93       5.000      0.0152       0.0120     1

# %%
np.max(flux5)
# Out:
# 5.226

# %%
#defining the figure and fig size
fig, ax = plt.subplots()
fig.set_size_inches(12,10)

# Store which labels have already been used
used_labels = set()

#function to sort the non-detections vs the detections
def plot(days, fluxes, errors, color, label_name):
    for day, flux, err in zip(days, fluxes, errors):
        if flux < 3 * err:
            fmt = 'x'  # square for non-detection
            label = None  # no label for non-detections

            ax.errorbar(day, (flux+3*err), fmt=fmt, color=color, label=label)
            
        else:
            fmt = '^'  # triangle for detection
            label = label_name if label_name not in used_labels else None
        
            ax.errorbar(day, flux, yerr=err, fmt=fmt, color=color, label=label)
        
        if label:
            used_labels.add(label)

# Plot each band
plot(days1_26, flux1_26, flux_err1_26, 'orange', '1.26 GHz')
plot(days1_74, flux1_74, flux_err1_74, 'red', '1.74 GHz')

plot(days5, flux5, flux_err5, 'green', '5 GHz')
plot(days7, flux7, flux_err7, 'blue', '7 GHz')

plot(days13_5, flux13_5, flux_err13_5, 'purple', '13.5 GHz')
plot(days16_5, flux16_5, flux_err16_5, 'hotpink', '16.5 GHz')

plot(days29_5, flux29_5, flux_err29_5, 'black', '29.5 GHz')
plot(days35, flux35, flux_err35, 'grey', '35 GHz')


# Final plot formatting
ax.set_xscale('log')
ax.set_xticks([10,20,50,100,500,1000], labels = ['10','20','50','100','500', '1000'], fontsize = 20)
ax.set_yscale('log')
ax.set_yticks([.1, 1,10, 100], labels = [r'$10^{-1}$',r'$10^{0}$',r'$10^{1}$', r'$10^{2}$'], fontsize = 20)
ax.set_xlabel("Time since eruption (days)", fontsize = 25)
ax.set_ylabel("Flux Density (mJy)", fontsize = 25)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

ax.set_title("")
plt.legend(fontsize = 15)
plt.savefig("V392Per_lc.png")
plt.show()

# %%
df5
# Out:
#          MJD  Freq (GHz)  Flux (mJy)  eFlux (mJy)  Days
# 0   58984.93       5.000      0.0606       0.0160   747
# 1   58924.11       5.000      0.1170       0.0220   687
# 2   58765.29       5.000      0.0426       0.0160   528
# 3   58712.62       5.000      0.0750       0.0170   475
# 4   58652.58       5.000      0.1650       0.0134   415
# 5   58627.98       5.000      0.1570       0.0145   390
# 6   58519.04       5.000      0.4920       0.0127   282
# 7   58493.11       5.000      0.5590       0.0158   256
# 8   58460.18       5.000      0.7660       0.0137   223
# 9   58423.58       5.000      1.1210       0.0201   186
# 10  58379.44       5.000      1.6370       0.0158   142
# 11  58368.43       5.000      1.8650       0.0170   131
# 12  58323.50       4.868      1.2000       0.0200    86
# 13  58283.60       4.868      3.5700       0.0250    46
# 14  58278.58       5.000      4.4190       0.0123    41
# 15  58269.61       5.000      5.2260       0.0122    32
# 16  58260.96       5.000      4.5230       0.0134    23
# 17  58259.70       4.868      3.9320       0.0196    22
# 18  58256.62       5.000      3.2270       0.0131    19
# 19  58250.64       5.000      0.5000       0.0132    13
# 20  58246.67       5.000      0.2320       0.0125     9
# 21  58238.93       5.000      0.0152       0.0120     1

# %%
print(flux_err5)
# Out:
# 0     0.016284
# 1     0.022765
# 2     0.016141
# 3     0.017409
# 4     0.015736
# 5     0.016489
# 6     0.027685
# 7     0.032107
# 8     0.040677
# 9     0.059545
# 10    0.083361
# 11    0.094787
# 12    0.063246
# 13    0.180242
# 14    0.221292
# 15    0.261585
# 16    0.226547
# 17    0.197575
# 18    0.161881
# 19    0.028271
# 20    0.017053
# 21    0.012024
# dtype: float64

# %%
v392_opt_unflitered = pd.read_csv('aavsodata_690fd00e1c36e.txt', header = 0)

#now to get only the vband

column_name = 'Band'
key = 'V'

v392_opt_kinda = v392_opt_unflitered[v392_opt_unflitered[column_name].str.contains(key, na=False)]

v392_opt_close = v392_opt_kinda[~v392_opt_kinda[column_name].str.contains('Vis.|CV', na=False)]

v392_opt =  v392_opt_close[~v392_opt_kinda["Magnitude"].str.contains('<9.1|<14.360', na=False)]

v392_opt
# Out:
# C:\Users\wilhe\AppData\Local\Temp\ipykernel_28600\1777685986.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   v392_opt =  v392_opt_close[~v392_opt_kinda["Magnitude"].str.contains('<9.1|<14.360', na=False)]
#                 JD Magnitude  Uncertainty  HQuncertainty Band Observer Code  \
# 0     2.458238e+06     6.340        0.002            NaN    V           TRT
# 11    2.458238e+06     6.537        0.037            NaN    V           MIW
# 24    2.458239e+06     7.248        0.070            NaN    V          PMAK
# 27    2.458239e+06      7.27        0.020            NaN    V          VMAG
# 37    2.458239e+06     7.377        0.028            NaN    V           VOL
# ...            ...       ...          ...            ...  ...           ...
# 3928  2.458947e+06    14.776        0.033            NaN    V           DEY
# 3932  2.458956e+06    14.829        0.010            NaN    V           DEY
# 3935  2.458957e+06    14.762        0.009            NaN    V           DEY
# 3938  2.458959e+06    14.682        0.010            NaN    V           DEY
# 3942  2.458972e+06    14.639        0.021            NaN    V           DEY
#
#      Comment Code(s)  Comp Star 1       Comp Star 2     Charts  ...    Cmag  \
# 0                NaN           93               132  X22784DEC  ...  13.796
# 11               NaN     ENSEMBLE               132   X22884OW  ...     NaN
# 24               NaN     ENSEMBLE  87 (000-BMQ-783)    X22891P  ...     NaN
# 27               NaN  000-BBH-327       000-BBH-307  X22891BPS  ...   9.340
# 37               NaN           81                84   X22891BQ  ...   8.095
# ...              ...          ...               ...        ...  ...     ...
# 3928             NaN  000-BBH-306               NaN   X25161AS  ... -12.066
# 3932             NaN  000-BBH-306               NaN   X25161AS  ... -12.165
# 3935             NaN  000-BBH-306               NaN   X25161AS  ... -12.126
# 3938             NaN  000-BBH-306               NaN   X25161AS  ... -12.066
# 3942             NaN  000-BBH-306               NaN   X25161AS  ... -11.891
#
#         Kmag HJD  Star Name  Observer Affiliation  Measurement Method  \
# 0     17.752 NaN   V392 PER                  MCSE                 STD
# 11    13.209 NaN   V392 PER               BAA-VSS                 STD
# 24     8.795 NaN   V392 PER                 AAVSO                 STD
# 27    13.230 NaN  V0392 PER                 AAVSO                 STD
# 37     8.432 NaN   V392 PER                 AAVSO                 STD
# ...      ...  ..        ...                   ...                 ...
# 3928     NaN NaN   V392 PER                 AAVSO                 STD
# 3932     NaN NaN   V392 PER                 AAVSO                 STD
# 3935     NaN NaN   V392 PER                 AAVSO                 STD
# 3938     NaN NaN   V392 PER                 AAVSO                 STD
# 3942     NaN NaN   V392 PER                 AAVSO                 STD
#
#       Grouping Method ADS Reference Digitizer Credit
# 0                 NaN           NaN       NaN    NaN
# 11                NaN           NaN       NaN    NaN
# 24                NaN           NaN       NaN    NaN
# 27                NaN           NaN       NaN    NaN
# 37                NaN           NaN       NaN    NaN
# ...               ...           ...       ...    ...
# 3928               13           NaN       NaN    NaN
# 3932               11           NaN       NaN    NaN
# 3935               12           NaN       NaN    NaN
# 3938               13           NaN       NaN    NaN
# 3942               14           NaN       NaN    NaN
#
# [359 rows x 24 columns]

# %%
#MJD/t0 = 58238
#JD = 2458238

opticaldays = ((v392_opt['JD'].astype(float)) - 2458238)
vmag = v392_opt['Magnitude'].astype(float)
error_vmag = v392_opt['Uncertainty'].astype(float)

# %%
fig, ax = plt.subplots()

fig.set_size_inches(12,8)

ax.errorbar(opticaldays, vmag, yerr=error_vmag, fmt='.', color='black')

ax.set_xscale('log')
ax.set_xticks([1, 10,20,40,60,100, 200], labels = ['1','10','20', '40', '60','100', '200'], fontsize = 20)
#ax.set_yscale('log')
#ax.set_yticks([0.1,1], labels = [r], fontsize = 20)
ax.invert_yaxis()
ax.set_xlabel("Time since eruption (days)", fontsize = 25)
ax.set_ylabel("V mag ()", fontsize = 25)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

ax.set_title("")
plt.show();

# %%
#detection list 

mask0 =  df1_74['Flux (mJy)'] > 3 * np.sqrt(df1_74["eFlux (mJy)"]**2 + (df1_74["Flux (mJy)"]*0.05)**2) #don't show the non-detections
days1_74d = df1_74['MJD'][mask0] - 58238
flux1_74d = df1_74["Flux (mJy)"][mask0]
flux_err1_74d = np.sqrt(df1_74["eFlux (mJy)"][mask0]**2 + (df1_74["Flux (mJy)"][mask0]*0.05)**2)

mask0 =  df5['Flux (mJy)'] > 3 * np.sqrt(df5["eFlux (mJy)"]**2 + (df5["Flux (mJy)"]*0.05)**2) #don't show the non-detections
days5d = df5['MJD'][mask0] - 58238
flux5d = df5["Flux (mJy)"][mask0]
flux_err5d = np.sqrt(df5["eFlux (mJy)"][mask0]**2 + (df5["Flux (mJy)"][mask0]*0.05)**2)

mask0 =  df13_5['Flux (mJy)'] > 3 * np.sqrt(df13_5["eFlux (mJy)"]**2 + (df13_5["Flux (mJy)"]*0.1)**2) #don't show the non-detections
days13_5d = df13_5['MJD'][mask0] - 58238
flux13_5d = df13_5["Flux (mJy)"][mask0]
flux_err13_5d = np.sqrt(df13_5["eFlux (mJy)"][mask0]**2 + (df13_5["Flux (mJy)"][mask0]*0.1)**2)

mask0 =  df29_5['Flux (mJy)'] > 3 * np.sqrt(df29_5["eFlux (mJy)"]**2 + (df29_5["Flux (mJy)"]*0.1)**2) #don't show the non-detections
days29_5d = df29_5['MJD'][mask0] - 58238
flux29_5d = df29_5["Flux (mJy)"][mask0]
flux_err29_5d = np.sqrt(df29_5["eFlux (mJy)"][mask0]**2 + (df29_5["Flux (mJy)"][mask0]*0.1)**2)

# %%
#non detection list

mask0 =  df1_74['Flux (mJy)'] < 3 * np.sqrt(df1_74["eFlux (mJy)"]**2 + (df1_74["Flux (mJy)"]*0.05)**2) #don't show the non-detections
days1_74nd = df1_74['MJD'][mask0] - 58238
flux1_74nd = df1_74["Flux (mJy)"][mask0]
flux_err1_74nd = np.sqrt(df1_74["eFlux (mJy)"][mask0]**2 + (df1_74["Flux (mJy)"][mask0]*0.05)**2)

mask0 =  df5['Flux (mJy)'] < 3 * np.sqrt(df5["eFlux (mJy)"]**2 + (df5["Flux (mJy)"]*0.05)**2) #don't show the non-detections
days5nd = df5['MJD'][mask0] - 58238
flux5nd = df5["Flux (mJy)"][mask0]
flux_err5nd = np.sqrt(df5["eFlux (mJy)"][mask0]**2 + (df5["Flux (mJy)"][mask0]*0.05)**2)

mask0 =  df13_5['Flux (mJy)'] < 3 * np.sqrt(df13_5["eFlux (mJy)"]**2 + (df13_5["Flux (mJy)"]*0.1)**2) #don't show the non-detections
days13_5nd = df13_5['MJD'][mask0] - 58238
flux13_5nd = df13_5["Flux (mJy)"][mask0]
flux_err13_5nd = np.sqrt(df13_5["eFlux (mJy)"][mask0]**2 + (df13_5["Flux (mJy)"][mask0]*0.1)**2)

mask0 =  df29_5['Flux (mJy)'] < 3 * np.sqrt(df29_5["eFlux (mJy)"]**2 + (df29_5["Flux (mJy)"]*0.1)**2) #don't show the non-detections
days29_5nd = df29_5['MJD'][mask0] - 58238
flux29_5nd = df29_5["Flux (mJy)"][mask0]
flux_err29_5nd = np.sqrt(df29_5["eFlux (mJy)"][mask0]**2 + (df29_5["Flux (mJy)"][mask0]*0.1)**2)

# %%
plt.style.use('tableau-colorblind10')

from matplotlib.ticker import AutoMinorLocator

fig, axs = plt.subplots(2, 1, figsize=(10, 10), sharey=False, sharex = True)#, constrained_layout=True)


#first the visual
axs[0].scatter(opticaldays, vmag, marker = '.', color = 'black')
axs[0].annotate('V392 Per (2021)',(90,6), fontsize=15)

axs[0].set_xscale('log')
#axs[0].set_yscale('log')

axs[0].set_ylabel('Visual Brightness (mag)',fontsize =20)

axs[0].set_yticks([4,6,8,10,12,14, 16], labels = [r'$4$',r'$6$',r'$8$',r'$10$', r'$12$', r'$14$', r'$16$'], fontsize = 18)
axs[0].invert_yaxis()
axs[0].tick_params(which='minor', length=4, direction = 'in', top=True, labeltop=False, left=True, labelleft=False, bottom=True, labelbottom=False, right = True,labelright = False)
axs[0].yaxis.set_minor_locator(AutoMinorLocator(2))  # 2 minor intervals between major ticks
axs[0].tick_params(which='major', length=7, direction = 'in', width =1, top=True, labeltop=False, bottom=True, labelbottom=False, right = True, labelright = False)


#now the radio
axs[1].set_ylabel('Flux Density (mJy)',fontsize=20)
axs[1].set_xlabel('Time Since Eruption (Days)', fontsize=20)
axs[1].set_xscale('log')
axs[1].set_yscale('log')


axs[1].errorbar(days1_74d, flux1_74d, yerr=flux_err1_74d, linestyle ='--', fmt = '*' , markersize = 8.5, label='1.74 GHz')

axs[1].errorbar(days5d, flux5d, yerr=flux_err5d, linestyle ='--', fmt = '*', markersize = 8.5, label='5.00 GHz')

axs[1].errorbar(days13_5d, flux13_5d, yerr=flux_err13_5d, linestyle ='--', fmt = '*' , label='13.50 GHz')

axs[1].errorbar(days29_5d, flux29_5d, yerr=flux_err29_5d, linestyle ='--', fmt = '*' , markersize = 8.5, label='29.50 GHz')



axs[1].scatter(days1_74nd, flux1_74nd , marker = 'v')

axs[1].scatter(days5nd, flux5nd , marker = 'v')

axs[1].scatter(days13_5nd, flux13_5nd , marker = 'v')

axs[1].scatter(days29_5nd, flux29_5nd , marker = 'v')




axs[1].legend(fontsize=15)

axs[1].set_xticks([1, 10,100, 500], labels = ['1', '10','100', '500'], fontsize = 18)
axs[1].set_yticks([0.01,0.1, 1, 10], labels = [r'$0.01$',r'$0.1$',r'$1$', r'$10$'], fontsize = 18)
#axs[1].set_ylim(bottom=0.5, top=150)

axs[1].tick_params(which='minor', length =4, direction = 'in', top=True, labeltop=False, bottom=True, labelbottom=False, right = True,labelright = False)
axs[1].tick_params(which='major', length=7, direction = 'in', width =1, top=True, labeltop=False, bottom=True, labelbottom=True, right = True, labelright = False)


fig.subplots_adjust(hspace=0.05)
plt.savefig("V392_Optical_and_Radio_lightcurves.png")
plt.show();
