# %% [markdown]
# V407 Cyg lightcurve

# %%
#imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Making the dataframe based off of data provided with v407cyg.dat
#there were some issues when trying to import it in and read it with pandas

# %%
data = (
    [55284.8,    2.0,  1.5, -0.124,  0.720,  0.000,  0.050], #'AL733',   'D *non detection']
    [55289.7,    3.0,  1.4,  2.980,  0.500,  0.000,  0.050], #'AS1039',	'D']
    [55298.7,    5.0,  1.4,  4.040,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55301.7,    6.0,  1.4,  3.597,  0.330,  0.000,  0.050], #'AS1039',	'D']
    [55304.7 ,   7.0 , 1.4,  4.780,  0.300,  0.000,  0.050], #'AS1039',	'D]
    [55308.7  ,  8.0  ,1.4,  5.482,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55311.7  ,  9.0 , 1.4,  5.780,  0.320,  0.000,  0.050], #'AS1039',	'D']
    [55315.6,   10.0  ,1.4,  5.944, 0.260,  0.000,  0.050], #'AS1039',	'D']
    [55318.6,   11.0  ,1.4,  5.760, 0.280,  0.000,  0.050], #'AS1039',	'D']
    [55323.6,   12.0  ,1.4,  6.441,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55330.5 ,  13.0  ,1.4,  5.355,  0.280,  0.000,  0.050], #'AS1039',	'D']
    [55332.6 ,  14.0  ,1.4,  5.803,  0.280,  0.000,  0.050], #'AS1039',	'D']	
    [55341.6 ,  15.0  ,1.4,  5.853,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55345.6 ,  16.0  ,1.4,  5.828,  0.290,  0.000,  0.050], #'AS1039',	'D']
    [55362.5 ,  17.0,	1.4,  5.606,  0.260,  0.000,  0.050], #'AS1039',	'D']
    [55367.6,	  18.0,	1.4,  5.763,  0.330,  0.000,  0.050], #'AS1039',	'D']
    [55368.5,	  19.0,	1.4,  5.905,  0.290,  0.000,  0.050], #'AS1039',	'D']
    [55404.4 ,  20.0,  1.4,  6.917,  0.280,  0.000,  0.050], #'10B-233', 'D']
    [55419.4,	  21.0,	1.4,  7.924,  0.330,  0.000,  0.050],	#'10B-233', 'D']
    [55434.3,	  22.0,	1.4,  5.489,  0.260,  0.000,  0.050], #'10B-233', 'D']
    [55449.2,	  23.0, 	1.4,  5.608,  0.240,  0.000,  0.050], #'10B-233', 'D']
    [55469.2,	  24.0,	1.4,  5.582,  0.145,  0.000,  0.050], #'10B-233', 'DnC']
    [55625.4 ,  25.0 , 1.3,  4.220,  0.163,  0.000,  0.050], #'11A-254', 'B']
    [55735.4 ,  26.0,  1.3,  3.596,  0.081,  0.000,  0.050], #'11A-254', 'A']
    [55869.1 ,  27.0,  1.3,  3.642,  0.534,  0.000,  0.050], #'11B-170', 'D']
    [55934.8 ,  28.0,  1.3,  4.688,  1.020,  0.000,  0.050], #'11B-170', 'DnC *held width constant']
    [56035.4 ,  29.0,  1.3,  2.940,  0.301,  0.000,  0.050], #'11B-170', 'C']

    [55284.8,    2.0,  1.9,  1.930,  0.525,  0.000,  0.050],  #held width constant
    [55289.7,    3.0,  1.8,  3.469,  0.350,  0.000,  0.050],
    [55298.7,    5.0,  1.8,  4.762,  0.300,  0.000,  0.050],
    [55301.7,    6.0,  1.8,  5.466,  0.300,  0.000,  0.050],
    [55304.7,    7.0,  1.8,  5.512,  0.350,  0.000,  0.050],
    [55308.7,    8.0,  1.8,  6.662,  0.330,  0.000,  0.050],
    [55311.7,    9.0,  1.8,  6.841,  0.300,  0.000,  0.050],
    [55404.3,   20.0, 25.0, 13.636,  0.105,  0.015,  0.100],
    [55419.4,	  21.0, 25.0, 13.297,  0.084,  0.013,  0.100],
    [55434.3,	  22.0, 25.0, 11.200,  0.055,  0.008,  0.100],
    [55449.3,	  23.0, 25.0,  9.506,  0.081,  0.020,  0.100],
    [55469.2,	  24.0, 25.0, 10.082,  0.068,  0.066,  0.100],
    [55625.4,   25.0, 25.6,  4.744,  0.033,  0.000,  0.100],
    [55735.4,	  26.0, 25.6,  2.620,  0.048,  0.000,  0.100],
    [55869.1,   27.0, 25.6,  3.828,  0.000,  0.047,  0.100],
    [55934.8,   28.0, 25.6,  2.992,  0.057,  0.000,  0.100],
    [56035.4,   29.0, 25.6,  2.970,  0.052,  0.000,  0.100],

    [55298.7,    5.0, 41.0, 59.890,  0.000, 0.890,  0.200],
    [55327.6,   13.0, 41.0, 51.340,  0.000,  0.750,  0.200],
    [55332.5,   14.0, 41.0, 44.900,  0.000,  0.620,  0.200],
    [55341.5,   15.0, 41.0, 39.970,  0.000,  0.560,  0.200],
    [55345.5,   16.0, 41.0, 37.050,  0.000,  0.570,  0.200],
    [55368.5,	  19.0, 41.0, 25.944,  0.000,  0.646,  0.200],
    [55404.3,	  20.0, 41.0, 18.670,  0.000,  0.831,  0.200],
    [55419.4,	  21.0, 41.0, 12.392,  0.000,  0.479,  0.200],
    [55434.3,	  22.0, 41.0, 14.580,  0.000,  0.586,  0.200],
    [55449.3,	  23.0, 41.0,  9.662,  0.000,  0.845,  0.200],
    [55469.2,	  24.0, 41.0, 14.189,  0.000,  0.640,  0.200],
    [55625.4,   25.0, 41.0,  5.303,  0.000,  0.181,  0.200],
    [55735.4,   26.0, 41.0,  4.249,  0.000,  0.171,  0.200],
    [55869.1,   27.0, 41.0,  4.323,  0.000,  0.124,  0.200],
    [55934.8,   28.0, 41.0,  3.959,  0.000,  0.232,  0.200],
    [56035.4,   29.0, 41.0,  2.879,  0.000,  0.165,  0.200],

    [55298.7,    5.0, 45.0, 65.630,  0.000,  1.160,  0.200],
    [55327.6,   13.0, 45.0, 50.660,  0.000,  0.750,  0.200],
    [55332.5,   14.0, 45.0, 46.310,  0.000,  0.620,  0.200],
    [55341.5,   15.0, 45.0, 38.400,  0.000,  0.640,  0.200],
    [55345.5,   16.0, 45.0, 35.880,  0.000,  0.600,  0.200],
    [55368.5,	  19.0, 45.0, 28.133,  0.000,  0.771,  0.200],
    [55404.3,	  20.0, 45.0, 18.608,  0.000,  0.972,  0.200],
    [55419.4,	  21.0, 45.0, 13.509,  0.000,  0.522,  0.200],
    [55434.3,	  22.0, 45.0, 15.120,  0.000,  0.595,  0.200],
    [55449.3,	  23.0, 45.0,  9.093,  0.000,  0.783,  0.200],
    [55469.2,	  24.0, 45.0, 12.754,  0.000,  0.689,  0.200],
    [55625.4,   25.0, 45.0,  5.445,  0.000,  0.238,  0.200],
    [55735.4,   26.0, 45.0,  4.445,  0.000,  0.237,  0.200],
    [55869.1,   27.0, 45.0,  4.466,  0.000,  0.162,  0.200],
    [55934.8,   28.0, 45.0,  5.225,  0.000,  0.373,  0.200],
    [56035.4,   29.0, 45.0,  2.660,  0.000,  0.247,  0.200],

    #[55289.7    3.0 49.0 44.980  0.000  1.590  0.500]
    #[55308.6    6.0 49.0 82.500  0.000  0.000  0.200] 


    [55277.5,   -1.0,  8.35, 8.500,  0.000,  0.800,  0.100], # ATel 2506
    [55277.5,   -1.0, 10.45, 11.60,  0.000,  0.900,  0.100], 
    [55277.5,   -1.0, 14.60, 14.60,  0.000,  1.200,  0.100], 
    [55277.5,   -1.0, 15.00, 24.10,  0.000,  1.700,  0.100],
    [55277.5,   -1.0, 142.0, 146.0,  0.000,  51.00,  0.100],
    )

df = pd.DataFrame(data, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

# %%
df
# Out:
#          MJD  Epoch    Freq     Flux  Error1 (gaussfit)  Error2 (image)  \
# 0    55284.8    2.0    1.50   -0.124               0.72             0.0
# 1    55289.7    3.0    1.40    2.980               0.50             0.0
# 2    55298.7    5.0    1.40    4.040               0.30             0.0
# 3    55301.7    6.0    1.40    3.597               0.33             0.0
# 4    55304.7    7.0    1.40    4.780               0.30             0.0
# ..       ...    ...     ...      ...                ...             ...
# 192  55277.5   -1.0    8.35    8.500               0.00             0.8
# 193  55277.5   -1.0   10.45   11.600               0.00             0.9
# 194  55277.5   -1.0   14.60   14.600               0.00             1.2
# 195  55277.5   -1.0   15.00   24.100               0.00             1.7
# 196  55277.5   -1.0  142.00  146.000               0.00            51.0
#
#      Error3 (calibration) (%)
# 0                        0.05
# 1                        0.05
# 2                        0.05
# 3                        0.05
# 4                        0.05
# ..                        ...
# 192                      0.10
# 193                      0.10
# 194                      0.10
# 195                      0.10
# 196                      0.10
#
# [197 rows x 7 columns]

# %%
MJD = df["MJD"]

days = MJD-55265

# %%
days
# Out:
# 0      19.8
# 1      24.7
# 2      33.7
# 3      36.7
# 4      39.7
#        ...
# 192    12.5
# 193    12.5
# 194    12.5
# 195    12.5
# 196    12.5
# Name: MJD, Length: 197, dtype: float64

# %%
flux = df["Flux"]
flux_err = df["Error1 (gaussfit)"]

# %%
flux
# Out:
# 0       -0.124
# 1        2.980
# 2        4.040
# 3        3.597
# 4        4.780
#         ...
# 192      8.500
# 193     11.600
# 194     14.600
# 195     24.100
# 196    146.000
# Name: Flux, Length: 197, dtype: float64

# %%
flux_err
# Out:
# 0      0.72
# 1      0.50
# 2      0.30
# 3      0.33
# 4      0.30
#        ...
# 192    0.00
# 193    0.00
# 194    0.00
# 195    0.00
# 196    0.00
# Name: Error1 (gaussfit), Length: 197, dtype: float64

# %%
fig,ax = plt.subplots()

ax.plot(days,flux, '.')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel("Days")
ax.set_ylabel("Flux Density (mJy)")
ax.set_title("")
plt.show()

# %%
f1_5 = (
    [55284.8,    2.0,  1.5, -0.124,  0.720,  0.000,  0.050],
)#'AL733',   'D *non detection']

f1_4 = (
    [55289.7,    3.0,  1.4,  2.980,  0.500,  0.000,  0.050], #'AS1039',	'D']
    [55298.7,    5.0,  1.4,  4.040,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55301.7,    6.0,  1.4,  3.597,  0.330,  0.000,  0.050], #'AS1039',	'D']
    [55304.7 ,   7.0 , 1.4,  4.780,  0.300,  0.000,  0.050], #'AS1039',	'D]
    [55308.7  ,  8.0  ,1.4,  5.482,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55311.7  ,  9.0 , 1.4,  5.780,  0.320,  0.000,  0.050], #'AS1039',	'D']
    [55315.6,   10.0  ,1.4,  5.944, 0.260,  0.000,  0.050], #'AS1039',	'D']
    [55318.6,   11.0  ,1.4,  5.760, 0.280,  0.000,  0.050], #'AS1039',	'D']
    [55323.6,   12.0  ,1.4,  6.441,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55330.5 ,  13.0  ,1.4,  5.355,  0.280,  0.000,  0.050], #'AS1039',	'D']
    [55332.6 ,  14.0  ,1.4,  5.803,  0.280,  0.000,  0.050], #'AS1039',	'D']	
    [55341.6 ,  15.0  ,1.4,  5.853,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55345.6 ,  16.0  ,1.4,  5.828,  0.290,  0.000,  0.050], #'AS1039',	'D']
    [55362.5 ,  17.0,	1.4,  5.606,  0.260,  0.000,  0.050], #'AS1039',	'D']
    [55367.6,	  18.0,	1.4,  5.763,  0.330,  0.000,  0.050], #'AS1039',	'D']
    [55368.5,	  19.0,	1.4,  5.905,  0.290,  0.000,  0.050], #'AS1039',	'D']
    [55404.4 ,  20.0,  1.4,  6.917,  0.280,  0.000,  0.050], #'10B-233', 'D']
    [55419.4,	  21.0,	1.4,  7.924,  0.330,  0.000,  0.050],	#'10B-233', 'D']
    [55434.3,	  22.0,	1.4,  5.489,  0.260,  0.000,  0.050], #'10B-233', 'D']
    [55449.2,	  23.0, 	1.4,  5.608,  0.240,  0.000,  0.050], #'10B-233', 'D']
    [55469.2,	  24.0,	1.4,  5.582,  0.145,  0.000,  0.050])#'10B-233', 'DnC']

f1_3 = (
    [55625.4 ,  25.0 , 1.3,  4.220,  0.163,  0.000,  0.050], #'11A-254', 'B']
    [55735.4 ,  26.0,  1.3,  3.596,  0.081,  0.000,  0.050], #'11A-254', 'A']
    [55869.1 ,  27.0,  1.3,  3.642,  0.534,  0.000,  0.050], #'11B-170', 'D']
    [55934.8 ,  28.0,  1.3,  4.688,  1.020,  0.000,  0.050], #'11B-170', 'DnC *held width constant']
    [56035.4 ,  29.0,  1.3,  2.940,  0.301,  0.000,  0.050]) #'11B-170', 'C']

f1_9 = (
    [55284.8,    2.0,  1.9,  1.930,  0.525,  0.000,  0.050],)  #held width constant

f1_8 = (
    [55289.7,    3.0,  1.8,  3.469,  0.350,  0.000,  0.050],
    [55298.7,    5.0,  1.8,  4.762,  0.300,  0.000,  0.050],
    [55301.7,    6.0,  1.8,  5.466,  0.300,  0.000,  0.050],
    [55304.7,    7.0,  1.8,  5.512,  0.350,  0.000,  0.050],
    [55308.7,    8.0,  1.8,  6.662,  0.330,  0.000,  0.050],
    [55311.7,    9.0,  1.8,  6.841,  0.300,  0.000,  0.050],
    [55315.6,   10.0,  1.8,  7.376,  0.290,  0.000,  0.050],
    [55318.6 ,  11.0,  1.8,  7.478,  0.260,  0.000,  0.050],
    [55323.6,   12.0,  1.8,  7.657,  0.330,  0.000,  0.050],
    [55330.5,   13.0,  1.8,  6.651,  0.270,  0.000,  0.050],
    [55332.6,   14.0,  1.8,  7.574,  0.260,  0.000,  0.050],
    [55341.6,   15.0,  1.8,  8.049,  0.260,  0.000,  0.050],
    [55345.6,   16.0,  1.8,  7.532,  0.280,  0.000 , 0.050],
    [55362.5,   17.0,	1.8,  7.540,  0.240,  0.000,  0.050],
    [55315.6,   10.0, 19.0, 33.032,  0.095,  0.011,  0.100],
    [55318.6,   11.0, 19.0, 29.067,  0.108,  0.018,  0.100],
    [55323.6,   12.0, 19.0, 27.774,  0.079,  0.014,  0.100],
    [55327.6,   13.0, 19.0, 28.251,  0.073,  0.010,  0.100],
    [55332.5,   14.0, 19.0, 28.752,  0.089,  0.012,  0.100],
    [55341.5,	  15.0, 19.0, 28.360,  0.082,  0.013,  0.100],
    [55345.5,   16.0, 19.0, 26.717,  0.074,  0.016,  0.100],
    [55368.5,	  19.0, 19.0, 23.036,  0.106,  0.013,  0.100],
    [55404.3,   20.0, 19.0, 14.867,  0.137,  0.013,  0.100],
    [55419.4,	  21.0, 19.0, 13.256,  0.092,  0.008,  0.100],
    [55434.3,	  22.0, 19.0, 11.867,  0.089,  0.010,  0.100],
    [55449.3,	  23.0, 19.0, 10.008,  0.080,  0.011,  0.100],
    [55469.2,	  24.0, 19.0,  9.864,  0.066,  0.059,  0.100])

f20_1 = (
    [55625.4,   25.0, 20.1,  4.652,  0.033,  0.000,  0.100],
    [55735.4,	  26.0, 20.1,  2.542,  0.040,  0.000,  0.100],
    [55869.1,   27.0, 20.1,  3.672,  0.000,  0.038,  0.100],
    [55934.8,   28.0, 20.1,  3.140,  0.047,  0.000,  0.100],
    [56035.4,   29.0, 20.1,  2.914,  0.040,  0.000,  0.100])

f25 = (
    [55289.7,    3.0, 25.0, 24.545,  0.055,  0.004,  0.100],
    [55294.6,    4.0, 25.0, 27.706,  0.065,  0.005,  0.100],
    [55298.6,    5.0, 25.0, 35.279,  0.054,  0.006,  0.100],
    [55301.6,    6.0, 25.0, 37.236,  0.074,  0.006,  0.100],
    [55304.7,    7.0, 25.0, 34.345,  0.193,  0.038,  0.100],
    [55308.6,    8.0, 25.0, 30.322,  0.323,  0.025,  0.100],
    [55311.6,    9.0, 25.0, 33.856,  0.053,  0.010,  0.100],
    [55315.6,   10.0, 25.0, 37.507,  0.070,  0.014,  0.100],
    [55318.6,   11.0, 25.0, 34.754,  0.079,  0.015,  0.100],
    [55323.6,   12.0, 25.0, 29.494,  0.060,  0.014,  0.100],
    [55327.6,   13.0, 25.0, 30.309,  0.081,  0.013,  0.100],
    [55332.5,   14.0, 25.0, 29.247,  0.062,  0.012,  0.100],
    [55341.5,	  15.0, 25.0, 28.799,  0.053,  0.011,  0.100],
    [55345.5,   16.0, 25.0, 27.507,  0.084,  0.015,  0.100],
    [55368.5,	  19.0, 25.0, 22.468,  0.062,  0.011,  0.100],
    [55404.3,   20.0, 25.0, 13.636,  0.105,  0.015,  0.100],
    [55419.4,	  21.0, 25.0, 13.297,  0.084,  0.013,  0.100],
    [55434.3,	  22.0, 25.0, 11.200,  0.055,  0.008,  0.100],
    [55449.3,	  23.0, 25.0,  9.506,  0.081,  0.020,  0.100],
    [55469.2,	  24.0, 25.0, 10.082,  0.068,  0.066,  0.100])

f25_6 = (
    [55625.4,   25.0, 25.6,  4.744,  0.033,  0.000,  0.100],
    [55735.4,	  26.0, 25.6,  2.620,  0.048,  0.000,  0.100],
    [55869.1,   27.0, 25.6,  3.828,  0.000,  0.047,  0.100],
    [55934.8,   28.0, 25.6,  2.992,  0.057,  0.000,  0.100],
    [56035.4,   29.0, 25.6,  2.970,  0.052,  0.000,  0.100])

f41 = (
    [55298.7,    5.0, 41.0, 59.890,  0.000, 0.890,  0.200],
    [55327.6,   13.0, 41.0, 51.340,  0.000,  0.750,  0.200],
    [55332.5,   14.0, 41.0, 44.900,  0.000,  0.620,  0.200],
    [55341.5,   15.0, 41.0, 39.970,  0.000,  0.560,  0.200],
    [55345.5,   16.0, 41.0, 37.050,  0.000,  0.570,  0.200],
    [55368.5,	  19.0, 41.0, 25.944,  0.000,  0.646,  0.200],
    [55404.3,	  20.0, 41.0, 18.670,  0.000,  0.831,  0.200],
    [55419.4,	  21.0, 41.0, 12.392,  0.000,  0.479,  0.200],
    [55434.3,	  22.0, 41.0, 14.580,  0.000,  0.586,  0.200],
    [55449.3,	  23.0, 41.0,  9.662,  0.000,  0.845,  0.200],
    [55469.2,	  24.0, 41.0, 14.189,  0.000,  0.640,  0.200],
    [55625.4,   25.0, 41.0,  5.303,  0.000,  0.181,  0.200],
    [55735.4,   26.0, 41.0,  4.249,  0.000,  0.171,  0.200],
    [55869.1,   27.0, 41.0,  4.323,  0.000,  0.124,  0.200],
    [55934.8,   28.0, 41.0,  3.959,  0.000,  0.232,  0.200],
    [56035.4,   29.0, 41.0,  2.879,  0.000,  0.165,  0.200])

f45 = (
    [55298.7,    5.0, 45.0, 65.630,  0.000,  1.160,  0.200],
    [55327.6,   13.0, 45.0, 50.660,  0.000,  0.750,  0.200],
    [55332.5,   14.0, 45.0, 46.310,  0.000,  0.620,  0.200],
    [55341.5,   15.0, 45.0, 38.400,  0.000,  0.640,  0.200],
    [55345.5,   16.0, 45.0, 35.880,  0.000,  0.600,  0.200],
    [55368.5,	  19.0, 45.0, 28.133,  0.000,  0.771,  0.200],
    [55404.3,	  20.0, 45.0, 18.608,  0.000,  0.972,  0.200],
    [55419.4,	  21.0, 45.0, 13.509,  0.000,  0.522,  0.200],
    [55434.3,	  22.0, 45.0, 15.120,  0.000,  0.595,  0.200],
    [55449.3,	  23.0, 45.0,  9.093,  0.000,  0.783,  0.200],
    [55469.2,	  24.0, 45.0, 12.754,  0.000,  0.689,  0.200],
    [55625.4,   25.0, 45.0,  5.445,  0.000,  0.238,  0.200],
    [55735.4,   26.0, 45.0,  4.445,  0.000,  0.237,  0.200],
    [55869.1,   27.0, 45.0,  4.466,  0.000,  0.162,  0.200],
    [55934.8,   28.0, 45.0,  5.225,  0.000,  0.373,  0.200],
    [56035.4,   29.0, 45.0,  2.660,  0.000,  0.247,  0.200])

    #[55289.7    3.0 49.0 44.980  0.000  1.590  0.500]
    #[55308.6    6.0 49.0 82.500  0.000  0.000  0.200] 

f8_35 = (
    [55277.5,   -1.0,  8.35, 8.500,  0.000,  0.800,  0.100],) # ATel 2506
f10_45 = (
    [55277.5,   -1.0, 10.45, 11.60,  0.000,  0.900,  0.100],)
f14_6 = (
    [55277.5,   -1.0, 14.60, 14.60,  0.000,  1.200,  0.100],)
f15 = (
    [55277.5,   -1.0, 15.00, 24.10,  0.000,  1.700,  0.100],)
f142 = (
    [55277.5,   -1.0, 142.0, 146.0,  0.000,  51.00,  0.100],
    
    )

# %%
df_1_5 = pd.DataFrame(f1_5, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_1_4 = pd.DataFrame(f1_4, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_1_3 = pd.DataFrame(f1_3, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_1_9 = pd.DataFrame(f1_9, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_1_8 = pd.DataFrame(f1_8, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_5 = pd.DataFrame(f5, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_4_8 = pd.DataFrame(f4_8, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_7 = pd.DataFrame(f7, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_7_9 = pd.DataFrame(f7_9, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_7_4 = pd.DataFrame(f7_4, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_19 = pd.DataFrame(f19, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_20_1 = pd.DataFrame(f20_1, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_25 = pd.DataFrame(f25, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_25_6 = pd.DataFrame(f25_6, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_41 = pd.DataFrame(f41, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_45 = pd.DataFrame(f45, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_8_35 = pd.DataFrame(f8_35, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_10_45 = pd.DataFrame(f10_45, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_14_6 = pd.DataFrame(f14_6, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_15 = pd.DataFrame(f15, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])
df_142 = pd.DataFrame(f142, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

# %%
MJD_1_5 = df_1_5["MJD"]
days_1_5 = MJD_1_5-55265.2
flux_1_5 = df_1_5["Flux"]
flux_err_1_5 = df_1_5["Error1 (gaussfit)"]

MJD_1_4 = df_1_4["MJD"]
days_1_4 = MJD_1_4-55265.2
flux_1_4 = df_1_4["Flux"]
flux_err_1_4 = df_1_4["Error1 (gaussfit)"]

MJD_1_3 = df_1_3["MJD"]
days_1_3 = MJD_1_3-55265.2
flux_1_3 = df_1_3["Flux"]
flux_err_1_3 = df_1_3["Error1 (gaussfit)"]

MJD_1_9 = df_1_9["MJD"]
days_1_9 = MJD_1_9-55265.2
flux_1_9 = df_1_9["Flux"]
flux_err_1_9 = df_1_9["Error1 (gaussfit)"]

MJD_1_8 = df_1_8["MJD"]
days_1_8 = MJD_1_8-55265.2
flux_1_8 = df_1_8["Flux"]
flux_err_1_8 = df_1_8["Error1 (gaussfit)"]

MJD_5 = df_5["MJD"]
days_5 = MJD_5-55265.2
flux_5 = df_5["Flux"]
flux_err_5 = df_5["Error1 (gaussfit)"]

MJD_4_8 = df_4_8["MJD"]
days_4_8 = MJD_4_8-55265.2
flux_4_8 = df_4_8["Flux"]
flux_err_4_8 = df_4_8["Error1 (gaussfit)"]

MJD_7 = df_7["MJD"]
days_7 = MJD_7-55265.2
flux_7 = df_7["Flux"]
flux_err_7 = df_7["Error1 (gaussfit)"]

MJD_7_9 = df_7_9["MJD"]
days_7_9 = MJD_7_9-55265.2
flux_7_9 = df_7_9["Flux"]
flux_err_7_9 = df_7_9["Error1 (gaussfit)"]

MJD_7_4 = df_7_4["MJD"]
days_7_4 = MJD_7_4-55265.2
flux_7_4 = df_7_4["Flux"]
flux_err_7_4 = df_7_4["Error1 (gaussfit)"]

MJD_19 = df_19["MJD"]
days_19 = MJD_19-55265.2
flux_19 = df_19["Flux"]
flux_err_19 = df_19["Error1 (gaussfit)"]

MJD_20_1 = df_20_1["MJD"]
days_20_1 = MJD_20_1-55265.2
flux_20_1 = df_20_1["Flux"]
flux_err_20_1 = df_20_1["Error1 (gaussfit)"]

MJD_25 = df_25["MJD"]
days_25 = MJD_25-55265.2
flux_25 = df_25["Flux"]
flux_err_25 = df_25["Error1 (gaussfit)"]

MJD_25_6 = df_25_6["MJD"]
days_25_6 = MJD_25_6-55265.2
flux_25_6 = df_25_6["Flux"]
flux_err_25_6 = df_25_6["Error1 (gaussfit)"]

MJD_41 = df_41["MJD"]
days_41 = MJD_41-55265.2
flux_41 = df_41["Flux"]
flux_err_41 = df_41["Error1 (gaussfit)"]

MJD_45 = df_45["MJD"]
days_45 = MJD_45-55265.2
flux_45 = df_45["Flux"]
flux_err_45 = df_45["Error1 (gaussfit)"]

MJD_8_35 = df_8_35["MJD"]
days_8_35 = MJD_8_35-55265.2
flux_8_35 = df_8_35["Flux"]
flux_err_8_35 = df_8_35["Error1 (gaussfit)"]

MJD_10_45 = df_10_45["MJD"]
days_10_45 = MJD_10_45-55265.2
flux_10_45 = df_10_45["Flux"]
flux_err_10_45 = df_10_45["Error1 (gaussfit)"]

MJD_14_6 = df_14_6["MJD"]
days_14_6 = MJD_14_6-55265.2
flux_14_6 = df_14_6["Flux"]
flux_err_14_6 = df_14_6["Error1 (gaussfit)"]

MJD_15 = df_15["MJD"]
days_15 = MJD_15-55265.2
flux_15 = df_15["Flux"]
flux_err_15 = df_15["Error1 (gaussfit)"]

MJD_142 = df_142["MJD"]
days_142 = MJD_142-55265.2
flux_142 = df_142["Flux"]
flux_err_142 = df_142["Error1 (gaussfit)"]

# %%
fig,ax = plt.subplots()

fig.set_size_inches(12,10)

ax.errorbar(days_1_5,flux_1_5, yerr=flux_err_1_5,  label = '1.5 GHz', color='red', fmt='^')
ax.errorbar(days_1_4,flux_1_4,yerr=flux_err_1_4, color='orange', label = '1.4 GHz', fmt='^')
ax.errorbar(days_1_3,flux_1_3,yerr=flux_err_1_3, color='yellow', label = '1.3 GHz', fmt='^')

ax.errorbar(days_1_9,flux_1_9,yerr=flux_err_1_9, color='maroon', label = '1.9 GHz', fmt='^')
ax.errorbar(days_1_8,flux_1_8, yerr=flux_err_1_9, color='gold', label = '1.8 GHz', fmt='^')
ax.errorbar(days_5,flux_5, yerr=flux_err_5, color='tan', label = '5 GHz', fmt='^')

ax.errorbar(days_4_8,flux_4_8, yerr=flux_err_4_8, color='olive', label = '4.8 GHz', fmt='^')
ax.errorbar(days_7,flux_7, yerr=flux_err_7, color='darkolivegreen', label = '7 GHz', fmt='^')
ax.errorbar(days_7_9,flux_7_9, yerr=flux_err_7_9, color='greenyellow', label = '7.9 GHz', fmt='^')

ax.errorbar(days_7_4,flux_7_4, yerr=flux_err_7_4, color='green', label = '7.4 GHz', fmt='^')
ax.errorbar(days_19,flux_19, yerr=flux_err_19, color='aquamarine', label = '19 GHz', fmt='^')
ax.errorbar(days_20_1,flux_20_1, yerr=flux_err_20_1, color='teal', label = '20.1 GHz', fmt='^')

ax.errorbar(days_25,flux_25, yerr=flux_err_25, color='blue', label = '25 GHz', fmt='^')
ax.errorbar(days_25_6,flux_25_6, yerr=flux_err_25_6, color='navy', label = '25.6 GHz', fmt='^')
ax.errorbar(days_41,flux_41, yerr=flux_err_41, color='black', label = '41 GHz', fmt='^')

ax.errorbar(days_45,flux_45, yerr=flux_err_45, color='grey', label = '45 GHz', fmt='^')
ax.errorbar(days_8_35,flux_8_35, yerr=flux_err_8_35, color='blueviolet', label = '8.35 GHz', fmt='^')
ax.errorbar(days_10_45,flux_10_45, yerr=flux_err_10_45, color='purple', label = '10.45 GHz', fmt='^')

ax.errorbar(days_14_6,flux_14_6, yerr=flux_err_14_6, color='violet', label = '14.6 GHz', fmt='^')
ax.errorbar(days_15,flux_15, yerr=flux_err_15, color='deeppink', label = '15 GHz', fmt='^')
ax.errorbar(days_142,flux_142, yerr=flux_err_142, color='lightsteelblue', label = '142 GHz', fmt='^')


ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel("Time since eruption (days)")
ax.set_ylabel("Flux Density (mJy)")
ax.set_title("")
plt.legend()
plt.show()

# %%
fig,ax = plt.subplots()

fig.set_size_inches(12,10)

#ax.errorbar(days_1_5,flux_1_5, yerr=flux_err_1_5,  label = '1.5 GHz', color='red', fmt='^')
ax.errorbar(days_1_4,flux_1_4,yerr=flux_err_1_4, color='orange', label = '1.4 GHz', fmt='^')
ax.errorbar(days_1_3,flux_1_3,yerr=flux_err_1_3, color='yellow', label = '1.3 GHz', fmt='^')
ax.errorbar(days_1_9,flux_1_9,yerr=flux_err_1_9, color='maroon', label = '1.9 GHz', fmt='^')
ax.errorbar(days_1_8,flux_1_8, yerr=flux_err_1_9, color='red', label = '1.8 GHz', fmt='^')


ax.errorbar(days_5,flux_5, yerr=flux_err_5, color='olive', label = '5 GHz', fmt='^')
ax.errorbar(days_4_8,flux_4_8, yerr=flux_err_4_8, color='green', label = '4.8 GHz', fmt='^')
ax.errorbar(days_7,flux_7, yerr=flux_err_7, color='blue', label = '7 GHz', fmt='^')
ax.errorbar(days_7_9,flux_7_9, yerr=flux_err_7_9, color='navy', label = '7.9 GHz', fmt='^')
ax.errorbar(days_7_4,flux_7_4, yerr=flux_err_7_4, color='tan', label = '7.4 GHz', fmt='^')
#ax.errorbar(days_8_35,flux_8_35, yerr=flux_err_8_35, color='blueviolet', label = '8.35 GHz', fmt='^')
#ax.errorbar(days_10_45,flux_10_45, yerr=flux_err_10_45, color='purple', label = '10.45 GHz', fmt='^')

#ax.errorbar(days_14_6,flux_14_6, yerr=flux_err_14_6, color='violet', label = '14.6 GHz', fmt='^')
#ax.errorbar(days_15,flux_15, yerr=flux_err_15, color='deeppink', label = '15 GHz', fmt='^')

ax.errorbar(days_19,flux_19, yerr=flux_err_19, color='aquamarine', label = '19 GHz', fmt='^')
ax.errorbar(days_20_1,flux_20_1, yerr=flux_err_20_1, color='teal', label = '20.1 GHz', fmt='^')
ax.errorbar(days_25,flux_25, yerr=flux_err_25, color='hotpink', label = '25 GHz', fmt='^')
ax.errorbar(days_25_6,flux_25_6, yerr=flux_err_25_6, color='deeppink', label = '25.6 GHz', fmt='^')

ax.errorbar(days_41,flux_41, yerr=flux_err_41, color='black', label = '41 GHz', fmt='^')
ax.errorbar(days_45,flux_45, yerr=flux_err_45, color='grey', label = '45 GHz', fmt='^')

#ax.errorbar(days_142,flux_142, yerr=flux_err_142, color='lightsteelblue', label = '142 GHz', fmt='^')


ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel("Time since eruption (days)")
ax.set_ylabel("Flux Density (mJy)")
ax.set_title("")
plt.legend()
plt.show()

# %%
#Keeping it up, grouping together the frequencies, getting the correct error bars and getting the detections vs non-detections different symbols

# %%
f1_4 = (
    [55289.7,    3.0,  1.4,  2.980,  0.500,  0.000,  0.050], #'AS1039',	'D']
    [55298.7,    5.0,  1.4,  4.040,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55301.7,    6.0,  1.4,  3.597,  0.330,  0.000,  0.050], #'AS1039',	'D']
    [55304.7 ,   7.0 , 1.4,  4.780,  0.300,  0.000,  0.050], #'AS1039',	'D]
    [55308.7  ,  8.0  ,1.4,  5.482,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55311.7  ,  9.0 , 1.4,  5.780,  0.320,  0.000,  0.050], #'AS1039',	'D']
    [55315.6,   10.0  ,1.4,  5.944, 0.260,  0.000,  0.050], #'AS1039',	'D']
    [55318.6,   11.0  ,1.4,  5.760, 0.280,  0.000,  0.050], #'AS1039',	'D']
    [55323.6,   12.0  ,1.4,  6.441,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55330.5 ,  13.0  ,1.4,  5.355,  0.280,  0.000,  0.050], #'AS1039',	'D']
    [55332.6 ,  14.0  ,1.4,  5.803,  0.280,  0.000,  0.050], #'AS1039',	'D']	
    [55341.6 ,  15.0  ,1.4,  5.853,  0.300,  0.000,  0.050], #'AS1039',	'D']
    [55345.6 ,  16.0  ,1.4,  5.828,  0.290,  0.000,  0.050], #'AS1039',	'D']
    [55362.5 ,  17.0,	1.4,  5.606,  0.260,  0.000,  0.050], #'AS1039',	'D']
    [55367.6,	  18.0,	1.4,  5.763,  0.330,  0.000,  0.050], #'AS1039',	'D']
    [55368.5,	  19.0,	1.4,  5.905,  0.290,  0.000,  0.050], #'AS1039',	'D']
    [55404.4 ,  20.0,  1.4,  6.917,  0.280,  0.000,  0.050], #'10B-233', 'D']
    [55419.4,	  21.0,	1.4,  7.924,  0.330,  0.000,  0.050],	#'10B-233', 'D']
    [55434.3,	  22.0,	1.4,  5.489,  0.260,  0.000,  0.050], #'10B-233', 'D']
    [55449.2,	  23.0, 	1.4,  5.608,  0.240,  0.000,  0.050], #'10B-233', 'D']
    [55469.2,	  24.0,	1.4,  5.582,  0.145,  0.000,  0.050],#'10B-233', 'DnC']

#and the 1.3 frequency as well
    [55625.4 ,  25.0 , 1.3,  4.220,  0.163,  0.000,  0.050], #'11A-254', 'B']
    [55735.4 ,  26.0,  1.3,  3.596,  0.081,  0.000,  0.050], #'11A-254', 'A']
    [55869.1 ,  27.0,  1.3,  3.642,  0.534,  0.000,  0.050], #'11B-170', 'D']
    [55934.8 ,  28.0,  1.3,  4.688,  1.020,  0.000,  0.050], #'11B-170', 'DnC *held width constant']
    [56035.4 ,  29.0,  1.3,  2.940,  0.301,  0.000,  0.050], #'11B-170', 'C']
# the 1.5 frequency 
    [55284.8,    2.0,  1.5, -0.124,  0.720,  0.000,  0.050]) #'AL733',   'D *non detection']

f1_8 = (
    [55289.7,    3.0,  1.8,  3.469,  0.350,  0.000,  0.050],
    [55298.7,    5.0,  1.8,  4.762,  0.300,  0.000,  0.050],
    [55301.7,    6.0,  1.8,  5.466,  0.300,  0.000,  0.050],
    [55304.7,    7.0,  1.8,  5.512,  0.350,  0.000,  0.050],
    [55308.7,    8.0,  1.8,  6.662,  0.330,  0.000,  0.050],
    [55311.7,    9.0,  1.8,  6.841,  0.300,  0.000,  0.050],
    [55315.6,   10.0,  1.8,  7.376,  0.290,  0.000,  0.050],
    [55318.6 ,  11.0,  1.8,  7.478,  0.260,  0.000,  0.050],
    [55323.6,   12.0,  1.8,  7.657,  0.330,  0.000,  0.050],
    [55330.5,   13.0,  1.8,  6.651,  0.270,  0.000,  0.050],
    [55332.6,   14.0,  1.8,  7.574,  0.260,  0.000,  0.050],
    [55341.6,   15.0,  1.8,  8.049,  0.260,  0.000,  0.050],
    [55345.6,   16.0,  1.8,  7.532,  0.280,  0.000 , 0.050],
    [55362.5,   17.0,	1.8,  7.540,  0.240,  0.000,  0.050],
    [55367.6,	  18.0,  1.8,  7.811,  0.290,  0.000,  0.050],
    [55368.5,	  19.0,  1.8,  7.381,  0.260,  0.000,  0.050],
    [55404.4 ,  20.0,  1.8 , 8.225,  0.300,  0.000,  0.050],
    [55419.4,	  21.0,	1.8,  8.192 , 0.200,  0.000,  0.050],
    [55434.3,	  22.0,	1.8,  6.386,  0.240,  0.000,  0.050],
    [55449.2,	  23.0, 	1.8,  6.338,  0.160,  0.000,  0.050],
    [55469.2,	  24.0,	1.8,  5.532,  0.135,  0.000,  0.050],
    [55625.4,   25.0,  1.8,  4.644,  0.092,  0.000 , 0.050],
    [55735.4,   26.0,  1.8,  4.074,  0.068,  0.000,  0.050],
    [55869.1 ,  27.0,  1.8,  3.855,  0.291,  0.000,  0.050],
    [55934.8,   28.0,  1.8,  3.316,  0.554,  0.000,  0.050], #held width constant
    [56035.4,   29.0,  1.8,  3.347,  0.232,  0.000,  0.050],

    #the 1.9 frequency
    [55284.8,    2.0,  1.9,  1.930,  0.525,  0.000,  0.050]) #held width constant


f4_8 = (
    [55289.7,    3.0,  4.8,  6.880,  0.000,  0.130,  0.050],
    [55294.7,    4.0,  4.8,  8.990,  0.000,  0.130,  0.050],
    [55298.7,    5.0,  4.8, 10.680,  0.000,  0.110,  0.050],
    [55301.7,    6.0,  4.8, 12.363,  0.182,  0.051,  0.050],
    [55304.7,    7.0,  4.8, 12.792,  0.167,  0.039,  0.050],
    [55308.7,    8.0,  4.8, 13.690,  0.171,  0.034,  0.050],
    [55311.6,    9.0,  4.8, 13.964,  0.078,  0.014,  0.050],
    [55315.6,   10.0,  4.8, 13.673,  0.107,  0.027,  0.050],
    [55318.6,   11.0,  4.8, 13.135,  0.130,  0.028,  0.050],
    [55323.6,   12.0,  4.8, 14.160,  0.088,  0.016,  0.050],
    [55330.5,   13.0,  4.8, 15.023,  0.082,  0.023,  0.050],
    [55332.6,   14.0,  4.8, 15.479,  0.000,  0.155,  0.050],
    [55341.6,   15.0,  4.8, 17.395,  0.092,  0.032,  0.050],
    [55345.6,   16.0,  4.8, 17.465,  0.000,  0.165,  0.050],
    [55362.5,   17.0,  4.8, 17.255,  0.061,  0.016,  0.050],
    [55367.6,	  18.0,	4.8, 17.777,  0.145,  0.032,  0.050],	
    [55368.5,	  19.0,	4.8, 17.446,  0.000,  0.135,  0.050],
    [55404.4,   20.0,  4.8, 12.926,  0.083,  0.022,  0.050],
    [55419.3,	  21.0,	4.8, 11.805,  0.118,  0.018,  0.050],
    [55434.3,	  22.0,	4.8, 10.785,  0.100,  0.018,  0.050],
    [55449.2,	  23.0,  4.8,  9.979,  0.115,  0.024,  0.050],
    [55469.2,	  24.0,	4.8,  9.173,  0.074,  0.000,  0.050], 

    #the frequency 5
    [55282.9,    1.0,  5.0,  6.389,  0.000,  0.150,  0.050],
    [55284.8,    2.0,  5.0,  7.034,  0.000,  0.104,  0.050],
    [55625.4,   25.0,  5.0,  5.003,  0.000,  0.027,  0.050],
    [55735.4,   26.0,  5.0,  3.270,  0.000,  0.029,  0.050],
    [55869.1,   27.0,  5.0,  3.542,  0.000,  0.036,  0.050],
    [55934.8,   28.0,  5.0,  3.212,  0.055,  0.000,  0.050],
    [56035.4,   29.0,  5.0,  2.913,  0.028,  0.000,  0.050])

f7_4 = (   
    #THE FREQ 7
    [55289.7,    3.0,  7.0,  8.810,  0.000,  0.110,  0.050],
    [55294.7,    4.0,  7.0, 11.880,  0.000,  0.080,  0.050],
    [55298.7,    5.0,  7.0, 12.870,  0.000,  0.140,  0.050],
    [55301.7,    6.0,  7.0, 14.670,  0.111,  0.032,  0.050],
    [55304.7,    7.0,  7.0, 15.586,  0.145,  0.050,  0.050],
    [55308.7,    8.0,  7.0, 15.718,  0.108,  0.037,  0.050],
    [55311.6,    9.0,  7.0, 16.072,  0.071,  0.029,  0.050],
    [55315.6,   10.0,  7.0, 16.882,  0.087,  0.038,  0.050],
    [55318.6,   11.0,  7.0, 16.103,  0.089,  0.036,  0.050],
    [55323.6,   12.0,  7.0, 17.178,  0.055,  0.019,  0.050],

    #THE FREQ 7.9
    [55330.5,   13.0,  7.9, 19.175,  0.056,  0.013,  0.050],
    [55332.6,   14.0,  7.9, 19.876,  0.000,  0.133,  0.050],
    [55341.6,   15.0,  7.9, 21.710,  0.080,  0.030,  0.050],
    [55345.6,   16.0,  7.9, 20.618,  0.000,  0.154,  0.050],
    [55362.5,   17.0,  7.9, 20.190,  0.065,  0.009,  0.050],
    [55367.6,	  18.0,	7.9, 19.022,  0.068,  0.015,  0.050],	
    [55368.5,	  19.0,	7.9, 18.301,  0.000,  0.182,  0.050],
    [55404.4,   20.0,  7.9, 14.569,  0.082,  0.017,  0.050],
    [55419.3,	  21.0,	7.9, 12.923,  0.069,  0.013,  0.050],
    [55434.3,	  22.0,	7.9, 11.313,  0.041,  0.009,  0.050],
    [55449.2,	  23.0,	7.9, 10.158,  0.066,  0.012,  0.050],
    [55469.2,	  24.0,	7.9,  9.102,  0.062,  0.000,  0.050],

    #THE FREQ 7.4
    [55625.4,   25.0,  7.4,  4.813,  0.000,  0.023,  0.050],
    [55735.4,   26.0,  7.4,  2.752,  0.000,  0.033,  0.050], 
    [55869.1,   27.0,  7.4,  3.494,  0.000,  0.029,  0.050],
    [55934.8,   28.0,  7.4,  3.154,  0.025,  0.000,  0.050],
    [56035.4,   29.0,  7.4, 2.803,  0.020,  0.000,  0.050],

    #[55277.5   -2.0  8.4  8.500  0.000  0.800  0.200]  #from Effelsberg, ATel 2506
    #[55282.5   -1.0  6.4  8.900  0.000  1.000  0.200]  #from ATA, Atel 2529
)

f19 = (
    [55289.7,    3.0, 19.0, 20.486,  0.075,  0.004,  0.100],
    [55294.6,    4.0, 19.0, 23.654,  0.056,  0.003,  0.100],
    [55298.6,    5.0, 19.0, 29.126,  0.069,  0.005,  0.100],
    [55301.6,    6.0, 19.0, 30.900,  0.084,  0.006,  0.100],
    [55304.7,    7.0, 19.0, 29.153,  0.114,  0.018,  0.100],
    [55308.6,    8.0, 19.0, 28.913,  0.246,  0.016,  0.100],
    [55311.6,    9.0, 19.0, 30.382,  0.072,  0.011,  0.100],
    [55315.6,   10.0, 19.0, 33.032,  0.095,  0.011,  0.100],
    [55318.6,   11.0, 19.0, 29.067,  0.108,  0.018,  0.100],
    [55323.6,   12.0, 19.0, 27.774,  0.079,  0.014,  0.100],
    [55327.6,   13.0, 19.0, 28.251,  0.073,  0.010,  0.100],
    [55332.5,   14.0, 19.0, 28.752,  0.089,  0.012,  0.100],
    [55341.5,	  15.0, 19.0, 28.360,  0.082,  0.013,  0.100],
    [55345.5,   16.0, 19.0, 26.717,  0.074,  0.016,  0.100],
    [55368.5,	  19.0, 19.0, 23.036,  0.106,  0.013,  0.100],
    [55404.3,   20.0, 19.0, 14.867,  0.137,  0.013,  0.100],
    [55419.4,	  21.0, 19.0, 13.256,  0.092,  0.008,  0.100],
    [55434.3,	  22.0, 19.0, 11.867,  0.089,  0.010,  0.100],
    [55449.3,	  23.0, 19.0, 10.008,  0.080,  0.011,  0.100],
    [55469.2,	  24.0, 19.0,  9.864,  0.066,  0.059,  0.100],

    #The freq 20.1
    [55625.4,   25.0, 20.1,  4.652,  0.033,  0.000,  0.100],
    [55735.4,	  26.0, 20.1,  2.542,  0.040,  0.000,  0.100],
    [55869.1,   27.0, 20.1,  3.672,  0.000,  0.038,  0.100],
    [55934.8,   28.0, 20.1,  3.140,  0.047,  0.000,  0.100],
    [56035.4,   29.0, 20.1,  2.914,  0.040,  0.000,  0.100],)

f25 = (
    [55289.7,    3.0, 25.0, 24.545,  0.055,  0.004,  0.100],
    [55294.6,    4.0, 25.0, 27.706,  0.065,  0.005,  0.100],
    [55298.6,    5.0, 25.0, 35.279,  0.054,  0.006,  0.100],
    [55301.6,    6.0, 25.0, 37.236,  0.074,  0.006,  0.100],
    [55304.7,    7.0, 25.0, 34.345,  0.193,  0.038,  0.100],
    [55308.6,    8.0, 25.0, 30.322,  0.323,  0.025,  0.100],
    [55311.6,    9.0, 25.0, 33.856,  0.053,  0.010,  0.100],
    [55315.6,   10.0, 25.0, 37.507,  0.070,  0.014,  0.100],
    [55318.6,   11.0, 25.0, 34.754,  0.079,  0.015,  0.100],
    [55323.6,   12.0, 25.0, 29.494,  0.060,  0.014,  0.100],
    [55327.6,   13.0, 25.0, 30.309,  0.081,  0.013,  0.100],
    [55332.5,   14.0, 25.0, 29.247,  0.062,  0.012,  0.100],
    [55341.5,	  15.0, 25.0, 28.799,  0.053,  0.011,  0.100],
    [55345.5,   16.0, 25.0, 27.507,  0.084,  0.015,  0.100],
    [55368.5,	  19.0, 25.0, 22.468,  0.062,  0.011,  0.100],
    [55404.3,   20.0, 25.0, 13.636,  0.105,  0.015,  0.100],
    [55419.4,	  21.0, 25.0, 13.297,  0.084,  0.013,  0.100],
    [55434.3,	  22.0, 25.0, 11.200,  0.055,  0.008,  0.100],
    [55449.3,	  23.0, 25.0,  9.506,  0.081,  0.020,  0.100],
    [55469.2,	  24.0, 25.0, 10.082,  0.068,  0.066,  0.100],

    #The freq 25.6
    [55625.4,   25.0, 25.6,  4.744,  0.033,  0.000,  0.100],
    [55735.4,	  26.0, 25.6,  2.620,  0.048,  0.000,  0.100],
    [55869.1,   27.0, 25.6,  3.828,  0.000,  0.047,  0.100],
    [55934.8,   28.0, 25.6,  2.992,  0.057,  0.000,  0.100],
    [56035.4,   29.0, 25.6,  2.970,  0.052,  0.000,  0.100])

f41 = (
    [55298.7,    5.0, 41.0, 59.890,  0.000, 0.890,  0.200],
    [55327.6,   13.0, 41.0, 51.340,  0.000,  0.750,  0.200],
    [55332.5,   14.0, 41.0, 44.900,  0.000,  0.620,  0.200],
    [55341.5,   15.0, 41.0, 39.970,  0.000,  0.560,  0.200],
    [55345.5,   16.0, 41.0, 37.050,  0.000,  0.570,  0.200],
    [55368.5,	  19.0, 41.0, 25.944,  0.000,  0.646,  0.200],
    [55404.3,	  20.0, 41.0, 18.670,  0.000,  0.831,  0.200],
    [55419.4,	  21.0, 41.0, 12.392,  0.000,  0.479,  0.200],
    [55434.3,	  22.0, 41.0, 14.580,  0.000,  0.586,  0.200],
    [55449.3,	  23.0, 41.0,  9.662,  0.000,  0.845,  0.200],
    [55469.2,	  24.0, 41.0, 14.189,  0.000,  0.640,  0.200],
    [55625.4,   25.0, 41.0,  5.303,  0.000,  0.181,  0.200],
    [55735.4,   26.0, 41.0,  4.249,  0.000,  0.171,  0.200],
    [55869.1,   27.0, 41.0,  4.323,  0.000,  0.124,  0.200],
    [55934.8,   28.0, 41.0,  3.959,  0.000,  0.232,  0.200],
    [56035.4,   29.0, 41.0,  2.879,  0.000,  0.165,  0.200])

f45 = (
    [55298.7,    5.0, 45.0, 65.630,  0.000,  1.160,  0.200],
    [55327.6,   13.0, 45.0, 50.660,  0.000,  0.750,  0.200],
    [55332.5,   14.0, 45.0, 46.310,  0.000,  0.620,  0.200],
    [55341.5,   15.0, 45.0, 38.400,  0.000,  0.640,  0.200],
    [55345.5,   16.0, 45.0, 35.880,  0.000,  0.600,  0.200],
    [55368.5,	  19.0, 45.0, 28.133,  0.000,  0.771,  0.200],
    [55404.3,	  20.0, 45.0, 18.608,  0.000,  0.972,  0.200],
    [55419.4,	  21.0, 45.0, 13.509,  0.000,  0.522,  0.200],
    [55434.3,	  22.0, 45.0, 15.120,  0.000,  0.595,  0.200],
    [55449.3,	  23.0, 45.0,  9.093,  0.000,  0.783,  0.200],
    [55469.2,	  24.0, 45.0, 12.754,  0.000,  0.689,  0.200],
    [55625.4,   25.0, 45.0,  5.445,  0.000,  0.238,  0.200],
    [55735.4,   26.0, 45.0,  4.445,  0.000,  0.237,  0.200],
    [55869.1,   27.0, 45.0,  4.466,  0.000,  0.162,  0.200],
    [55934.8,   28.0, 45.0,  5.225,  0.000,  0.373,  0.200],
    [56035.4,   29.0, 45.0,  2.660,  0.000,  0.247,  0.200])

    #[55289.7    3.0 49.0 44.980  0.000  1.590  0.500]
    #[55308.6    6.0 49.0 82.500  0.000  0.000  0.200]  

f12_1 = (
    #the frequency 15
    [55277.5,   -1.0, 15.00, 24.10,  0.000,  1.700,  0.100],
    #the frequency 14.6
    [55277.5,   -1.0, 14.60, 14.60,  0.000,  1.200,  0.100],
    #rge freq 10.45
    [55277.5,   -1.0, 10.45, 11.60,  0.000,  0.900,  0.100],
    #the frew 8.35 
    [55277.5,   -1.0,  8.35, 8.500,  0.000,  0.800,  0.100], # ATel 2506
   )

f142 = (
    [55277.5,   -1.0, 142.0, 146.0,  0.000,  51.00,  0.100],)

# %%
df_1_4 = pd.DataFrame(f1_4, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

df_1_8 = pd.DataFrame(f1_8, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

df_4_8 = pd.DataFrame(f4_8, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

df_7_4 = pd.DataFrame(f7_4, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

df_19 = pd.DataFrame(f19, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

df_25 = pd.DataFrame(f25, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

df_41 = pd.DataFrame(f41, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

df_45 = pd.DataFrame(f45, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

df_12_1 = pd.DataFrame(f12_1, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

df_142 = pd.DataFrame(f142, columns = ["MJD","Epoch","Freq","Flux","Error1 (gaussfit)","Error2 (image)","Error3 (calibration) (%)",])

# %%
MJD_1_4 = df_1_4["MJD"]
days_1_4 = MJD_1_4-55265.8
flux_1_4 = df_1_4["Flux"]
flux_err_1_4 = np.sqrt((df_1_4["Error1 (gaussfit)"])**2 + (df_1_4['Flux']*0.05)**2)


MJD_1_8 = df_1_8["MJD"]
days_1_8 = MJD_1_8-55265.8
flux_1_8 = df_1_8["Flux"]
flux_err_1_8 = np.sqrt((df_1_8["Error1 (gaussfit)"])**2 + (df_1_8['Flux']*0.05)**2)


MJD_4_8 = df_4_8["MJD"]
days_4_8 = MJD_4_8-55265.8
flux_4_8 = df_4_8["Flux"]
flux_err_4_8 = np.sqrt((df_4_8["Error1 (gaussfit)"])**2 + (df_4_8['Flux']*0.05)**2)


MJD_7_4 = df_7_4["MJD"]
days_7_4 = MJD_7_4-55265.8
flux_7_4 = df_7_4["Flux"]
flux_err_7_4 = np.sqrt((df_7_4["Error1 (gaussfit)"])**2 + (df_7_4['Flux']*0.05)**2)

MJD_19 = df_19["MJD"]
days_19 = MJD_19-55265.8
flux_19 = df_19["Flux"]
flux_err_19 = np.sqrt((df_19["Error1 (gaussfit)"])**2 + (df_19['Flux']*0.1)**2)


MJD_25 = df_25["MJD"]
days_25 = MJD_25-55265.8
flux_25 = df_25["Flux"]
flux_err_25 = np.sqrt((df_25["Error1 (gaussfit)"])**2 + (df_25['Flux']*0.1)**2)


MJD_41 = df_41["MJD"]
days_41 = MJD_41-55265.8
flux_41 = df_41["Flux"]
flux_err_41 = np.sqrt((df_41["Error1 (gaussfit)"])**2 + (df_41['Flux']*0.1)**2)

MJD_45 = df_45["MJD"]
days_45 = MJD_45-55265.8
flux_45 = df_45["Flux"]
flux_err_45 = np.sqrt((df_45["Error1 (gaussfit)"])**2 + (df_45['Flux']*0.1)**2)

MJD_12_1 = df_12_1["MJD"]
days_12_1 = MJD_12_1-55265.8
flux_12_1 = df_12_1["Flux"]
flux_err_12_1 = np.sqrt((df_12_1["Error1 (gaussfit)"])**2 + (df_12_1['Flux']*0.1)**2)

MJD_142 = df_142["MJD"]
days_142 = MJD_142-55265.8
flux_142 = df_142["Flux"]
flux_err_142 = np.sqrt((df_142["Error1 (gaussfit)"])**2 + (df_142['Flux']*0.1)**2)

# %%
"""fig,ax = plt.subplots()

fig.set_size_inches(12,10)

#if it is classified as a non-detection then it is a square symbol 
for i in flux_1_4:
    for j in flux_err_1_4:
        if i < 3*j:
            ax.errorbar(days_1_4,flux_1_4,yerr=flux_err_1_4, color='orange', fmt='s')
        else:
            ax.errorbar(days_1_4,flux_1_4,yerr=flux_err_1_4, color='orange', label = '1.4 GHz', fmt='^')

for i in flux_1_8:
    for j in flux_err_1_8:
        
        if i < 3*j:
            ax.errorbar(days_1_8,flux_1_8,yerr=flux_err_1_8, color='red', fmt='s')
        else:
            ax.errorbar(days_1_8,flux_1_8,yerr=flux_err_1_8, color='red', label = '1.8 GHz', fmt='^')

for i in flux_4_8:
    for j in flux_err_4_8:
        
        if i < 3*j:
            ax.errorbar(days_4_8,flux_4_8,yerr=flux_err_4_8, color='green', fmt='s')
        else:
            ax.errorbar(days_4_8,flux_4_8,yerr=flux_err_4_8, color='green', label = '4.8 GHz', fmt='^')

for i in flux_7_4:
    for j in flux_err_7_4:
        
        if i < 3*j:
            ax.errorbar(days_7_4,flux_7_4,yerr=flux_err_7_4, color='blue', fmt='s')
        else:
            ax.errorbar(days_7_4,flux_7_4,yerr=flux_err_7_4, color='blue', label = '7.4 GHz', fmt='^')

for i in flux_19:
    for j in flux_err_19:
        
        if i < 3*j:
            ax.errorbar(days_19,flux_19,yerr=flux_err_19, color='hotpink', fmt='s')
        else:
            ax.errorbar(days_19,flux_19,yerr=flux_err_19, color='hotpink', label = '19 GHz', fmt='^')

for i in flux_25:
    for j in flux_err_25:
        
        if i < 3*j:
            ax.errorbar(days_25,flux_25,yerr=flux_err_25, color='teal', fmt='s')
        else:
            ax.errorbar(days_25,flux_25,yerr=flux_err_25, color='teal', label = '25 GHz', fmt='^')

for i in flux_41:
    for j in flux_err_41:
        
        if i < 3*j:
            ax.errorbar(days_41,flux_41,yerr=flux_err_41, color='black', fmt='s')
        else:
            ax.errorbar(days_41,flux_41,yerr=flux_err_41, color='black', label = '41 GHz', fmt='^')

for i in flux_45:
    for j in flux_err_45:
        
        if i < 3*j:
            ax.errorbar(days_45,flux_45,yerr=flux_err_45, color='yellow', fmt='s')
        else:
            ax.errorbar(days_45,flux_45,yerr=flux_err_45, color='yellow', label = '45 GHz', fmt='^')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel("Time since eruption (days)")
ax.set_ylabel("Flux Density (mJy)")
ax.set_title("")
plt.legend()
plt.show()""";

# %%
#trying again, but this time with a function to do that, to make sure there aren't hundreds of labels on the graph

# %%
print(flux_err_4_8)
# Out:
# 0     0.344000
# 1     0.449500
# 2     0.534000
# 3     0.644386
# 4     0.661042
# 5     0.705536
# 6     0.702543
# 7     0.691973
# 8     0.669493
# 9     0.713448
# 10    0.755613
# 11    0.773950
# 12    0.874602
# 13    0.873250
# 14    0.864904
# 15    0.900599
# 16    0.872300
# 17    0.651608
# 18    0.601929
# 19    0.548444
# 20    0.512031
# 21    0.464581
# 22    0.319450
# 23    0.351700
# 24    0.250150
# 25    0.163500
# 26    0.177100
# 27    0.169757
# 28    0.148317
# dtype: float64

# %%
print(flux_4_8)
# Out:
# 0      6.880
# 1      8.990
# 2     10.680
# 3     12.363
# 4     12.792
# 5     13.690
# 6     13.964
# 7     13.673
# 8     13.135
# 9     14.160
# 10    15.023
# 11    15.479
# 12    17.395
# 13    17.465
# 14    17.255
# 15    17.777
# 16    17.446
# 17    12.926
# 18    11.805
# 19    10.785
# 20     9.979
# 21     9.173
# 22     6.389
# 23     7.034
# 24     5.003
# 25     3.270
# 26     3.542
# 27     3.212
# 28     2.913
# Name: Flux, dtype: float64

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12,10)

# Store which labels have already been used
used_labels = set()

def plot(days, fluxes, errors, color, label_name):
    for day, flux, err in zip(days, fluxes, errors):
        if flux < 3 * err:
            fmt = 'x'  # square for non-detection
            label = None  # no label for non-detections
            ax.errorbar(day, (flux+err*3), fmt=fmt, color=color, label=label)
            
        else:
            fmt = '^'  # triangle for detection
            label = label_name if label_name not in used_labels else None
        
            ax.errorbar(day, flux, yerr=err, fmt=fmt, color=color, label=label)
        
        if label:
            used_labels.add(label)

# Plot each band
plot(days_1_4, flux_1_4, flux_err_1_4, 'orange', '1.4 GHz')
plot(days_1_8, flux_1_8, flux_err_1_8, 'red', '1.8 GHz')
plot(days_4_8, flux_4_8, flux_err_4_8, 'green', '4.8 GHz')
plot(days_7_4, flux_7_4, flux_err_7_4, 'blue', '7.4 GHz')
plot(days_19, flux_19, flux_err_19, 'hotpink', '19 GHz')
plot(days_25, flux_25, flux_err_25, 'teal', '25 GHz')
plot(days_41, flux_41, flux_err_41, 'black', '41 GHz')
plot(days_45, flux_45, flux_err_45, 'yellow', '45 GHz')
plot(days_12_1, flux_12_1, flux_err_12_1, 'purple', '12.1 GHz')
plot(days_142, flux_142, flux_err_142, 'brown', '142 GHz')

# Final plot formatting
ax.set_xscale('log')
ax.set_xticks([10,20,50,100,500,1000], labels = ['10','20','50','100','500','1000'], fontsize =20)
ax.set_yscale('log')
ax.set_yticks([1,10, 100], labels = [r'$10^{0}$',r'$10^{1}$', r'$10^{2}$'], fontsize = 20)
ax.set_xlabel("Time since eruption (days)", fontsize = 25)
ax.set_ylabel("Flux Density (mJy)", fontsize = 25)

ax.tick_params(axis='both', which='both', direction='in', top=True, right=True)

ax.set_title("")
plt.legend(fontsize = 15)
plt.savefig("V407_lc.png")
plt.show()

# %%
np.max(flux_4_8)
# Out:
# 17.777

# %%
df_4_8
# Out:
#         MJD  Epoch  Freq    Flux  Error1 (gaussfit)  Error2 (image)  \
# 0   55289.7    3.0   4.8   6.880              0.000           0.130
# 1   55294.7    4.0   4.8   8.990              0.000           0.130
# 2   55298.7    5.0   4.8  10.680              0.000           0.110
# 3   55301.7    6.0   4.8  12.363              0.182           0.051
# 4   55304.7    7.0   4.8  12.792              0.167           0.039
# 5   55308.7    8.0   4.8  13.690              0.171           0.034
# 6   55311.6    9.0   4.8  13.964              0.078           0.014
# 7   55315.6   10.0   4.8  13.673              0.107           0.027
# 8   55318.6   11.0   4.8  13.135              0.130           0.028
# 9   55323.6   12.0   4.8  14.160              0.088           0.016
# 10  55330.5   13.0   4.8  15.023              0.082           0.023
# 11  55332.6   14.0   4.8  15.479              0.000           0.155
# 12  55341.6   15.0   4.8  17.395              0.092           0.032
# 13  55345.6   16.0   4.8  17.465              0.000           0.165
# 14  55362.5   17.0   4.8  17.255              0.061           0.016
# 15  55367.6   18.0   4.8  17.777              0.145           0.032
# 16  55368.5   19.0   4.8  17.446              0.000           0.135
# 17  55404.4   20.0   4.8  12.926              0.083           0.022
# 18  55419.3   21.0   4.8  11.805              0.118           0.018
# 19  55434.3   22.0   4.8  10.785              0.100           0.018
# 20  55449.2   23.0   4.8   9.979              0.115           0.024
# 21  55469.2   24.0   4.8   9.173              0.074           0.000
# 22  55282.9    1.0   5.0   6.389              0.000           0.150
# 23  55284.8    2.0   5.0   7.034              0.000           0.104
# 24  55625.4   25.0   5.0   5.003              0.000           0.027
# 25  55735.4   26.0   5.0   3.270              0.000           0.029
# 26  55869.1   27.0   5.0   3.542              0.000           0.036
# 27  55934.8   28.0   5.0   3.212              0.055           0.000
# 28  56035.4   29.0   5.0   2.913              0.028           0.000
#
#     Error3 (calibration) (%)
# 0                       0.05
# 1                       0.05
# 2                       0.05
# 3                       0.05
# 4                       0.05
# 5                       0.05
# 6                       0.05
# 7                       0.05
# 8                       0.05
# 9                       0.05
# 10                      0.05
# 11                      0.05
# 12                      0.05
# 13                      0.05
# 14                      0.05
# 15                      0.05
# 16                      0.05
# 17                      0.05
# 18                      0.05
# 19                      0.05
# 20                      0.05
# 21                      0.05
# 22                      0.05
# 23                      0.05
# 24                      0.05
# 25                      0.05
# 26                      0.05
# 27                      0.05
# 28                      0.05
